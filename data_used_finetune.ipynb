# %%
import os
import numpy as np
import pandas as pd

# 경로 설정
ctrl_csv_path = '/mnt/dsk1/yhlee/workdir/cmaqnet/datasets/control_matrix.csv'
# met_npy_path = '/mnt/dsk1/yhlee/workdir/cmaqnet/datasets/interpolated_meteo_v2.npy'
met_npy_path = '/mnt/dsk1/yhlee/workdir/cmaqnet/datasets/rsm_total_o3_conc.npy'

# %%
# 2. Meteorological 데이터 로드 및 확인
met_data = np.load(met_npy_path).astype(np.float32)
print("Meteorological 데이터 shape:", met_data.shape)
print("\nMeteorological 데이터 타입:", met_data.dtype)
# Out:
# Meteorological 데이터 shape: (119, 4, 40, 24, 1, 82, 67)
#
# Meteorological 데이터 타입: float32

# %%
ctrl_df = pd.read_csv(ctrl_csv_path, index_col=0)
ctrl_df
# Out:
#      1)A_ALL_POW  2)A_ALL_IND  3)A_ALL_MOB  4)A_ALL_RES  5)A_NH3_AGR  \
# Run
# 1       1.000000     1.000000     1.000000     1.000000     1.000000
# 2       0.514472     0.927851     0.945247     0.692404     1.109061
# 3       1.491511     1.186824     0.617696     0.980489     0.584264
# 4       1.315290     1.020411     1.398561     0.913795     0.511858
# 5       1.335318     0.533092     0.682967     1.105300     0.665543
# ..           ...          ...          ...          ...          ...
# 115     1.379326     1.261603     0.639514     0.589251     1.232075
# 116     1.254290     0.770109     1.122607     0.606761     1.160236
# 117     1.245353     0.797480     0.835128     0.968097     1.359073
# 118     1.343780     0.601578     0.824097     1.048677     0.913516
# 119     0.848999     1.394097     0.858153     1.052993     0.955613
#
#      6)A_ALL_SLV  7)A_ALL_OTH  8)B_ALL_POW  9)B_ALL_IND  10)B_ALL_MOB  ...  \
# ...
