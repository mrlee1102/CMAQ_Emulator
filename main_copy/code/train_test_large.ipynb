# %%
import os

import numpy as np
import pandas as pd
import netCDF4 as nc
from sklearn.model_selection import train_test_split

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
from tensorflow.keras.utils import Sequence
    
from src.model.cmaqnet_cond_unet import build_model

# define constants
model_path = '/home/user/workdir/main/src/model/small_1/final_model'  # 모델 저장 경로
epochs = 100  # 훈련 반복 횟수
batch_size = 32  # 배치 크기
test_split = 0.2  # 테스트 데이터 비율 (20%)
random_seed = 42  # 랜덤 시드

# build model
model = build_model(
    ctrl_dim=17*5, # 17 regions * 5 precursor activities
    cond_dim=[1, 1], # timestep / boundary activity
    emb_dims=[128, 128],
    emb_type=['time', 'normal'],
    out_channel=1,
    hidden_size=[128, 96],
    hidden_depth=4,
    in_filters=20,
    kernel_size=3,
    activation='silu',
    dropout=0.0,
    use_abs=True)

model.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss=tf.keras.losses.MeanSquaredError(),)
model.summary()

# define callback
def scheduler(epoch, lr):
    if epoch < 500: return 1e-3
    else: return 1e-4
callback_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)

callback_ckpt = tf.keras.callbacks.ModelCheckpoint(
    filepath='/home/user/workdir/main/src/model/large_1/final_model-{epoch:02d}-{val_loss:.2f}',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    save_freq='epoch')

# load data
emis_ctrl_2019_05 = pd.read_csv(
    '/home/user/workdir/main/resources/ctrl/precursor_control_2019.csv', index_col=0)
emis_ctrl_2019_05['Timestep'] = 0.0
emis_ctrl_2019_05['Boundary'] = 0.5
# emis_ctrl_2019_02 = emis_ctrl_2019_05.copy()
# emis_ctrl_2019_02['Boundary'] = 1.0
emis_ctrl_2019_10 = emis_ctrl_2019_05.copy()
emis_ctrl_2019_10['Boundary'] = 1.0
ctrl_data = pd.concat([
    # emis_ctrl_2019_02,
    emis_ctrl_2019_05,
    emis_ctrl_2019_10
], axis=0)
ctrl_data = ctrl_data.reset_index(drop=True).values
emis_data, time_data, boundary_data = ctrl_data[:, :85], ctrl_data[:, 85], ctrl_data[:, 86]

base_path_2019 = '/home/user/workdir/main/datasets/concentration/2019'

conc_path = []
for i in range(1, 120):
    conc_path.append(os.path.join(base_path_2019, '0.50', f'ACONC.{i}'))
for i in range(1, 120):
    conc_path.append(os.path.join(base_path_2019, '1.00', f'ACONC.{i}'))
# -------------------------
X_train, X_test, y_train_path, y_test_path = train_test_split(
    ctrl_data, conc_path, test_size=test_split, random_state=random_seed)

class DataGenerator(Sequence):
    def __init__(self, x_set, y_set, shuffle:bool=True, random_seed:int=42):
        self.shuffle = shuffle
        self.random_state = np.random.RandomState(random_seed)
        self.ctrl_data = x_set
        self.conc_path = y_set
        self.on_epoch_end()
    
    def __len__(self):
        return len(self.ctrl_data)
    
    def __getitem__(self, index):
        i = self.indexes[index]
        emis_data, time_data, boundary_data = \
            self.ctrl_data[i, :85], self.ctrl_data[i, 85], self.ctrl_data[i, 86]
        path = self.conc_path[i]
        with nc.Dataset(path) as f:
            conc_data = f.variables['PM2_5'][:].data.squeeze().reshape(82, 67, 1)
        return [emis_data, time_data, boundary_data], conc_data
    
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.ctrl_data))
        if self.shuffle:
            self.random_state.shuffle(self.indexes)

train_generator = DataGenerator(X_train, y_train_path)
test_generator = DataGenerator(X_test, y_test_path)
# Out:
# 2024-12-26 09:14:04.386123: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-26 09:14:04.388342: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-26 09:14:04.416345: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-26 09:14:04.416369: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-26 09:14:04.416390: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-26 09:14:04.421932: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-26 09:14:04.422616: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-26 09:14:05.099604: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-26 09:14:05.633433: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  cond_input_0 (InputLayer)   [(None, 1)]                  0         []
#
#  tf.math.multiply (TFOpLamb  (None, 438)                  0         ['cond_input_0[0][0]']
#  da)
#
#  tf.math.sin (TFOpLambda)    (None, 438)                  0         ['tf.math.multiply[0][0]']
#
#  tf.math.cos (TFOpLambda)    (None, 438)                  0         ['tf.math.multiply[0][0]']
#
#  ctrl_input (InputLayer)     [(None, 85)]                 0         []
#
#  tf.concat (TFOpLambda)      (None, 876)                  0         ['tf.math.sin[0][0]',
#                                                                      'tf.math.cos[0][0]']
#
#  cond_input_1 (InputLayer)   [(None, 1)]                  0         []
#
#  gridding_layer (GriddingLa  (None, 82, 67, 5)            0         ['ctrl_input[0][0]']
#  yer)
#
#  dense (Dense)               (None, 128)                  112256    ['tf.concat[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  256       ['cond_input_1[0][0]']
#
#  resizing (Resizing)         (None, 128, 96, 5)           0         ['gridding_layer[0][0]']
#
#  activation (Activation)     (None, 128)                  0         ['dense[0][0]']
#
#  activation_1 (Activation)   (None, 128)                  0         ['dense_1[0][0]']
#
#  conv2d (Conv2D)             (None, 128, 96, 20)          920       ['resizing[0][0]']
#
#  dense_2 (Dense)             (None, 20)                   2580      ['activation[0][0]']
#
#  dense_3 (Dense)             (None, 20)                   2580      ['activation_1[0][0]']
#
#  batch_normalization (Batch  (None, 128, 96, 20)          80        ['conv2d[0][0]']
#  Normalization)
#
#  activation_3 (Activation)   (None, 20)                   0         ['dense_2[0][0]']
#
#  activation_4 (Activation)   (None, 20)                   0         ['dense_3[0][0]']
#
#  activation_2 (Activation)   (None, 128, 96, 20)          0         ['batch_normalization[0][0]']
#
#  reshape (Reshape)           (None, 1, 1, 20)             0         ['activation_3[0][0]']
#
#  reshape_1 (Reshape)         (None, 1, 1, 20)             0         ['activation_4[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 96, 20)          3620      ['activation_2[0][0]']
#
#  multiply (Multiply)         (None, 128, 96, 20)          0         ['activation_2[0][0]',
#                                                                      'reshape[0][0]']
#
#  multiply_1 (Multiply)       (None, 128, 96, 20)          0         ['activation_2[0][0]',
#                                                                      'reshape_1[0][0]']
#
#  add (Add)                   (None, 128, 96, 20)          0         ['conv2d_1[0][0]',
#                                                                      'multiply[0][0]',
#                                                                      'multiply_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 96, 20)          80        ['add[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 128, 96, 20)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 128, 96, 20)          0         ['activation_5[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 128, 96, 40)          7240      ['dropout[0][0]']
#
#  dense_4 (Dense)             (None, 40)                   5160      ['activation[0][0]']
#
#  dense_5 (Dense)             (None, 40)                   5160      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 96, 40)          160       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 40)                   0         ['dense_4[0][0]']
#
#  activation_8 (Activation)   (None, 40)                   0         ['dense_5[0][0]']
#
#  activation_6 (Activation)   (None, 128, 96, 40)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  reshape_2 (Reshape)         (None, 1, 1, 40)             0         ['activation_7[0][0]']
#
#  reshape_3 (Reshape)         (None, 1, 1, 40)             0         ['activation_8[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 96, 40)          14440     ['activation_6[0][0]']
#
#  multiply_2 (Multiply)       (None, 128, 96, 40)          0         ['activation_6[0][0]',
#                                                                      'reshape_2[0][0]']
#
#  multiply_3 (Multiply)       (None, 128, 96, 40)          0         ['activation_6[0][0]',
#                                                                      'reshape_3[0][0]']
#
#  add_1 (Add)                 (None, 128, 96, 40)          0         ['conv2d_3[0][0]',
#                                                                      'multiply_2[0][0]',
#                                                                      'multiply_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 96, 40)          160       ['add_1[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 128, 96, 40)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 128, 96, 40)          0         ['activation_9[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 48, 40)           0         ['dropout_1[0][0]']
#  D)
#
#  conv2d_4 (Conv2D)           (None, 64, 48, 80)           28880     ['max_pooling2d[0][0]']
#
#  dense_6 (Dense)             (None, 80)                   10320     ['activation[0][0]']
#
#  dense_7 (Dense)             (None, 80)                   10320     ['activation_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 48, 80)           320       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_11 (Activation)  (None, 80)                   0         ['dense_6[0][0]']
#
#  activation_12 (Activation)  (None, 80)                   0         ['dense_7[0][0]']
#
#  activation_10 (Activation)  (None, 64, 48, 80)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  reshape_4 (Reshape)         (None, 1, 1, 80)             0         ['activation_11[0][0]']
#
#  reshape_5 (Reshape)         (None, 1, 1, 80)             0         ['activation_12[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 48, 80)           57680     ['activation_10[0][0]']
#
#  multiply_4 (Multiply)       (None, 64, 48, 80)           0         ['activation_10[0][0]',
#                                                                      'reshape_4[0][0]']
#
#  multiply_5 (Multiply)       (None, 64, 48, 80)           0         ['activation_10[0][0]',
#                                                                      'reshape_5[0][0]']
#
#  add_2 (Add)                 (None, 64, 48, 80)           0         ['conv2d_5[0][0]',
#                                                                      'multiply_4[0][0]',
#                                                                      'multiply_5[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 48, 80)           320       ['add_2[0][0]']
#  chNormalization)
#
#  activation_13 (Activation)  (None, 64, 48, 80)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 64, 48, 80)           0         ['activation_13[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 24, 80)           0         ['dropout_2[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 24, 160)          115360    ['max_pooling2d_1[0][0]']
#
#  dense_8 (Dense)             (None, 160)                  20640     ['activation[0][0]']
#
#  dense_9 (Dense)             (None, 160)                  20640     ['activation_1[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 24, 160)          640       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_15 (Activation)  (None, 160)                  0         ['dense_8[0][0]']
#
#  activation_16 (Activation)  (None, 160)                  0         ['dense_9[0][0]']
#
#  activation_14 (Activation)  (None, 32, 24, 160)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  reshape_6 (Reshape)         (None, 1, 1, 160)            0         ['activation_15[0][0]']
#
#  reshape_7 (Reshape)         (None, 1, 1, 160)            0         ['activation_16[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 24, 160)          230560    ['activation_14[0][0]']
#
#  multiply_6 (Multiply)       (None, 32, 24, 160)          0         ['activation_14[0][0]',
#                                                                      'reshape_6[0][0]']
#
#  multiply_7 (Multiply)       (None, 32, 24, 160)          0         ['activation_14[0][0]',
#                                                                      'reshape_7[0][0]']
#
#  add_3 (Add)                 (None, 32, 24, 160)          0         ['conv2d_7[0][0]',
#                                                                      'multiply_6[0][0]',
#                                                                      'multiply_7[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 24, 160)          640       ['add_3[0][0]']
#  chNormalization)
#
#  activation_17 (Activation)  (None, 32, 24, 160)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_3 (Dropout)         (None, 32, 24, 160)          0         ['activation_17[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 12, 160)          0         ['dropout_3[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 12, 320)          461120    ['max_pooling2d_2[0][0]']
#
#  dense_10 (Dense)            (None, 320)                  41280     ['activation[0][0]']
#
#  dense_11 (Dense)            (None, 320)                  41280     ['activation_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 16, 12, 320)          1280      ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_19 (Activation)  (None, 320)                  0         ['dense_10[0][0]']
#
#  activation_20 (Activation)  (None, 320)                  0         ['dense_11[0][0]']
#
#  activation_18 (Activation)  (None, 16, 12, 320)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  reshape_8 (Reshape)         (None, 1, 1, 320)            0         ['activation_19[0][0]']
#
#  reshape_9 (Reshape)         (None, 1, 1, 320)            0         ['activation_20[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 12, 320)          921920    ['activation_18[0][0]']
#
#  multiply_8 (Multiply)       (None, 16, 12, 320)          0         ['activation_18[0][0]',
#                                                                      'reshape_8[0][0]']
#
#  multiply_9 (Multiply)       (None, 16, 12, 320)          0         ['activation_18[0][0]',
#                                                                      'reshape_9[0][0]']
#
#  add_4 (Add)                 (None, 16, 12, 320)          0         ['conv2d_9[0][0]',
#                                                                      'multiply_8[0][0]',
#                                                                      'multiply_9[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 12, 320)          1280      ['add_4[0][0]']
#  chNormalization)
#
#  activation_21 (Activation)  (None, 16, 12, 320)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 16, 12, 320)          0         ['activation_21[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 24, 160)          460960    ['dropout_4[0][0]']
#  anspose)
#
#  batch_normalization_10 (Ba  (None, 32, 24, 160)          640       ['conv2d_transpose[0][0]']
#  tchNormalization)
#
#  dense_12 (Dense)            (None, 160)                  20640     ['activation[0][0]']
#
#  dense_13 (Dense)            (None, 160)                  20640     ['activation_1[0][0]']
#
#  activation_22 (Activation)  (None, 32, 24, 160)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 160)                  0         ['dense_12[0][0]']
#
#  activation_24 (Activation)  (None, 160)                  0         ['dense_13[0][0]']
#
#  concatenate (Concatenate)   (None, 32, 24, 320)          0         ['activation_22[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  reshape_10 (Reshape)        (None, 1, 1, 160)            0         ['activation_23[0][0]']
#
#  reshape_11 (Reshape)        (None, 1, 1, 160)            0         ['activation_24[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 24, 160)          460960    ['concatenate[0][0]']
#
#  multiply_10 (Multiply)      (None, 32, 24, 160)          0         ['activation_22[0][0]',
#                                                                      'reshape_10[0][0]']
#
#  multiply_11 (Multiply)      (None, 32, 24, 160)          0         ['activation_22[0][0]',
#                                                                      'reshape_11[0][0]']
#
#  add_5 (Add)                 (None, 32, 24, 160)          0         ['conv2d_10[0][0]',
#                                                                      'multiply_10[0][0]',
#                                                                      'multiply_11[0][0]']
#
#  batch_normalization_11 (Ba  (None, 32, 24, 160)          640       ['add_5[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 32, 24, 160)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 32, 24, 160)          0         ['activation_25[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 48, 80)           115280    ['dropout_5[0][0]']
#  Transpose)
#
#  batch_normalization_12 (Ba  (None, 64, 48, 80)           320       ['conv2d_transpose_1[0][0]']
#  tchNormalization)
#
#  dense_14 (Dense)            (None, 80)                   10320     ['activation[0][0]']
#
#  dense_15 (Dense)            (None, 80)                   10320     ['activation_1[0][0]']
#
#  activation_26 (Activation)  (None, 64, 48, 80)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 80)                   0         ['dense_14[0][0]']
#
#  activation_28 (Activation)  (None, 80)                   0         ['dense_15[0][0]']
#
#  concatenate_1 (Concatenate  (None, 64, 48, 160)          0         ['activation_26[0][0]',
#  )                                                                   'dropout_2[0][0]']
#
#  reshape_12 (Reshape)        (None, 1, 1, 80)             0         ['activation_27[0][0]']
#
#  reshape_13 (Reshape)        (None, 1, 1, 80)             0         ['activation_28[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 64, 48, 80)           115280    ['concatenate_1[0][0]']
#
#  multiply_12 (Multiply)      (None, 64, 48, 80)           0         ['activation_26[0][0]',
#                                                                      'reshape_12[0][0]']
#
#  multiply_13 (Multiply)      (None, 64, 48, 80)           0         ['activation_26[0][0]',
#                                                                      'reshape_13[0][0]']
#
#  add_6 (Add)                 (None, 64, 48, 80)           0         ['conv2d_11[0][0]',
#                                                                      'multiply_12[0][0]',
#                                                                      'multiply_13[0][0]']
#
#  batch_normalization_13 (Ba  (None, 64, 48, 80)           320       ['add_6[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 64, 48, 80)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 64, 48, 80)           0         ['activation_29[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 96, 40)          28840     ['dropout_6[0][0]']
#  Transpose)
#
#  batch_normalization_14 (Ba  (None, 128, 96, 40)          160       ['conv2d_transpose_2[0][0]']
#  tchNormalization)
#
#  dense_16 (Dense)            (None, 40)                   5160      ['activation[0][0]']
#
#  dense_17 (Dense)            (None, 40)                   5160      ['activation_1[0][0]']
#
#  activation_30 (Activation)  (None, 128, 96, 40)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 40)                   0         ['dense_16[0][0]']
#
#  activation_32 (Activation)  (None, 40)                   0         ['dense_17[0][0]']
#
#  concatenate_2 (Concatenate  (None, 128, 96, 80)          0         ['activation_30[0][0]',
#  )                                                                   'dropout_1[0][0]']
#
#  reshape_14 (Reshape)        (None, 1, 1, 40)             0         ['activation_31[0][0]']
#
#  reshape_15 (Reshape)        (None, 1, 1, 40)             0         ['activation_32[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 128, 96, 40)          28840     ['concatenate_2[0][0]']
#
#  multiply_14 (Multiply)      (None, 128, 96, 40)          0         ['activation_30[0][0]',
#                                                                      'reshape_14[0][0]']
#
#  multiply_15 (Multiply)      (None, 128, 96, 40)          0         ['activation_30[0][0]',
#                                                                      'reshape_15[0][0]']
#
#  add_7 (Add)                 (None, 128, 96, 40)          0         ['conv2d_12[0][0]',
#                                                                      'multiply_14[0][0]',
#                                                                      'multiply_15[0][0]']
#
#  batch_normalization_15 (Ba  (None, 128, 96, 40)          160       ['add_7[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 128, 96, 40)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  dropout_7 (Dropout)         (None, 128, 96, 40)          0         ['activation_33[0][0]']
#
#  resizing_1 (Resizing)       (None, 82, 67, 40)           0         ['dropout_7[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 82, 67, 1)            41        ['resizing_1[0][0]']
#
#  tf.math.abs (TFOpLambda)    (None, 82, 67, 1)            0         ['conv2d_13[0][0]']
#
# ==================================================================================================
# Total params: 3403853 (12.98 MB)
# Trainable params: 3400253 (12.97 MB)
# Non-trainable params: 3600 (14.06 KB)
# __________________________________________________________________________________________________

# %%
train_generator

# %%
# train model
history = model.fit(
    train_generator,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=test_generator,
    callbacks=[callback_lr, callback_ckpt])
model.save(model_path)
