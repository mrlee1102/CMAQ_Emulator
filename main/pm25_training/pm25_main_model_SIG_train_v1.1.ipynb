# %% [markdown]
# ## 시군구 형식(v1.1)의 모델 학습 및 예측
#
# ### 1. 라이브러리 및 Geometric 설정
#
# - 셰이프 데이터: TL_SCCO_SIG.shp
# - Grid 데이터: si_gun_gu_allocation_v1.csv
#   - 컬럼형태: [Column, Row, **Ratio (0.0 ~ 100.0)**, Region_Code, Region_Name, SIG_ENG_NM]
#
# ### 2. 모델 학습 코드
#
# ### 3. 모델 예측 코드
#
# ### 4. 시-군-구 평균 농도 산출 및 데이터 테이블화
#
# ---

# %% [markdown]
# ### 라이브러리 및 Geometric 설정

# %%
# Import
import os
import sys
sys.path.append('/home/user/workdir/CMAQ_Emulator/main')

# 모델 라이브러리
from src.model.cmaqnet_cond_unet_SIG_v1 import build_model

# 학습 및 처리/분석 관련 라이브러리
import numpy as np
import pandas as pd
import netCDF4 as nc
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# Geometric 및 시각화 라이브러리
import geopandas as gpd
from shapely.geometry import Point
import matplotlib as mpl
import matplotlib.pyplot as plt

# 2D Map 결과 도출을 위한 좌표계 설정
proj = '+proj=lcc +lat_1=30 +lat_2=60 +lon_1=126 +lat_0=38 +lon_0=126 +ellps=GRS80 +units=m'

def get_sigungu_map() -> gpd.GeoDataFrame:
    """시군구 단위의 shapefile을 로드하는 함수"""
    # 시군구 단위 Shapefile 경로
    path = '/home/user/workdir/CMAQ_Emulator/main/resources/geom/TL_SCCO_SIG.shp'
    sigungu_map = gpd.GeoDataFrame.from_file(path, encoding='cp949')
    sigungu_map.crs = 'EPSG:5179'
    return sigungu_map

def get_base_raster() -> gpd.GeoDataFrame:
    """시뮬레이션 영역에 대한 82x67 베이스 격자망을 포인트 형태로 생성하는 함수"""
    points = [Point(i, j)
              for i in range(-180000, -180000 + 9000 * 67, 9000)
              for j in range(-585000, -585000 + 9000 * 82, 9000)]
    grid_data = gpd.GeoDataFrame(points, geometry='geometry', columns=['geometry'])
    grid_data.crs = proj # 좌표계 설정
    grid_data['index'] = grid_data.index
    return grid_data

def create_sigungu_grid_and_mask() -> (pd.DataFrame, np.ndarray):
    """
    시군구 단위의 GRID CSV와 Shapefile을 통합하여
    최종 격자 할당 정보(DataFrame)와 영토 마스크(Numpy Array)를 생성합니다.
    """
    # 1. 시군구 단위 격자 할당 CSV 파일 로드 (우선순위 데이터)
    try:
        # 이전에 변환한 v2 CSV 파일을 사용합니다.
        univ_grid = (
            pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/geom/si_gun_gu_allocation_v1.csv')
            .sort_values(by=['Row', 'Column', 'Ratio'], ascending=[True, True, False])
            .drop_duplicates(subset=['Row', 'Column'], keep='first')
            .reset_index(drop=True)
        )
        univ_grid = univ_grid[['Row', 'Column', 'Region_Name', 'SIG_ENG_NM']].copy()
        print(f"시군구 격자 CSV 로드 완료: {len(univ_grid)}개 격자")
    except FileNotFoundError:
        print("경고: si_gun_gu_allocation_v1.csv 파일을 찾을 수 없습니다.")
        univ_grid = pd.DataFrame(columns=['Row', 'Column', 'Region_Name', 'SIG_ENG_NM'])

    # 2. Shapefile 기반의 격자 정보 생성 (보조 데이터)
    sigungu_map = get_sigungu_map()
    grid_data = get_base_raster()
    sido_code_map = {
        '11': 'Seoul', '26': 'Busan', '27': 'Daegu', '28': 'Incheon',
        '29': 'Gwangju', '30': 'Daejeon', '31': 'Ulsan', '36': 'Sejong',
        '41': 'Gyeonggi', '42': 'Gangwon', '43': 'Chungbuk', '44': 'Chung-Nam',
        '45': 'Jeon-Buk', '46': 'Jeon-Nam', '47': 'Gyeong-Buk', '48': 'Gyeong-Nam',
        '50': 'Jeju'
    }
    joined_gdf = gpd.sjoin(grid_data, sigungu_map.to_crs(grid_data.crs), how='left', predicate='within')
    valid_grids = joined_gdf.dropna(subset=['SIG_CD']).copy()
    valid_grids['Row'] = (valid_grids['index'] % 82) + 1
    valid_grids['Column'] = (valid_grids['index'] // 82) + 1
    valid_grids['Region_Name'] = valid_grids['SIG_CD'].str[:2].map(sido_code_map)
    gov_grid = valid_grids[['Row', 'Column', 'Region_Name', 'SIG_ENG_NM']]
    print(f"Shapefile 기반 격자 생성 완료: {len(gov_grid)}개 격자")

    # 3. 두 데이터 소스를 통합하여 최종 격자 할당 정보(grid_alloc) 생성
    grid_alloc = (
        pd.concat([univ_grid, gov_grid])
        .drop_duplicates(subset=['Row', 'Column'], keep='first')
        .reset_index(drop=True)
    )
    print(f"\n최종 통합 격자 정보 생성 완료: {len(grid_alloc)}개 격자")

    # 4. 영토 마스크(mask) 생성
    # Numpy 인덱싱을 위해 좌표를 1-based에서 0-based로 조정
    grid_alloc_for_mask = grid_alloc.copy()
    grid_alloc_for_mask[['Row', 'Column']] = grid_alloc_for_mask[['Row', 'Column']] - 1
    
    # 행, 열 인덱스 추출
    row_indices = grid_alloc_for_mask['Row'].values
    col_indices = grid_alloc_for_mask['Column'].values
    
    # 82x67 크기의 빈 마스크를 만들고, 영토에 해당하는 부분만 1로 채움
    mask = np.zeros((82, 67))
    mask[row_indices, col_indices] = 1
    print(f"영토 마스크 생성 완료. 마스크 내 활성 격자 수: {int(np.sum(mask))}")
    
    return grid_alloc, mask

# --- 메인 코드 실행 ---
# 시군구 기반의 최종 격자 정보와 영토 마스크를 생성합니다.
grid_alloc, mask = create_sigungu_grid_and_mask()

# 지도 시각화를 위한 설정
sigungu_map = get_sigungu_map()
sigungu_map_proj = sigungu_map.to_crs(proj)
offset_x, offset_y = 4500, 4500

# 생성된 마스크 시각화
fig, ax = plt.subplots(figsize=(7, 6))
cmap_white = mpl.colormaps['jet'].copy()
cmap_white.set_under('white')

im = ax.imshow(mask[::-1], cmap=cmap_white, vmin=0.1, 
               extent=(-180000 + offset_x, 414000 + offset_x, -585000 + offset_y, 144000 + offset_y))
sigungu_map_proj.boundary.plot(ax=ax, edgecolor='black', facecolor='none', linewidth=0.5, alpha=0.3)
ax.set_title("Generated Sigungu-based Land Mask")
ax.set_xlabel("X (m)")
ax.set_ylabel("Y (m)")
plt.grid(alpha=0.2)
plt.show()
# Out:
# 시군구 격자 CSV 로드 완료: 1589개 격자
# Shapefile 기반 격자 생성 완료: 1181개 격자
#
# 최종 통합 격자 정보 생성 완료: 1589개 격자
# 영토 마스크 생성 완료. 마스크 내 활성 격자 수: 1589

# %% [markdown]
# ### 모델 학습 코드

# %%
# 입력 데이터셋 로드
emis_ctrl_2019_05 = pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/ctrl/precursor_control_2019.csv', index_col=0)
# emis_ctrl_2019_05['Timestep'] = 0.0 # 추후에 Boundary/Time Embedding 동시 수행 관점에서 사용
emis_ctrl_2019_05['Boundary'] = 0.5
emis_ctrl_2019_10 = emis_ctrl_2019_05.copy()
emis_ctrl_2019_10['Boundary'] = 1.0

ctrl_data = pd.concat([
    emis_ctrl_2019_05,
    emis_ctrl_2019_10
], axis=0)
ctrl_data = ctrl_data.reset_index(drop=True).values
emis_data, boundary_data = ctrl_data[:, :17*5], ctrl_data[:, 17*5]
# 레이블 데이터 로드
base_path_2019 = '/home/user/workdir/CMAQ_Emulator/main/datasets/concentration/2019'
conc_path = []
for i in range(1, 120): conc_path.append(os.path.join(base_path_2019, '0.50', f'ACONC.{i}'))
for i in range(1, 120): conc_path.append(os.path.join(base_path_2019, '1.00', f'ACONC.{i}'))
conc_data = []
for path in conc_path:
    with nc.Dataset(path) as f:
        conc_data.append(f.variables['PM2_5'][:].data.squeeze())
conc_data = np.array(conc_data).reshape(len(conc_path), 82, 67, 1)

# %%
# 모델 학습 시 저장 경로
model_path = '/home/user/workdir/CMAQ_Emulator/main/src/model/pm25_prediction/PM25_MODEL_SIG_v1.1'

epochs = 500  # 훈련 반복 횟수
batch_size = 32  # 배치 크기
test_split = 0.4  # 테스트 데이터 비율 (20%)
random_seed = 32  # 랜덤 시드

X_emis_train, X_emis_test, X_boundary_train, X_boundary_test, y_train, y_test = train_test_split(emis_data, boundary_data, conc_data, test_size=test_split, random_state=random_seed, stratify=boundary_data)

# Cosine Decay 스케줄 설정
steps_per_epoch = len(X_emis_train) // batch_size 
total_steps = epochs * steps_per_epoch

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("Memory growth enabled for GPUs")
    except RuntimeError as e:
        print(e)

strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=1e-3,
        decay_steps=total_steps,
        alpha=0.1  # 최종 lr 비율 (0이면 최솟값이 0)
    )
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
    model = build_model(
        ctrl_dim=17*5,
        cond_dim=[1],
        emb_dims=[128],
        emb_type=['normal'],
        out_channel=1,
        hidden_size=[128, 96],
        hidden_depth=4,
        in_filters=20,
        kernel_size=3,
        activation='silu',
        dropout=0.0,
        use_abs=True
    )
    model.compile(
        optimizer=optimizer, 
        loss=tf.keras.losses.Huber(delta=1)  # delta는 Huber 손실 전환점
    )

early_stop = EarlyStopping(monitor='val_loss', patience=500, restore_best_weights=True)
history = model.fit(
    x=[X_emis_train, X_boundary_train],
    y=y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=[[X_emis_test, X_boundary_test], y_test],
    callbacks=[early_stop]
)

model.save(model_path)
# Out:
# Memory growth enabled for GPUs
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# WARNING:tensorflow:AutoGraph could not transform <bound method GriddingLayer.call of <src.model.layers_SIG_v1.GriddingLayer object at 0x7f97fc711ba0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: name 'Optional' is not defined
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method GriddingLayer.call of <src.model.layers_SIG_v1.GriddingLayer object at 0x7f97fc711ba0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: name 'Optional' is not defined
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/500
# INFO:tensorflow:Collective all_reduce tensors: 84 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 84 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 5/5 [==============================] - 42s 2s/step - loss: 7.3158 - val_loss: 8.7423
# Epoch 2/500
# 5/5 [==============================] - 1s 152ms/step - loss: 5.4717 - val_loss: 8.0906
# Epoch 3/500
# 5/5 [==============================] - 1s 155ms/step - loss: 5.1457 - val_loss: 6.9847
# Epoch 4/500
# 5/5 [==============================] - 1s 130ms/step - loss: 4.9576 - val_loss: 7.1707
# Epoch 5/500
# 5/5 [==============================] - 1s 145ms/step - loss: 4.7902 - val_loss: 7.0510
# Epoch 6/500
# 5/5 [==============================] - 1s 163ms/step - loss: 4.6284 - val_loss: 6.4839
# Epoch 7/500
# 5/5 [==============================] - 1s 166ms/step - loss: 4.4714 - val_loss: 5.7073
# Epoch 8/500
# 5/5 [==============================] - 1s 179ms/step - loss: 4.3138 - val_loss: 4.5408
# Epoch 9/500
# 5/5 [==============================] - 1s 170ms/step - loss: 4.1326 - val_loss: 4.2712
# Epoch 10/500
# 5/5 [==============================] - 1s 152ms/step - loss: 3.9698 - val_loss: 4.5449
# Epoch 11/500
# 5/5 [==============================] - 1s 160ms/step - loss: 3.8181 - val_loss: 4.5282
# Epoch 12/500
# 5/5 [==============================] - 1s 167ms/step - loss: 3.6519 - val_loss: 4.0853
# Epoch 13/500
# 5/5 [==============================] - 1s 154ms/step - loss: 3.4937 - val_loss: 4.4280
# Epoch 14/500
# 5/5 [==============================] - 1s 164ms/step - loss: 3.3419 - val_loss: 4.7282
# Epoch 15/500
# 5/5 [==============================] - 1s 160ms/step - loss: 3.1743 - val_loss: 4.0127
# Epoch 16/500
# 5/5 [==============================] - 1s 148ms/step - loss: 3.0129 - val_loss: 4.8839
# Epoch 17/500
# 5/5 [==============================] - 1s 223ms/step - loss: 2.8580 - val_loss: 4.6251
# Epoch 18/500
# 5/5 [==============================] - 1s 245ms/step - loss: 2.6642 - val_loss: 4.0023
# Epoch 19/500
# 5/5 [==============================] - 1s 162ms/step - loss: 2.5053 - val_loss: 4.3344
# Epoch 20/500
# 5/5 [==============================] - 1s 144ms/step - loss: 2.3052 - val_loss: 4.2384
# Epoch 21/500
# 5/5 [==============================] - 1s 175ms/step - loss: 2.1609 - val_loss: 3.8433
# Epoch 22/500
# 5/5 [==============================] - 1s 157ms/step - loss: 1.9716 - val_loss: 4.2436
# Epoch 23/500
# 5/5 [==============================] - 1s 156ms/step - loss: 1.8854 - val_loss: 4.2629
# Epoch 24/500
# 5/5 [==============================] - 1s 175ms/step - loss: 1.8197 - val_loss: 3.7126
# Epoch 25/500
# 5/5 [==============================] - 1s 188ms/step - loss: 1.6234 - val_loss: 3.2800
# Epoch 26/500
# 5/5 [==============================] - 1s 166ms/step - loss: 1.4997 - val_loss: 3.7671
# Epoch 27/500
# 5/5 [==============================] - 1s 166ms/step - loss: 1.3204 - val_loss: 3.0544
# Epoch 28/500
# 5/5 [==============================] - 1s 162ms/step - loss: 1.2414 - val_loss: 2.7737
# Epoch 29/500
# 5/5 [==============================] - 1s 158ms/step - loss: 1.1763 - val_loss: 3.1387
# Epoch 30/500
# 5/5 [==============================] - 1s 148ms/step - loss: 0.9901 - val_loss: 2.9310
# Epoch 31/500
# 5/5 [==============================] - 1s 152ms/step - loss: 0.8910 - val_loss: 3.1071
# Epoch 32/500
# 5/5 [==============================] - 1s 153ms/step - loss: 0.7642 - val_loss: 3.3158
# Epoch 33/500
# 5/5 [==============================] - 1s 150ms/step - loss: 0.8330 - val_loss: 3.1205
# Epoch 34/500
# 5/5 [==============================] - 1s 144ms/step - loss: 0.6303 - val_loss: 3.1425
# Epoch 35/500
# 5/5 [==============================] - 1s 162ms/step - loss: 0.7884 - val_loss: 3.3395
# Epoch 36/500
# 5/5 [==============================] - 1s 158ms/step - loss: 0.6559 - val_loss: 3.5731
# Epoch 37/500
# 5/5 [==============================] - 1s 161ms/step - loss: 0.5784 - val_loss: 3.0169
# Epoch 38/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.5284 - val_loss: 2.7713
# Epoch 39/500
# 5/5 [==============================] - 1s 166ms/step - loss: 0.4383 - val_loss: 2.7925
# Epoch 40/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.4040 - val_loss: 2.6174
# Epoch 41/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.3508 - val_loss: 2.5481
# Epoch 42/500
# 5/5 [==============================] - 1s 155ms/step - loss: 0.4016 - val_loss: 3.0163
# Epoch 43/500
# 5/5 [==============================] - 1s 159ms/step - loss: 0.3535 - val_loss: 2.6767
# Epoch 44/500
# 5/5 [==============================] - 1s 162ms/step - loss: 0.3196 - val_loss: 2.6022
# Epoch 45/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.5479 - val_loss: 2.3488
# Epoch 46/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.4771 - val_loss: 2.2883
# Epoch 47/500
# 5/5 [==============================] - 1s 152ms/step - loss: 0.2442 - val_loss: 2.5461
# Epoch 48/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.1669 - val_loss: 2.1430
# Epoch 49/500
# 5/5 [==============================] - 1s 158ms/step - loss: 0.2252 - val_loss: 2.1654
# Epoch 50/500
# 5/5 [==============================] - 1s 147ms/step - loss: 0.2131 - val_loss: 2.2102
# Epoch 51/500
# 5/5 [==============================] - 1s 155ms/step - loss: 0.2559 - val_loss: 2.5415
# Epoch 52/500
# 5/5 [==============================] - 1s 149ms/step - loss: 0.2344 - val_loss: 2.6990
# Epoch 53/500
# 5/5 [==============================] - 1s 162ms/step - loss: 0.1260 - val_loss: 2.6755
# Epoch 54/500
# 5/5 [==============================] - 1s 150ms/step - loss: 0.1573 - val_loss: 2.3339
# Epoch 55/500
# 5/5 [==============================] - 1s 169ms/step - loss: 0.2353 - val_loss: 3.3059
# Epoch 56/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.3973 - val_loss: 1.4393
# Epoch 57/500
# 5/5 [==============================] - 1s 161ms/step - loss: 0.1792 - val_loss: 0.8410
# Epoch 58/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.1299 - val_loss: 0.5339
# Epoch 59/500
# 5/5 [==============================] - 1s 164ms/step - loss: 0.2246 - val_loss: 0.6092
# Epoch 60/500
# 5/5 [==============================] - 1s 202ms/step - loss: 0.2949 - val_loss: 0.3519
# Epoch 61/500
# 5/5 [==============================] - 1s 149ms/step - loss: 0.1542 - val_loss: 0.7924
# Epoch 62/500
# 5/5 [==============================] - 1s 170ms/step - loss: 0.1159 - val_loss: 0.9326
# Epoch 63/500
# 5/5 [==============================] - 1s 163ms/step - loss: 0.1476 - val_loss: 0.7307
# Epoch 64/500
# 5/5 [==============================] - 1s 150ms/step - loss: 0.2851 - val_loss: 1.0573
# Epoch 65/500
# 5/5 [==============================] - 1s 167ms/step - loss: 0.3868 - val_loss: 0.6674
# Epoch 66/500
# 5/5 [==============================] - 1s 159ms/step - loss: 0.2278 - val_loss: 1.7421
# Epoch 67/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1977 - val_loss: 0.7412
# Epoch 68/500
# 5/5 [==============================] - 1s 165ms/step - loss: 0.1595 - val_loss: 1.4416
# Epoch 69/500
# 5/5 [==============================] - 1s 165ms/step - loss: 0.2261 - val_loss: 1.1096
# Epoch 70/500
# 5/5 [==============================] - 1s 194ms/step - loss: 0.1300 - val_loss: 0.5593
# Epoch 71/500
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1325 - val_loss: 1.0390
# Epoch 72/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1616 - val_loss: 2.2451
# Epoch 73/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.1066 - val_loss: 2.4120
# Epoch 74/500
# 5/5 [==============================] - 1s 200ms/step - loss: 0.1036 - val_loss: 1.8636
# Epoch 75/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0980 - val_loss: 1.3709
# Epoch 76/500
# 5/5 [==============================] - 1s 158ms/step - loss: 0.1455 - val_loss: 0.8951
# Epoch 77/500
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0754 - val_loss: 0.5715
# Epoch 78/500
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0678 - val_loss: 0.6191
# Epoch 79/500
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0407 - val_loss: 0.6040
# Epoch 80/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0858 - val_loss: 0.3237
# Epoch 81/500
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0848 - val_loss: 0.2489
# Epoch 82/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1508 - val_loss: 0.3022
# Epoch 83/500
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0682 - val_loss: 0.3590
# Epoch 84/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.2594 - val_loss: 0.8445
# Epoch 85/500
# 5/5 [==============================] - 1s 232ms/step - loss: 0.1420 - val_loss: 0.1583
# Epoch 86/500
# 5/5 [==============================] - 1s 167ms/step - loss: 0.2732 - val_loss: 1.5868
# Epoch 87/500
# 5/5 [==============================] - 1s 153ms/step - loss: 0.1554 - val_loss: 4.2329
# Epoch 88/500
# 5/5 [==============================] - 1s 147ms/step - loss: 0.1523 - val_loss: 4.3044
# Epoch 89/500
# 5/5 [==============================] - 1s 164ms/step - loss: 0.2528 - val_loss: 3.9633
# Epoch 90/500
# 5/5 [==============================] - 1s 154ms/step - loss: 0.1236 - val_loss: 4.0627
# Epoch 91/500
# 5/5 [==============================] - 1s 147ms/step - loss: 0.1341 - val_loss: 3.8618
# Epoch 92/500
# 5/5 [==============================] - 1s 160ms/step - loss: 0.0754 - val_loss: 4.0602
# Epoch 93/500
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0530 - val_loss: 3.6968
# Epoch 94/500
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0703 - val_loss: 3.6293
# Epoch 95/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0411 - val_loss: 3.0955
# Epoch 96/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0558 - val_loss: 2.2303
# Epoch 97/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.1122 - val_loss: 1.8162
# Epoch 98/500
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0645 - val_loss: 2.3424
# Epoch 99/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0480 - val_loss: 1.9024
# Epoch 100/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0484 - val_loss: 1.4274
# Epoch 101/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0320 - val_loss: 1.0877
# Epoch 102/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.1471 - val_loss: 0.9657
# Epoch 103/500
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0810 - val_loss: 0.8379
# Epoch 104/500
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0478 - val_loss: 0.9198
# Epoch 105/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1901 - val_loss: 0.6749
# Epoch 106/500
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0523 - val_loss: 0.6605
# Epoch 107/500
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0428 - val_loss: 0.6837
# Epoch 108/500
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0453 - val_loss: 0.4497
# Epoch 109/500
# 5/5 [==============================] - 1s 195ms/step - loss: 0.2528 - val_loss: 0.2997
# Epoch 110/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0407 - val_loss: 0.3126
# Epoch 111/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0560 - val_loss: 0.3632
# Epoch 112/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0876 - val_loss: 0.3877
# Epoch 113/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0458 - val_loss: 0.3016
# Epoch 114/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.1387 - val_loss: 0.2633
# Epoch 115/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0822 - val_loss: 0.1952
# Epoch 116/500
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0319 - val_loss: 0.1169
# Epoch 117/500
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0446 - val_loss: 0.0865
# Epoch 118/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0434 - val_loss: 0.2169
# Epoch 119/500
# 5/5 [==============================] - 1s 222ms/step - loss: 0.2484 - val_loss: 0.2702
# Epoch 120/500
# 5/5 [==============================] - 1s 211ms/step - loss: 0.2367 - val_loss: 0.2425
# Epoch 121/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0539 - val_loss: 0.1487
# Epoch 122/500
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0904 - val_loss: 0.1677
# Epoch 123/500
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0738 - val_loss: 0.0878
# Epoch 124/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0643 - val_loss: 0.1802
# Epoch 125/500
# 5/5 [==============================] - 1s 214ms/step - loss: 0.2033 - val_loss: 0.0854
# Epoch 126/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0669 - val_loss: 0.2445
# Epoch 127/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0524 - val_loss: 1.2921
# Epoch 128/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0451 - val_loss: 1.4416
# Epoch 129/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.3437 - val_loss: 0.1443
# Epoch 130/500
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1772 - val_loss: 0.9734
# Epoch 131/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.1778 - val_loss: 1.5525
# Epoch 132/500
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0878 - val_loss: 1.1866
# Epoch 133/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3018 - val_loss: 0.8258
# Epoch 134/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.1189 - val_loss: 0.6517
# Epoch 135/500
# 5/5 [==============================] - 1s 207ms/step - loss: 0.1068 - val_loss: 0.3558
# Epoch 136/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.1146 - val_loss: 0.2798
# Epoch 137/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0906 - val_loss: 0.2175
# Epoch 138/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0941 - val_loss: 0.2065
# Epoch 139/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.1153 - val_loss: 0.1557
# Epoch 140/500
# 5/5 [==============================] - 1s 166ms/step - loss: 0.1021 - val_loss: 0.0979
# Epoch 141/500
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0791 - val_loss: 0.1336
# Epoch 142/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0912 - val_loss: 0.1690
# Epoch 143/500
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0532 - val_loss: 0.1175
# Epoch 144/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.1037 - val_loss: 0.2264
# Epoch 145/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0707 - val_loss: 0.1934
# Epoch 146/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0919 - val_loss: 0.4257
# Epoch 147/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0874 - val_loss: 0.4042
# Epoch 148/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0831 - val_loss: 0.2471
# Epoch 149/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.2163 - val_loss: 0.7686
# Epoch 150/500
# 5/5 [==============================] - 1s 197ms/step - loss: 0.1224 - val_loss: 0.6819
# Epoch 151/500
# 5/5 [==============================] - 1s 194ms/step - loss: 0.1032 - val_loss: 0.4768
# Epoch 152/500
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1137 - val_loss: 0.3773
# Epoch 153/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3863 - val_loss: 1.6413
# Epoch 154/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.2155 - val_loss: 1.5227
# Epoch 155/500
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0750 - val_loss: 1.1393
# Epoch 156/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0900 - val_loss: 0.2724
# Epoch 157/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0880 - val_loss: 0.2828
# Epoch 158/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0950 - val_loss: 0.4515
# Epoch 159/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1591 - val_loss: 0.1693
# Epoch 160/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0650 - val_loss: 0.3034
# Epoch 161/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0659 - val_loss: 0.6288
# Epoch 162/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0578 - val_loss: 0.7837
# Epoch 163/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1338 - val_loss: 0.6968
# Epoch 164/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0460 - val_loss: 0.6165
# Epoch 165/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0424 - val_loss: 0.4389
# Epoch 166/500
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0269 - val_loss: 0.3893
# Epoch 167/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0431 - val_loss: 0.3431
# Epoch 168/500
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0280 - val_loss: 0.2656
# Epoch 169/500
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0311 - val_loss: 0.2516
# Epoch 170/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0825 - val_loss: 0.2276
# Epoch 171/500
# 5/5 [==============================] - 1s 198ms/step - loss: 0.1023 - val_loss: 0.5755
# Epoch 172/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0873 - val_loss: 0.9256
# Epoch 173/500
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0658 - val_loss: 2.2508
# Epoch 174/500
# 5/5 [==============================] - 1s 171ms/step - loss: 0.2724 - val_loss: 3.1144
# Epoch 175/500
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0509 - val_loss: 2.8373
# Epoch 176/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.1242 - val_loss: 2.3565
# Epoch 177/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0960 - val_loss: 1.7971
# Epoch 178/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0601 - val_loss: 1.2266
# Epoch 179/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0633 - val_loss: 1.0176
# Epoch 180/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0628 - val_loss: 0.8297
# Epoch 181/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0474 - val_loss: 0.6660
# Epoch 182/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0382 - val_loss: 0.6691
# Epoch 183/500
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0280 - val_loss: 0.7104
# Epoch 184/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0266 - val_loss: 0.5830
# Epoch 185/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0197 - val_loss: 0.4886
# Epoch 186/500
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0224 - val_loss: 0.4899
# Epoch 187/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0232 - val_loss: 0.4575
# Epoch 188/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0182 - val_loss: 0.4685
# Epoch 189/500
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0205 - val_loss: 0.4855
# Epoch 190/500
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0198 - val_loss: 0.3988
# Epoch 191/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0169 - val_loss: 0.3314
# Epoch 192/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0557 - val_loss: 0.2043
# Epoch 193/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0359 - val_loss: 0.2209
# Epoch 194/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0313 - val_loss: 0.2587
# Epoch 195/500
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0430 - val_loss: 0.1531
# Epoch 196/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0336 - val_loss: 0.1434
# Epoch 197/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0560 - val_loss: 0.1421
# Epoch 198/500
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0532 - val_loss: 0.2537
# Epoch 199/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0517 - val_loss: 0.5635
# Epoch 200/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0645 - val_loss: 0.2714
# Epoch 201/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0478 - val_loss: 0.1828
# Epoch 202/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0270 - val_loss: 0.1213
# Epoch 203/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0258 - val_loss: 0.0903
# Epoch 204/500
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0318 - val_loss: 0.0914
# Epoch 205/500
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0331 - val_loss: 0.0809
# Epoch 206/500
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0249 - val_loss: 0.0674
# Epoch 207/500
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0299 - val_loss: 0.0637
# Epoch 208/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0295 - val_loss: 0.0842
# Epoch 209/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0192 - val_loss: 0.0750
# Epoch 210/500
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0200 - val_loss: 0.0791
# Epoch 211/500
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0192 - val_loss: 0.0541
# Epoch 212/500
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0171 - val_loss: 0.0380
# Epoch 213/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0193 - val_loss: 0.0651
# Epoch 214/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0213 - val_loss: 0.0573
# Epoch 215/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0181 - val_loss: 0.0579
# Epoch 216/500
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0197 - val_loss: 0.0457
# Epoch 217/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0183 - val_loss: 0.0665
# Epoch 218/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0170 - val_loss: 0.0788
# Epoch 219/500
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0205 - val_loss: 0.1007
# Epoch 220/500
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0195 - val_loss: 0.1084
# Epoch 221/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0205 - val_loss: 0.0427
# Epoch 222/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0189 - val_loss: 0.0438
# Epoch 223/500
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0219 - val_loss: 0.0363
# Epoch 224/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0180 - val_loss: 0.0661
# Epoch 225/500
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0172 - val_loss: 0.0725
# Epoch 226/500
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0169 - val_loss: 0.0417
# Epoch 227/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0157 - val_loss: 0.0341
# Epoch 228/500
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0153 - val_loss: 0.0262
# Epoch 229/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0140 - val_loss: 0.0471
# Epoch 230/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0185 - val_loss: 0.0462
# Epoch 231/500
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0194 - val_loss: 0.0449
# Epoch 232/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0222 - val_loss: 0.0368
# Epoch 233/500
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0229 - val_loss: 0.0269
# Epoch 234/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0168 - val_loss: 0.0300
# Epoch 235/500
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0161 - val_loss: 0.0350
# Epoch 236/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0187 - val_loss: 0.0262
# Epoch 237/500
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0212 - val_loss: 0.0302
# Epoch 238/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0175 - val_loss: 0.0722
# Epoch 239/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0179 - val_loss: 0.0286
# Epoch 240/500
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0166 - val_loss: 0.0228
# Epoch 241/500
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0151 - val_loss: 0.0256
# Epoch 242/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0141 - val_loss: 0.0263
# Epoch 243/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0129 - val_loss: 0.0270
# Epoch 244/500
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0137 - val_loss: 0.0196
# Epoch 245/500
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0153 - val_loss: 0.0207
# Epoch 246/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0117 - val_loss: 0.0243
# Epoch 247/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0123 - val_loss: 0.0290
# Epoch 248/500
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0127 - val_loss: 0.0275
# Epoch 249/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0132 - val_loss: 0.0391
# Epoch 250/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0157 - val_loss: 0.0237
# Epoch 251/500
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0130 - val_loss: 0.0248
# Epoch 252/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0156 - val_loss: 0.0212
# Epoch 253/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0135 - val_loss: 0.0361
# Epoch 254/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0141 - val_loss: 0.0237
# Epoch 255/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0142 - val_loss: 0.0216
# Epoch 256/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0129 - val_loss: 0.0264
# Epoch 257/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0111 - val_loss: 0.0356
# Epoch 258/500
# 5/5 [==============================] - 1s 160ms/step - loss: 0.0143 - val_loss: 0.0424
# Epoch 259/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0114 - val_loss: 0.0261
# Epoch 260/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0137 - val_loss: 0.0216
# Epoch 261/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0136 - val_loss: 0.0273
# Epoch 262/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0121 - val_loss: 0.0297
# Epoch 263/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0131 - val_loss: 0.0276
# Epoch 264/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0148 - val_loss: 0.0306
# Epoch 265/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0104 - val_loss: 0.0256
# Epoch 266/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0120 - val_loss: 0.0376
# Epoch 267/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0123 - val_loss: 0.0258
# Epoch 268/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0130 - val_loss: 0.0232
# Epoch 269/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0127 - val_loss: 0.0346
# Epoch 270/500
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0109 - val_loss: 0.0394
# Epoch 271/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0105 - val_loss: 0.0269
# Epoch 272/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0124 - val_loss: 0.0366
# Epoch 273/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0109 - val_loss: 0.0372
# Epoch 274/500
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0157 - val_loss: 0.0784
# Epoch 275/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0142 - val_loss: 0.0448
# Epoch 276/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0117 - val_loss: 0.0305
# Epoch 277/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0125 - val_loss: 0.0312
# Epoch 278/500
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0119 - val_loss: 0.0231
# Epoch 279/500
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0115 - val_loss: 0.0206
# Epoch 280/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0146 - val_loss: 0.0234
# Epoch 281/500
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0121 - val_loss: 0.0167
# Epoch 282/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0126 - val_loss: 0.0255
# Epoch 283/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0096 - val_loss: 0.0258
# Epoch 284/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0100 - val_loss: 0.0207
# Epoch 285/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0121 - val_loss: 0.0317
# Epoch 286/500
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0111 - val_loss: 0.0217
# Epoch 287/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0108 - val_loss: 0.0227
# Epoch 288/500
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0131 - val_loss: 0.0324
# Epoch 289/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0099 - val_loss: 0.0238
# Epoch 290/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0119 - val_loss: 0.0384
# Epoch 291/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0127 - val_loss: 0.0183
# Epoch 292/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0102 - val_loss: 0.0257
# Epoch 293/500
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0113 - val_loss: 0.0249
# Epoch 294/500
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0114 - val_loss: 0.0145
# Epoch 295/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0117 - val_loss: 0.0265
# Epoch 296/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0128 - val_loss: 0.0154
# Epoch 297/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0117 - val_loss: 0.0219
# Epoch 298/500
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0117 - val_loss: 0.0192
# Epoch 299/500
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0101 - val_loss: 0.0365
# Epoch 300/500
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0095 - val_loss: 0.0355
# Epoch 301/500
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0118 - val_loss: 0.0265
# Epoch 302/500
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0105 - val_loss: 0.0285
# Epoch 303/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0094 - val_loss: 0.0202
# Epoch 304/500
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0096 - val_loss: 0.0199
# Epoch 305/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0137 - val_loss: 0.0165
# Epoch 306/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0116 - val_loss: 0.0364
# Epoch 307/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0112 - val_loss: 0.0182
# Epoch 308/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0105 - val_loss: 0.0296
# Epoch 309/500
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0115 - val_loss: 0.0144
# Epoch 310/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0105 - val_loss: 0.0164
# Epoch 311/500
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0123 - val_loss: 0.0135
# Epoch 312/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0095 - val_loss: 0.0169
# Epoch 313/500
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0102 - val_loss: 0.0147
# Epoch 314/500
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0110 - val_loss: 0.0129
# Epoch 315/500
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0121 - val_loss: 0.0197
# Epoch 316/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0116 - val_loss: 0.0148
# Epoch 317/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0115 - val_loss: 0.0182
# Epoch 318/500
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0109 - val_loss: 0.0135
# Epoch 319/500
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0111 - val_loss: 0.0157
# Epoch 320/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0129 - val_loss: 0.0221
# Epoch 321/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0110 - val_loss: 0.0202
# Epoch 322/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0113 - val_loss: 0.0268
# Epoch 323/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0097 - val_loss: 0.0171
# Epoch 324/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0118 - val_loss: 0.0255
# Epoch 325/500
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0118 - val_loss: 0.0160
# Epoch 326/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0099 - val_loss: 0.0267
# Epoch 327/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0098 - val_loss: 0.0220
# Epoch 328/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0111 - val_loss: 0.0269
# Epoch 329/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0086 - val_loss: 0.0196
# Epoch 330/500
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0102 - val_loss: 0.0262
# Epoch 331/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0115 - val_loss: 0.0202
# Epoch 332/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0098 - val_loss: 0.0183
# Epoch 333/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0096 - val_loss: 0.0218
# Epoch 334/500
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0099 - val_loss: 0.0145
# Epoch 335/500
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0119 - val_loss: 0.0184
# Epoch 336/500
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0116 - val_loss: 0.0129
# Epoch 337/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0096 - val_loss: 0.0154
# Epoch 338/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0112 - val_loss: 0.0178
# Epoch 339/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0095 - val_loss: 0.0183
# Epoch 340/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0093 - val_loss: 0.0165
# Epoch 341/500
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0100 - val_loss: 0.0199
# Epoch 342/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0097 - val_loss: 0.0171
# Epoch 343/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0078 - val_loss: 0.0129
# Epoch 344/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0101 - val_loss: 0.0129
# Epoch 345/500
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 346/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0105 - val_loss: 0.0146
# Epoch 347/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0095 - val_loss: 0.0272
# Epoch 348/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0107 - val_loss: 0.0280
# Epoch 349/500
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0083 - val_loss: 0.0281
# Epoch 350/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0094 - val_loss: 0.0241
# Epoch 351/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0090 - val_loss: 0.0310
# Epoch 352/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0089 - val_loss: 0.0214
# Epoch 353/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0112 - val_loss: 0.0188
# Epoch 354/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0086 - val_loss: 0.0136
# Epoch 355/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0106 - val_loss: 0.0168
# Epoch 356/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0096 - val_loss: 0.0123
# Epoch 357/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0088 - val_loss: 0.0126
# Epoch 358/500
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0085 - val_loss: 0.0117
# Epoch 359/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0101 - val_loss: 0.0113
# Epoch 360/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0087 - val_loss: 0.0140
# Epoch 361/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0078 - val_loss: 0.0136
# Epoch 362/500
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0090 - val_loss: 0.0142
# Epoch 363/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0092 - val_loss: 0.0129
# Epoch 364/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0100 - val_loss: 0.0128
# Epoch 365/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0104 - val_loss: 0.0139
# Epoch 366/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0092 - val_loss: 0.0116
# Epoch 367/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0090 - val_loss: 0.0148
# Epoch 368/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0095 - val_loss: 0.0131
# Epoch 369/500
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0101 - val_loss: 0.0128
# Epoch 370/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0109 - val_loss: 0.0133
# Epoch 371/500
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0093 - val_loss: 0.0130
# Epoch 372/500
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0099 - val_loss: 0.0129
# Epoch 373/500
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0100 - val_loss: 0.0102
# Epoch 374/500
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0093 - val_loss: 0.0103
# Epoch 375/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0093 - val_loss: 0.0102
# Epoch 376/500
# 5/5 [==============================] - 1s 231ms/step - loss: 0.0092 - val_loss: 0.0093
# Epoch 377/500
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0092 - val_loss: 0.0102
# Epoch 378/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0094 - val_loss: 0.0106
# Epoch 379/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0096 - val_loss: 0.0097
# Epoch 380/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0108 - val_loss: 0.0131
# Epoch 381/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0085 - val_loss: 0.0110
# Epoch 382/500
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0092 - val_loss: 0.0126
# Epoch 383/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0089 - val_loss: 0.0137
# Epoch 384/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0106 - val_loss: 0.0128
# Epoch 385/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0083 - val_loss: 0.0184
# Epoch 386/500
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0090 - val_loss: 0.0142
# Epoch 387/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0092 - val_loss: 0.0176
# Epoch 388/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0096 - val_loss: 0.0163
# Epoch 389/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0084 - val_loss: 0.0166
# Epoch 390/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0086 - val_loss: 0.0182
# Epoch 391/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0092 - val_loss: 0.0158
# Epoch 392/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0101 - val_loss: 0.0173
# Epoch 393/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0089 - val_loss: 0.0151
# Epoch 394/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0103 - val_loss: 0.0193
# Epoch 395/500
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0117 - val_loss: 0.0161
# Epoch 396/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0089 - val_loss: 0.0167
# Epoch 397/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0104 - val_loss: 0.0155
# Epoch 398/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0091 - val_loss: 0.0168
# Epoch 399/500
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0090 - val_loss: 0.0140
# Epoch 400/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0091 - val_loss: 0.0158
# Epoch 401/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0115 - val_loss: 0.0166
# Epoch 402/500
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0102 - val_loss: 0.0169
# Epoch 403/500
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0111 - val_loss: 0.0165
# Epoch 404/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0087 - val_loss: 0.0157
# Epoch 405/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0092 - val_loss: 0.0132
# Epoch 406/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0107 - val_loss: 0.0136
# Epoch 407/500
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0092 - val_loss: 0.0167
# Epoch 408/500
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0097 - val_loss: 0.0146
# Epoch 409/500
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0099 - val_loss: 0.0131
# Epoch 410/500
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0086 - val_loss: 0.0143
# Epoch 411/500
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0098 - val_loss: 0.0138
# Epoch 412/500
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0112 - val_loss: 0.0197
# Epoch 413/500
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0089 - val_loss: 0.0149
# Epoch 414/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0087 - val_loss: 0.0146
# Epoch 415/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0086 - val_loss: 0.0156
# Epoch 416/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0115 - val_loss: 0.0177
# Epoch 417/500
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0109 - val_loss: 0.0152
# Epoch 418/500
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0089 - val_loss: 0.0145
# Epoch 419/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0104 - val_loss: 0.0149
# Epoch 420/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0084 - val_loss: 0.0150
# Epoch 421/500
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0085 - val_loss: 0.0137
# Epoch 422/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0081 - val_loss: 0.0147
# Epoch 423/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0089 - val_loss: 0.0155
# Epoch 424/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0090 - val_loss: 0.0131
# Epoch 425/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0102 - val_loss: 0.0143
# Epoch 426/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0090 - val_loss: 0.0181
# Epoch 427/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0080 - val_loss: 0.0149
# Epoch 428/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0092 - val_loss: 0.0169
# Epoch 429/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0082 - val_loss: 0.0165
# Epoch 430/500
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0086 - val_loss: 0.0183
# Epoch 431/500
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0097 - val_loss: 0.0199
# Epoch 432/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0083 - val_loss: 0.0158
# Epoch 433/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0103 - val_loss: 0.0178
# Epoch 434/500
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0096 - val_loss: 0.0184
# Epoch 435/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0092 - val_loss: 0.0141
# Epoch 436/500
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0077 - val_loss: 0.0123
# Epoch 437/500
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0093 - val_loss: 0.0130
# Epoch 438/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0082 - val_loss: 0.0178
# Epoch 439/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0103 - val_loss: 0.0149
# Epoch 440/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0091 - val_loss: 0.0126
# Epoch 441/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0076 - val_loss: 0.0114
# Epoch 442/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0091 - val_loss: 0.0128
# Epoch 443/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0095 - val_loss: 0.0121
# Epoch 444/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0079 - val_loss: 0.0136
# Epoch 445/500
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0087 - val_loss: 0.0146
# Epoch 446/500
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0086 - val_loss: 0.0189
# Epoch 447/500
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0108 - val_loss: 0.0160
# Epoch 448/500
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0086 - val_loss: 0.0158
# Epoch 449/500
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0099 - val_loss: 0.0143
# Epoch 450/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0075 - val_loss: 0.0165
# Epoch 451/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0096 - val_loss: 0.0182
# Epoch 452/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0098 - val_loss: 0.0194
# Epoch 453/500
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0089 - val_loss: 0.0204
# Epoch 454/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0108 - val_loss: 0.0203
# Epoch 455/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0084 - val_loss: 0.0204
# Epoch 456/500
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0085 - val_loss: 0.0171
# Epoch 457/500
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0085 - val_loss: 0.0244
# Epoch 458/500
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0081 - val_loss: 0.0277
# Epoch 459/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0091 - val_loss: 0.0323
# Epoch 460/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0097 - val_loss: 0.0241
# Epoch 461/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0101 - val_loss: 0.0264
# Epoch 462/500
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0105 - val_loss: 0.0179
# Epoch 463/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0086 - val_loss: 0.0155
# Epoch 464/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0086 - val_loss: 0.0184
# Epoch 465/500
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0100 - val_loss: 0.0117
# Epoch 466/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0082 - val_loss: 0.0126
# Epoch 467/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0112 - val_loss: 0.0135
# Epoch 468/500
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0085 - val_loss: 0.0135
# Epoch 469/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0104 - val_loss: 0.0116
# Epoch 470/500
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0116 - val_loss: 0.0148
# Epoch 471/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0113 - val_loss: 0.0132
# Epoch 472/500
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0100 - val_loss: 0.0142
# Epoch 473/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0096 - val_loss: 0.0130
# Epoch 474/500
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0078 - val_loss: 0.0134
# Epoch 475/500
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0082 - val_loss: 0.0140
# Epoch 476/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0085 - val_loss: 0.0111
# Epoch 477/500
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0098 - val_loss: 0.0154
# Epoch 478/500
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0084 - val_loss: 0.0162
# Epoch 479/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0091 - val_loss: 0.0191
# Epoch 480/500
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0096 - val_loss: 0.0123
# Epoch 481/500
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0094 - val_loss: 0.0162
# Epoch 482/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0092 - val_loss: 0.0112
# Epoch 483/500
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0089 - val_loss: 0.0141
# Epoch 484/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 485/500
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0091 - val_loss: 0.0116
# Epoch 486/500
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0098 - val_loss: 0.0104
# Epoch 487/500
# 5/5 [==============================] - 2s 400ms/step - loss: 0.0084 - val_loss: 0.0127
# Epoch 488/500
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0087 - val_loss: 0.0120
# Epoch 489/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0081 - val_loss: 0.0158
# Epoch 490/500
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0073 - val_loss: 0.0150
# Epoch 491/500
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0081 - val_loss: 0.0122
# Epoch 492/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0097 - val_loss: 0.0149
# Epoch 493/500
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0096 - val_loss: 0.0107
# Epoch 494/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0081 - val_loss: 0.0106
# Epoch 495/500
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0088 - val_loss: 0.0099
# Epoch 496/500
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0084 - val_loss: 0.0097
# Epoch 497/500
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0089 - val_loss: 0.0104
# Epoch 498/500
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0078 - val_loss: 0.0113
# Epoch 499/500
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0086 - val_loss: 0.0114
# Epoch 500/500
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0086 - val_loss: 0.0128
# INFO:tensorflow:Assets written to: /home/user/workdir/CMAQ_Emulator/main/src/model/pm25_prediction/PM25_MODEL_SIG_v1.1/assets
# INFO:tensorflow:Assets written to: /home/user/workdir/CMAQ_Emulator/main/src/model/pm25_prediction/PM25_MODEL_SIG_v1.1/assets

# %%
def plot_loss(history):
    epochs = range(1, len(history.history['loss']) + 1)
    
    plt.figure(figsize=(15, 10))
    
    # 1. 전체 에포크에 대한 학습 및 검증 손실
    plt.subplot(2, 2, 1)
    plt.plot(epochs, history.history['loss'], label='Training Loss', color='blue')
    plt.plot(epochs, history.history['val_loss'], label='Validation Loss', color='orange')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss over Epochs')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 2. 마지막 10 에포크의 손실 (세부 분석)
    plt.subplot(2, 2, 2)
    if len(epochs) >= 30:
        last_epochs = epochs[-30:]
        plt.plot(last_epochs, history.history['loss'][-30:], label='Training Loss', color='blue')
        plt.plot(last_epochs, history.history['val_loss'][-30:], label='Validation Loss', color='orange')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Loss (Last 10 Epochs)')
        plt.legend()
        plt.grid(alpha=0.3)
    else:
        plt.text(0.5, 0.5, "Not enough epochs for zoomed plot", ha='center')
    
    # 3. 학습 손실과 검증 손실의 차이
    plt.subplot(2, 2, 3)
    loss_diff = np.array(history.history['val_loss']) - np.array(history.history['loss'])
    plt.plot(epochs, loss_diff, label='Val Loss - Train Loss', color='green')
    plt.xlabel('Epochs')
    plt.ylabel('Loss Difference')
    plt.title('Difference between Validation and Training Loss')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 4. 이동 평균 (window=10)을 통한 평활화된 손실 추세
    plt.subplot(2, 2, 4)
    window = 10
    if len(epochs) >= window:
        train_ma = [np.mean(history.history['loss'][max(0, i-window):i]) for i in range(1, len(history.history['loss'])+1)]
        val_ma = [np.mean(history.history['val_loss'][max(0, i-window):i]) for i in range(1, len(history.history['val_loss'])+1)]
        plt.plot(epochs, train_ma, label='Training Loss MA', color='blue', linestyle='--')
        plt.plot(epochs, val_ma, label='Validation Loss MA', color='orange', linestyle='--')
        plt.xlabel('Epochs')
        plt.ylabel('Loss (Moving Average)')
        plt.title('Moving Average of Loss (window = 10)')
        plt.legend()
        plt.grid(alpha=0.3)
    else:
        plt.text(0.5, 0.5, "Not enough epochs for moving average plot", ha='center')
    
    plt.tight_layout()
    plt.show()

# Loss 결과물 출력
plot_loss(history)

# %% [markdown]
# ### 모델 예측 코드

# %%
test_split = 0.2  # 테스트 데이터 스플릿 비율 (20%)
random_seed = 42  # 랜덤 시드

# GPU를 이용한 추론 작업 셋팅
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("Memory growth enabled for GPUs")
    except RuntimeError as e:
        print(e)
strategy = tf.distribute.MirroredStrategy()

# 0. 학습된 Local AQM 모델 로드
with strategy.scope():
    model = tf.keras.models.load_model('/home/user/workdir/CMAQ_Emulator/main/src/model/pm25_prediction/PM25_MODEL_SIG_v1.1')

# 1. 입력 데이터셋 (지역별 전구물질 배출량, 17x5 크기 데이터, 총 119개 시나리오의) 로드
emis_ctrl_2019_05 = pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/ctrl/precursor_control_2019.csv', index_col=0)

# 2. 국외 영향 Factor인 BC의 값을 0.5, 1.0로 균등하게 샘플링
emis_ctrl_2019_05['Boundary'] = 0.5
emis_ctrl_2019_10 = emis_ctrl_2019_05.copy()
emis_ctrl_2019_10['Boundary'] = 1.0
ctrl_data = pd.concat([
    emis_ctrl_2019_05,
    emis_ctrl_2019_10
], axis=0)
ctrl_data = ctrl_data.reset_index(drop=True).values

# 입력 1: pred_emis_data 지역별 배출량 (85x1), 입력 2: pred_boundary_data BC 값 (1x1)
pred_emis_data, pred_boundary_data = ctrl_data[:, :17*5], ctrl_data[:, 17*5]

# 레이블 데이터 로드 (레이블: CMAQ 시뮬레이션 데이터, 추후 예측 결과 성능 검증에 사용)
base_path_2019 = '/home/user/workdir/CMAQ_Emulator/main/datasets/concentration/2019'
conc_path = []
for i in range(1, 120): conc_path.append(os.path.join(base_path_2019, '0.50', f'ACONC.{i}'))
for i in range(1, 120): conc_path.append(os.path.join(base_path_2019, '1.00', f'ACONC.{i}'))
conc_data = []
for path in conc_path:
    with nc.Dataset(path) as f:
        conc_data.append(f.variables['PM2_5'][:].data.squeeze())
conc_data = np.array(conc_data).reshape(len(conc_path), 82, 67, 1)

# 4. Local AQM 모델의 입력 데이터, 레이블 데이터 셋업 완료
_, X_emis_test, _, X_boundary_test, _, y_test = train_test_split(pred_emis_data, pred_boundary_data, conc_data, test_size=test_split, random_state=random_seed, stratify=pred_boundary_data)

# 5. Local AQM 모델을 이용한 추론 진행
y_preds = model.predict([X_emis_test,  X_boundary_test])
y_pred = y_preds.squeeze()
y_true = y_test.squeeze()
print("y_pred:", y_pred.shape, "y_true:", y_true.shape)
# Out:
# Memory growth enabled for GPUs
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# 2/2 [==============================] - 5s 742ms/step
# y_pred: (48, 82, 67) y_true: (48, 82, 67)

# %%
mask_expanded = np.repeat(mask[np.newaxis, :, :], repeats=y_true.shape[0], axis=0) # (24, 82, 67)
pred_conc_map_w_lines = np.where(mask_expanded == 1, y_pred, 0)  # 마스킹 적용
true_conc_map_w_lines = np.where(mask_expanded == 1, y_true, 0) # 마스킹 적용

# %%
def plot_scatter(ax, y_true, y_pred):
    r_x, r_y = np.polyfit(y_true, y_pred, 1)
    ax.hist2d(
        y_true, y_pred,
        bins=100, cmap='jet', cmin=1,
        norm=mpl.colors.LogNorm(vmin=1, vmax=1000),
    )
    ax.plot(
        y_true, r_x*y_true + r_y,
        color='red', label=f"y={r_x:.4f}x+{r_y:.4f}")
    r2 = r2_score(y_true, y_pred)
    ax.text(
        0.05, 0.95, f"$R^2={r2:.4f}$ \nSlope={r_x:.4f}\nIntercept={r_y:.4f}",
        verticalalignment='top', horizontalalignment='left',
        transform=ax.transAxes, fontsize=11
    )
    ax.grid(alpha=0.25)
    return ax

def get_score(y_true, y_pred):
    batch_size = y_true.shape[0]
    y_true = y_true.reshape(batch_size, -1)
    y_pred = y_pred.reshape(batch_size, -1)
    y_norm_err = np.abs(y_true - y_pred) / np.mean(y_true, axis=1, keepdims=True)
    y_err_mean = np.mean(y_norm_err, axis=1)
    y_err_std = np.percentile(y_norm_err, q=5, axis=1)
    # y_err_std = np.std(y_norm_err, axis=1)  # (48,)
    return y_err_mean, y_err_std

# %%
y_true_modi = true_conc_map_w_lines.reshape(-1)
y_pred_modi = pred_conc_map_w_lines.reshape(-1)

# y_true_modi = y_true.reshape(-1)
# y_pred_modi = y_pred.reshape(-1)

fig, axes = plt.subplots(1, 1, figsize=(5, 5), dpi=300)
axes = plot_scatter(axes, y_true_modi, y_pred_modi)
axes.grid(alpha=0.25)
axes.set_title("True vs. Pred scatter plot")
axes.set_xlabel('True PM2.5 [$\mu \mathrm{g}/\mathrm{m}^3$]')
axes.set_ylabel('Pred PM2.5 [$\mu \mathrm{g}/\mathrm{m}^3$]')
cbaxes = axes.inset_axes([0.5, 0.2, 0.35, 0.03])
cb = plt.colorbar(
    mpl.cm.ScalarMappable(norm=mpl.colors.LogNorm(vmin=1, vmax=1000), cmap='jet'),
    cax=cbaxes, label='Number of samples', orientation='horizontal')
cb.set_label(label='Number of samples', fontsize=10)

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 6), dpi=300)
score, score_std = get_score(true_conc_map_w_lines, pred_conc_map_w_lines)
# score, score_std = get_score(y_true, y_pred)
label_text = f'NMAE: {np.mean(score):.3f}±{np.std(score):.3f}'

axes.bar(np.arange(y_test.shape[0]), score, yerr=score_std, label=label_text, capsize=2)
axes.set_xticks(np.arange(y_test.shape[0]), range(y_test.shape[0]))
axes.grid(alpha=0.25)
axes.legend()
axes.set_title("NMAE of Cond. U-Net PM2.5")
axes.set_xlabel('Scenario')
axes.set_ylabel('NMAE [%]')
plt.show()

# %%
cmap_with_white = plt.get_cmap('jet').copy()   # jet 컬러맵 복사
cmap_with_white.set_bad('white')               # 마스킹된 부분을 흰색으로

def plot_prediction_loss(y_true, y_pred, map_boundary, num_samples=1, indices=-1):
    if indices == -1 or indices < 0:
        indices = np.random.choice(len(y_true), num_samples, replace=False)
    else:
        indices = [indices]
    
    local_min = min(y_true[indices].min(), y_pred[indices].min())
    local_max = max(y_true[indices].max(), y_pred[indices].max())
    local_diff = np.abs(y_true[indices] - y_pred[indices])
    local_max = max(local_max, local_diff.max())

    fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))
    if num_samples == 1:
        axes = axes[np.newaxis, :]

    x_min, x_max = -180000 + offset_x, 414000 + offset_x
    y_min, y_max = -585000 + offset_y, 144000 + offset_y
    x_ticks, x_labels = np.linspace(x_min, x_max, 8), [str(i) for i in range(124, 132)]
    y_ticks, y_labels = np.linspace(y_min, y_max, 8), [str(i) for i in range(32, 40)]
    threshold = 0.01

    for i, idx in enumerate(indices):
        # (A) True
        data_true = y_true[idx][::-1]
        masked_true = np.ma.masked_where(data_true <= threshold, data_true)
        im_true = axes[i, 0].imshow(masked_true, cmap=cmap_with_white, extent=(x_min, x_max, y_min, y_max), vmin=threshold, vmax=local_max)
        # ctprvn_proj 대신 인자로 받은 map_boundary 사용
        map_boundary.boundary.plot(ax=axes[i, 0], edgecolor='black', facecolor='none', linewidth=1, alpha=0.25)
        axes[i, 0].set_title(f"True (#{idx})")
        axes[i, 0].set_xlabel('Longitude [°]')
        axes[i, 0].set_ylabel('Latitude [°]')
        axes[i, 0].set_xlim(x_min, x_max)
        axes[i, 0].set_ylim(y_min, y_max)
        axes[i, 0].set_xticks(x_ticks)
        axes[i, 0].set_yticks(y_ticks)
        axes[i, 0].set_xticklabels(x_labels)
        axes[i, 0].set_yticklabels(y_labels)
        axes[i, 0].grid(alpha=0.25, color='silver')

        # (B) Predicted
        data_pred = y_pred[idx][::-1]
        masked_pred = np.ma.masked_where(data_pred <= threshold, data_pred)
        im_pred = axes[i, 1].imshow(masked_pred, cmap=cmap_with_white, extent=(x_min, x_max, y_min, y_max), vmin=threshold, vmax=local_max)
        # ctprvn_proj 대신 인자로 받은 map_boundary 사용
        map_boundary.boundary.plot(ax=axes[i, 1], edgecolor='black', facecolor='none', linewidth=1, alpha=0.25)
        axes[i, 1].set_title(f"Predicted (#{idx})")
        axes[i, 1].set_xlabel('Longitude [°]')
        axes[i, 1].set_ylabel('Latitude [°]')
        axes[i, 1].set_xlim(x_min, x_max)
        axes[i, 1].set_ylim(y_min, y_max)
        axes[i, 1].set_xticks(x_ticks)
        axes[i, 1].set_yticks(y_ticks)
        axes[i, 1].set_xticklabels(x_labels)
        axes[i, 1].set_yticklabels(y_labels)
        axes[i, 1].grid(alpha=0.25, color='silver')

        # (C) Difference
        data_diff = np.abs(y_true[idx] - y_pred[idx])[::-1]
        masked_diff = np.ma.masked_where(data_diff <= threshold, data_diff)
        im_diff = axes[i, 2].imshow(masked_diff, cmap=cmap_with_white, extent=(x_min, x_max, y_min, y_max), vmin=threshold, vmax=local_max)
        # ctprvn_proj 대신 인자로 받은 map_boundary 사용
        map_boundary.boundary.plot(ax=axes[i, 2], edgecolor='black', facecolor='none', linewidth=1, alpha=0.25)
        axes[i, 2].set_title(f"Difference (#{idx})")
        axes[i, 2].set_xlabel('Longitude [°]')
        axes[i, 2].set_ylabel('Latitude [°]')
        axes[i, 2].set_xlim(x_min, x_max)
        axes[i, 2].set_ylim(y_min, y_max)
        axes[i, 2].set_xticks(x_ticks)
        axes[i, 2].set_yticks(y_ticks)
        axes[i, 2].set_xticklabels(x_labels)
        axes[i, 2].set_yticklabels(y_labels)
        axes[i, 2].grid(alpha=0.25, color='silver')

    plt.subplots_adjust(wspace=-0.4, hspace=0.2)
    plt.tight_layout(rect=[0, 0, 0.88, 0.96])
    cbar = fig.colorbar(im_true, ax=axes.ravel().tolist(), orientation='vertical', fraction=0.03, pad=0.02, shrink=0.8)
    cbar.set_label('conc. [$\\mu \\mathrm{g}/\\mathrm{m}^3$]')
    plt.show()

plot_prediction_loss(true_conc_map_w_lines, pred_conc_map_w_lines, sigungu_map_proj, indices=np.argmax(score))

# %% [markdown]
# ### 시-군-구 평균 농도 산출 및 데이터 테이블화

# %%
# 1. A~Q 순서에 해당하는 광역지자체 이름 리스트 생성
region_columns = {
    'A': 'Seoul', 'B': 'Incheon', 'C': 'Busan', 'D': 'Daegu',
    'E': 'Gwangju', 'F': 'Gyeonggi', 'G': 'Gangwon', 'H': 'Chungbuk',
    'I': 'Chung-Nam', 'J': 'Gyeong-Buk', 'K': 'Gyeong-Nam', 'L': 'Jeon-Buk',
    'M': 'Jeon-Nam', 'N': 'Jeju', 'O': 'Daejeon', 'P': 'Ulsan', 'Q': 'Sejong'
}
region_order = list(region_columns.values())

# 2. 테스트 데이터셋 전체 기간에 대한 평균 농도 계산
avg_true_conc = np.mean(y_true, axis=0)
avg_pred_conc = np.mean(y_pred, axis=0)

# 3. 격자별 농도 데이터를 시군구 정보와 결합
grid_data_list = []
for _, row in grid_alloc.iterrows():
    r_idx, c_idx = int(row['Row']) - 1, int(row['Column']) - 1
    grid_data_list.append({
        'Region_Name': row['Region_Name'],
        'SIG_ENG_NM': row['SIG_ENG_NM'],
        'True_Conc': avg_true_conc[r_idx, c_idx],
        'Pred_Conc': avg_pred_conc[r_idx, c_idx]
    })
conc_by_grid_df = pd.DataFrame(grid_data_list)

# 4. 시군구를 기준으로 그룹화하여 평균 농도 산출
sigungu_avg_conc_df = conc_by_grid_df.groupby(['Region_Name', 'SIG_ENG_NM']).mean().reset_index()

# 5. 예측 농도와 실제 농도의 차이(Difference) 계산
sigungu_avg_conc_df['Difference'] = sigungu_avg_conc_df['Pred_Conc'] - sigungu_avg_conc_df['True_Conc']

# 6. 보기 쉽게 컬럼 이름 변경
sigungu_avg_conc_df = sigungu_avg_conc_df.rename(columns={
    'True_Conc': 'True_Avg_PM2.5',
    'Pred_Conc': 'Pred_Avg_PM2.5',
    'Difference': 'Difference (Pred - True)'
})

# 7. 광역지자체 A-Q 순서로 정렬하여 결과 테이블 출력
# 'Region_Name' 컬럼을 위에서 정의한 순서를 따르는 Categorical 타입으로 변환합니다.
sigungu_avg_conc_df['Region_Name'] = pd.Categorical(
    sigungu_avg_conc_df['Region_Name'],
    categories=region_order,
    ordered=True
)

# 지정된 광역지자체 순서와 기초지자체 이름 순으로 정렬합니다.
final_sorted_df = sigungu_avg_conc_df.sort_values(by=['Region_Name', 'SIG_ENG_NM']).reset_index(drop=True)

display(final_sorted_df)

# display 결과를 "SIG_table_v1.1.csv" 파일로 저장
final_sorted_df.to_csv("/home/user/workdir/CMAQ_Emulator/main/resources/geom/SIG_table_v1.1.csv", index=False)
# Out:
#     Region_Name       SIG_ENG_NM  True_Avg_PM2.5  Pred_Avg_PM2.5  \
# 0         Seoul        Jongno-gu       19.134909       18.895967
# 1         Seoul         Nowon-gu       20.400839       20.075119
# 2         Seoul        Songpa-gu       20.653564       20.347475
# 3         Seoul  Yeongdeungpo-gu       21.257971       20.996424
# 4         Seoul       Yongsan-gu       20.594492       20.315691
# ..          ...              ...             ...             ...
# 196       Ulsan           Buk-gu       13.216816       13.097694
# 197       Ulsan          Dong-gu       10.370206       10.305622
# 198       Ulsan           Nam-gu       14.227098       14.092014
# 199       Ulsan         Ulju-gun       13.491662       13.364911
# 200      Sejong        Sejong-si       18.959812       18.734865
#
#      Difference (Pred - True)
# 0                   -0.238941
# 1                   -0.325720
# 2                   -0.306089
# 3                   -0.261547
# 4                   -0.278801
# ..                        ...
# 196                 -0.119122
# 197                 -0.064584
# 198                 -0.135083
# 199                 -0.126751
# 200                 -0.224947
#
# [201 rows x 5 columns]
