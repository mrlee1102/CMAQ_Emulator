# %% [markdown]
# O3 농도 예측 모델의 학습 및 모델 예측 테스트 코드
#
# VER:
#
#     v5.2.2
#
# SETUP:
#
#     In[NOx, VOC, NH3, PM25, 'VOC*NOx', 'VOC^2*NOx', 'VOC*NOx^2', 'VOC^2*NOx^2']
#     Out[pred. O3]
#
# STRUCTURE:
#
#     CMAQ U-Net
#
#     model = build_model(
#         ...,
#         hidden_size=[96, 64],
#         hidden_depth=5,
#         ...,
#         in_filters=10,
#         ...
#     )
#
# PROPERTIES:
#
#     1. 학습 시 모델의 입력 파라미터를 낮추어(입력 해상도를 낮춰) 모델의 출력 해상도에 스무딩을 적용하는 역할
#     2. 모델의 깊이를 높여 입력 변수 간 비선형적 상호작용을 더 잘 반영할 수 있도록 구조화
#         2-1.
#             계층적 특징 추출:
#                 각 층은 이전 층의 출력을 비선형 활성화 함수를 통해 변환합니다. 여러 층을 쌓으면, 낮은 층에서는 간단한 패턴이나 국부적인 특징을 추출하고, 높은 층에서는 이들이 결합되어 보다 추상적이고 복잡한 패턴을 형성하게 됩니다. 이러한 계층적 구조는 입력 특성 간의 복잡한 상호작용과 비선형 관계를 효과적으로 모델링할 수 있도록 돕습니다.
#
#             비선형 함수 근사 능력:
#                 심층 신경망은 이론적으로 임의의 복잡한 함수를 근사할 수 있는 보편 근사자(universal approximator)입니다. 층이 깊어질수록 여러 비선형 변환의 합성(composition)을 통해 더 복잡한 함수 형태를 학습할 수 있습니다. 따라서, hidden depth가 늘어나면 입력 특성의 복잡한 비선형 관계를 더 잘 반영할 수 있습니다.
#
#             표현력 향상:
#                 각 추가 층은 모델에 추가적인 자유도를 부여하여, 데이터의 미묘한 패턴과 상호작용을 포착할 수 있게 합니다. 이는 특히, 입력 특성들 사이에 여러 단계의 상호작용이나 고차원적 비선형 관계가 존재하는 경우 유리합니다.

# %%
# Import
import os
import sys
sys.path.append('/home/user/workdir/CMAQ_Emulator/main')

import numpy as np
import pandas as pd
import netCDF4 as nc
from netCDF4 import Dataset

from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.metrics import r2_score

import geopandas as gpd
from shapely.geometry import Point
import matplotlib as mpl
import matplotlib.pyplot as plt
# Out:
# 2025-03-05 17:04:10.283731: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-05 17:04:10.316273: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-05 17:04:10.316307: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-05 17:04:10.316328: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-05 17:04:10.322592: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-05 17:04:11.212066: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Training

# %%
dataset_2013 = pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/ctrl/dataset_for_o3_interaction_v2.csv')

ctrl_data = pd.concat([dataset_2013], axis=0)
ctrl_data = ctrl_data.reset_index(drop=True).values
emis_data = ctrl_data[:, :17*7]
label_path_2013 = '/home/user/workdir/CMAQ_Emulator/main/datasets/concentration/2013'
label_path = []
for i in range(1, 120): 
    label_path.append(os.path.join(label_path_2013, '1.00', f'ACONC.{i}'))
label_data = []
for path in label_path:
    with nc.Dataset(path) as f:
        label_data.append(f.variables['O3'][:].data.squeeze())  # ncf 파일 내 목적변수를 지정 
label_data = np.array(label_data).reshape(len(label_data), 82, 67, 1)

# %%
from src.model.cmaqnet_unet import build_model
from tensorflow.keras.callbacks import EarlyStopping

model_path = '/home/user/workdir/CMAQ_Emulator/main/src/model/o3_prediction/v6/final_model(adjusted_v3)'  # 모델 저장 경로

epochs = 1000  # 훈련 반복 횟수
batch_size = 32  # 배치 크기
test_split = 0.4  # 테스트 데이터 비율 (50%)
random_seed = 42  # 랜덤 시드

X_emis_train, X_emis_test, y_train, y_test = train_test_split(emis_data, label_data, test_size=test_split, random_state=random_seed)

# Cosine Decay 스케줄 설정
steps_per_epoch = len(X_emis_train) // batch_size  # 정수 나눗셈
total_steps = epochs * steps_per_epoch

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("Memory growth enabled for GPUs")
    except RuntimeError as e:
        print(e)

strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=1e-3,
        decay_steps=total_steps,
        alpha=0.1  # 최종 lr 비율 (0이면 최솟값이 0)
    )
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
    model = build_model(
        ctrl_dim=17*7,
        out_channel=1,
        hidden_size=[256, 128],
        hidden_depth=5,
        in_filters=64,
        kernel_size=3,
        activation='silu',
        dropout=0.0,
        use_abs=True
    )
    model.compile(
        optimizer=optimizer,  # 위에서 정의한 CosineDecay 스케줄이 적용된 optimizer
        loss=tf.keras.losses.Huber(delta=0.1)  # delta는 Huber 손실 전환점
    )

early_stop = EarlyStopping(monitor='val_loss', patience=150, restore_best_weights=True)

history = model.fit(
    x=[X_emis_train],
    y=y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=[[X_emis_test], y_test],
    callbacks=[early_stop]
)

model.save(model_path)

def plot_loss(history):
    epochs = range(1, len(history.history['loss']) + 1)
    
    plt.figure(figsize=(15, 10))
    
    # 1. 전체 에포크에 대한 학습 및 검증 손실
    plt.subplot(2, 2, 1)
    plt.plot(epochs, history.history['loss'], label='Training Loss', color='blue')
    plt.plot(epochs, history.history['val_loss'], label='Validation Loss', color='orange')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss over Epochs')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 2. 마지막 10 에포크의 손실 (세부 분석)
    plt.subplot(2, 2, 2)
    if len(epochs) >= 10:
        last_epochs = epochs[-10:]
        plt.plot(last_epochs, history.history['loss'][-10:], label='Training Loss', color='blue')
        plt.plot(last_epochs, history.history['val_loss'][-10:], label='Validation Loss', color='orange')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Loss (Last 10 Epochs)')
        plt.legend()
        plt.grid(alpha=0.3)
    else:
        plt.text(0.5, 0.5, "Not enough epochs for zoomed plot", ha='center')
    
    # 3. 학습 손실과 검증 손실의 차이
    plt.subplot(2, 2, 3)
    loss_diff = np.array(history.history['val_loss']) - np.array(history.history['loss'])
    plt.plot(epochs, loss_diff, label='Val Loss - Train Loss', color='green')
    plt.xlabel('Epochs')
    plt.ylabel('Loss Difference')
    plt.title('Difference between Validation and Training Loss')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 4. 이동 평균 (window=10)을 통한 평활화된 손실 추세
    plt.subplot(2, 2, 4)
    window = 10
    if len(epochs) >= window:
        train_ma = [np.mean(history.history['loss'][max(0, i-window):i]) for i in range(1, len(history.history['loss'])+1)]
        val_ma = [np.mean(history.history['val_loss'][max(0, i-window):i]) for i in range(1, len(history.history['val_loss'])+1)]
        plt.plot(epochs, train_ma, label='Training Loss MA', color='blue', linestyle='--')
        plt.plot(epochs, val_ma, label='Validation Loss MA', color='orange', linestyle='--')
        plt.xlabel('Epochs')
        plt.ylabel('Loss (Moving Average)')
        plt.title('Moving Average of Loss (window = 10)')
        plt.legend()
        plt.grid(alpha=0.3)
    else:
        plt.text(0.5, 0.5, "Not enough epochs for moving average plot", ha='center')
    
    plt.tight_layout()
    plt.show()
''' 16min '''
# Out:
# Memory growth enabled for GPUs
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# 2025-03-05 16:26:22.816091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22332 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:19:00.0, compute capability: 8.6
# 2025-03-05 16:26:22.817741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22332 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1a:00.0, compute capability: 8.6
# 2025-03-05 16:26:22.819255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22332 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:67:00.0, compute capability: 8.6
# 2025-03-05 16:26:22.820735: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22263 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:68:00.0, compute capability: 8.6
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/1000
# INFO:tensorflow:Collective all_reduce tensors: 82 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 82 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 2025-03-05 16:26:45.359621: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape ingradient_tape/huber_loss/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-03-05 16:26:49.435930: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2025-03-05 16:26:49.447633: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2025-03-05 16:26:49.459768: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2025-03-05 16:26:49.482142: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2025-03-05 16:26:58.538344: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f482ded7bb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-03-05 16:26:58.538400: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-03-05 16:26:58.538414: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-03-05 16:26:58.538426: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-03-05 16:26:58.538436: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (3): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-03-05 16:26:58.552115: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-03-05 16:26:58.647680: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3/3 [==============================] - 49s 5s/step - loss: 0.0644 - val_loss: 3.0961
# Epoch 2/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 0.0204 - val_loss: 66.3274
# Epoch 3/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.0064 - val_loss: 119.9222
# Epoch 4/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.0026 - val_loss: 114.9388
# Epoch 5/1000
# 3/3 [==============================] - 1s 525ms/step - loss: 0.0018 - val_loss: 66.0225
# Epoch 6/1000
# 3/3 [==============================] - 1s 496ms/step - loss: 0.0014 - val_loss: 32.2445
# Epoch 7/1000
# 3/3 [==============================] - 2s 747ms/step - loss: 8.1213e-04 - val_loss: 18.2969
# Epoch 8/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 4.5604e-04 - val_loss: 10.2115
# Epoch 9/1000
# 3/3 [==============================] - 1s 552ms/step - loss: 4.6947e-04 - val_loss: 4.8659
# Epoch 10/1000
# 3/3 [==============================] - 2s 654ms/step - loss: 4.2537e-04 - val_loss: 2.4197
# Epoch 11/1000
# 3/3 [==============================] - 2s 660ms/step - loss: 3.9530e-04 - val_loss: 1.3529
# Epoch 12/1000
# 3/3 [==============================] - 2s 646ms/step - loss: 2.8380e-04 - val_loss: 0.7667
# Epoch 13/1000
# 3/3 [==============================] - 2s 646ms/step - loss: 2.2624e-04 - val_loss: 0.4772
# Epoch 14/1000
# 3/3 [==============================] - 2s 658ms/step - loss: 1.8083e-04 - val_loss: 0.2946
# Epoch 15/1000
# 3/3 [==============================] - 2s 653ms/step - loss: 1.3557e-04 - val_loss: 0.2004
# Epoch 16/1000
# 3/3 [==============================] - 2s 662ms/step - loss: 1.3348e-04 - val_loss: 0.1292
# Epoch 17/1000
# 3/3 [==============================] - 2s 662ms/step - loss: 1.0712e-04 - val_loss: 0.0847
# Epoch 18/1000
# 3/3 [==============================] - 2s 653ms/step - loss: 1.0199e-04 - val_loss: 0.0542
# Epoch 19/1000
# 3/3 [==============================] - 2s 638ms/step - loss: 7.7490e-05 - val_loss: 0.0365
# Epoch 20/1000
# 3/3 [==============================] - 2s 673ms/step - loss: 8.2252e-05 - val_loss: 0.0269
# Epoch 21/1000
# 3/3 [==============================] - 2s 668ms/step - loss: 6.7264e-05 - val_loss: 0.0201
# Epoch 22/1000
# 3/3 [==============================] - 2s 661ms/step - loss: 5.5980e-05 - val_loss: 0.0151
# Epoch 23/1000
# 3/3 [==============================] - 2s 690ms/step - loss: 5.3466e-05 - val_loss: 0.0113
# Epoch 24/1000
# 3/3 [==============================] - 2s 661ms/step - loss: 5.7180e-05 - val_loss: 0.0086
# Epoch 25/1000
# 3/3 [==============================] - 2s 641ms/step - loss: 4.4405e-05 - val_loss: 0.0065
# Epoch 26/1000
# 3/3 [==============================] - 2s 675ms/step - loss: 4.3734e-05 - val_loss: 0.0050
# Epoch 27/1000
# 3/3 [==============================] - 2s 648ms/step - loss: 4.0182e-05 - val_loss: 0.0039
# Epoch 28/1000
# 3/3 [==============================] - 2s 663ms/step - loss: 4.7308e-05 - val_loss: 0.0030
# Epoch 29/1000
# 3/3 [==============================] - 2s 660ms/step - loss: 4.2884e-05 - val_loss: 0.0025
# Epoch 30/1000
# 3/3 [==============================] - 2s 632ms/step - loss: 4.0040e-05 - val_loss: 0.0021
# Epoch 31/1000
# 3/3 [==============================] - 2s 660ms/step - loss: 4.1064e-05 - val_loss: 0.0018
# Epoch 32/1000
# 3/3 [==============================] - 2s 642ms/step - loss: 2.9685e-05 - val_loss: 0.0016
# Epoch 33/1000
# 3/3 [==============================] - 2s 626ms/step - loss: 2.8000e-05 - val_loss: 0.0013
# Epoch 34/1000
# 3/3 [==============================] - 2s 675ms/step - loss: 3.5927e-05 - val_loss: 0.0012
# Epoch 35/1000
# 3/3 [==============================] - 2s 663ms/step - loss: 4.1646e-05 - val_loss: 0.0010
# Epoch 36/1000
# 3/3 [==============================] - 2s 638ms/step - loss: 3.3519e-05 - val_loss: 9.5489e-04
# Epoch 37/1000
# 3/3 [==============================] - 2s 649ms/step - loss: 2.7017e-05 - val_loss: 8.7610e-04
# Epoch 38/1000
# 3/3 [==============================] - 2s 632ms/step - loss: 3.0775e-05 - val_loss: 7.4547e-04
# Epoch 39/1000
# 3/3 [==============================] - 2s 672ms/step - loss: 2.2339e-05 - val_loss: 6.4776e-04
# Epoch 40/1000
# 3/3 [==============================] - 2s 685ms/step - loss: 3.9161e-05 - val_loss: 6.1217e-04
# Epoch 41/1000
# 3/3 [==============================] - 2s 649ms/step - loss: 2.2746e-05 - val_loss: 5.3845e-04
# Epoch 42/1000
# 3/3 [==============================] - 2s 644ms/step - loss: 3.3839e-05 - val_loss: 5.0967e-04
# Epoch 43/1000
# 3/3 [==============================] - 2s 647ms/step - loss: 3.1450e-05 - val_loss: 4.9184e-04
# Epoch 44/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 2.8853e-05 - val_loss: 5.0399e-04
# Epoch 45/1000
# 3/3 [==============================] - 2s 674ms/step - loss: 4.2198e-05 - val_loss: 4.0144e-04
# Epoch 46/1000
# 3/3 [==============================] - 2s 644ms/step - loss: 4.3346e-05 - val_loss: 3.6758e-04
# Epoch 47/1000
# 3/3 [==============================] - 2s 662ms/step - loss: 4.0473e-05 - val_loss: 2.7202e-04
# Epoch 48/1000
# 3/3 [==============================] - 1s 546ms/step - loss: 6.8361e-05 - val_loss: 4.3670e-04
# Epoch 49/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 6.6954e-05 - val_loss: 3.5656e-04
# Epoch 50/1000
# 3/3 [==============================] - 2s 675ms/step - loss: 4.7977e-05 - val_loss: 2.6194e-04
# Epoch 51/1000
# 3/3 [==============================] - 2s 651ms/step - loss: 5.6203e-05 - val_loss: 1.9519e-04
# Epoch 52/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 5.6511e-05 - val_loss: 2.8524e-04
# Epoch 53/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 5.3872e-05 - val_loss: 3.2729e-04
# Epoch 54/1000
# 3/3 [==============================] - 2s 651ms/step - loss: 8.5968e-05 - val_loss: 1.5472e-04
# Epoch 55/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 3.9623e-05 - val_loss: 1.6069e-04
# Epoch 56/1000
# 3/3 [==============================] - 1s 543ms/step - loss: 4.6149e-05 - val_loss: 2.3978e-04
# Epoch 57/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 5.2064e-05 - val_loss: 2.7055e-04
# Epoch 58/1000
# 3/3 [==============================] - 2s 671ms/step - loss: 6.6103e-05 - val_loss: 1.4644e-04
# Epoch 59/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 4.3757e-05 - val_loss: 1.8526e-04
# Epoch 60/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 3.6191e-05 - val_loss: 2.1379e-04
# Epoch 61/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 3.8126e-05 - val_loss: 2.1868e-04
# Epoch 62/1000
# 3/3 [==============================] - 1s 534ms/step - loss: 3.0744e-05 - val_loss: 1.8961e-04
# Epoch 63/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 2.5576e-05 - val_loss: 1.7568e-04
# Epoch 64/1000
# 3/3 [==============================] - 1s 543ms/step - loss: 2.5211e-05 - val_loss: 1.6059e-04
# Epoch 65/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 2.0186e-05 - val_loss: 1.8039e-04
# Epoch 66/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 1.4658e-05 - val_loss: 1.5324e-04
# Epoch 67/1000
# 3/3 [==============================] - 1s 536ms/step - loss: 2.2482e-05 - val_loss: 1.6297e-04
# Epoch 68/1000
# 3/3 [==============================] - 2s 662ms/step - loss: 2.3545e-05 - val_loss: 1.2629e-04
# Epoch 69/1000
# 3/3 [==============================] - 1s 496ms/step - loss: 2.5806e-05 - val_loss: 1.4101e-04
# Epoch 70/1000
# 3/3 [==============================] - 2s 650ms/step - loss: 2.4145e-05 - val_loss: 1.0728e-04
# Epoch 71/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 2.4178e-05 - val_loss: 1.1735e-04
# Epoch 72/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 1.5294e-05 - val_loss: 1.3706e-04
# Epoch 73/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 2.3067e-05 - val_loss: 1.1380e-04
# Epoch 74/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 1.9875e-05 - val_loss: 1.4576e-04
# Epoch 75/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 2.5686e-05 - val_loss: 1.1595e-04
# Epoch 76/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 2.0856e-05 - val_loss: 1.4661e-04
# Epoch 77/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 1.7445e-05 - val_loss: 1.5152e-04
# Epoch 78/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 2.1941e-05 - val_loss: 1.2241e-04
# Epoch 79/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 1.5072e-05 - val_loss: 1.1136e-04
# Epoch 80/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 1.2520e-05 - val_loss: 1.1675e-04
# Epoch 81/1000
# 3/3 [==============================] - 2s 645ms/step - loss: 2.4116e-05 - val_loss: 9.5355e-05
# Epoch 82/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 2.0517e-05 - val_loss: 1.1833e-04
# Epoch 83/1000
# 3/3 [==============================] - 1s 534ms/step - loss: 2.2166e-05 - val_loss: 1.0245e-04
# Epoch 84/1000
# 3/3 [==============================] - 1s 547ms/step - loss: 1.7864e-05 - val_loss: 1.1637e-04
# Epoch 85/1000
# 3/3 [==============================] - 1s 503ms/step - loss: 1.8873e-05 - val_loss: 1.0204e-04
# Epoch 86/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 1.7695e-05 - val_loss: 1.0980e-04
# Epoch 87/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 1.9751e-05 - val_loss: 1.0275e-04
# Epoch 88/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 1.9636e-05 - val_loss: 1.0991e-04
# Epoch 89/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 2.4032e-05 - val_loss: 9.6425e-05
# Epoch 90/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 1.7983e-05 - val_loss: 9.5910e-05
# Epoch 91/1000
# 3/3 [==============================] - 2s 557ms/step - loss: 1.5408e-05 - val_loss: 1.0912e-04
# Epoch 92/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 2.3988e-05 - val_loss: 9.7105e-05
# Epoch 93/1000
# 3/3 [==============================] - 2s 639ms/step - loss: 2.4289e-05 - val_loss: 9.1388e-05
# Epoch 94/1000
# 3/3 [==============================] - 1s 535ms/step - loss: 1.1365e-04 - val_loss: 1.2893e-04
# Epoch 95/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 5.8500e-05 - val_loss: 1.7198e-04
# Epoch 96/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 6.6572e-05 - val_loss: 2.4205e-04
# Epoch 97/1000
# 3/3 [==============================] - 1s 539ms/step - loss: 4.2608e-05 - val_loss: 3.3169e-04
# Epoch 98/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 9.6223e-05 - val_loss: 2.0609e-04
# Epoch 99/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 4.0857e-05 - val_loss: 1.8610e-04
# Epoch 100/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 4.7704e-05 - val_loss: 2.5196e-04
# Epoch 101/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 5.4525e-05 - val_loss: 2.5572e-04
# Epoch 102/1000
# 3/3 [==============================] - 1s 525ms/step - loss: 4.9499e-05 - val_loss: 1.2363e-04
# Epoch 103/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 4.6967e-05 - val_loss: 1.0036e-04
# Epoch 104/1000
# 3/3 [==============================] - 1s 500ms/step - loss: 7.2056e-05 - val_loss: 2.1807e-04
# Epoch 105/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 3.7288e-05 - val_loss: 1.8113e-04
# Epoch 106/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 3.7180e-05 - val_loss: 1.2033e-04
# Epoch 107/1000
# 3/3 [==============================] - 2s 650ms/step - loss: 3.1195e-05 - val_loss: 8.3071e-05
# Epoch 108/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 5.5205e-05 - val_loss: 1.6248e-04
# Epoch 109/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 4.9907e-05 - val_loss: 1.4437e-04
# Epoch 110/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 3.2761e-05 - val_loss: 8.8697e-05
# Epoch 111/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 4.9495e-05 - val_loss: 9.9923e-05
# Epoch 112/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 3.4205e-05 - val_loss: 1.1896e-04
# Epoch 113/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 3.9998e-05 - val_loss: 1.4010e-04
# Epoch 114/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 5.1724e-05 - val_loss: 9.3635e-05
# Epoch 115/1000
# 3/3 [==============================] - 2s 555ms/step - loss: 3.3864e-05 - val_loss: 1.1236e-04
# Epoch 116/1000
# 3/3 [==============================] - 1s 534ms/step - loss: 4.1987e-05 - val_loss: 9.5016e-05
# Epoch 117/1000
# 3/3 [==============================] - 2s 683ms/step - loss: 4.7292e-05 - val_loss: 6.8923e-05
# Epoch 118/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 2.9513e-05 - val_loss: 9.6553e-05
# Epoch 119/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 3.5961e-05 - val_loss: 1.6472e-04
# Epoch 120/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 5.2740e-05 - val_loss: 8.3194e-05
# Epoch 121/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 2.9861e-05 - val_loss: 8.3545e-05
# Epoch 122/1000
# 3/3 [==============================] - 1s 536ms/step - loss: 2.9761e-05 - val_loss: 1.4722e-04
# Epoch 123/1000
# 3/3 [==============================] - 1s 547ms/step - loss: 4.3310e-05 - val_loss: 1.3572e-04
# Epoch 124/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 2.4658e-05 - val_loss: 8.9015e-05
# Epoch 125/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 2.5831e-05 - val_loss: 6.9396e-05
# Epoch 126/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 4.3998e-05 - val_loss: 1.7043e-04
# Epoch 127/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 3.7702e-05 - val_loss: 1.4304e-04
# Epoch 128/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 2.5184e-05 - val_loss: 8.1482e-05
# Epoch 129/1000
# 3/3 [==============================] - 2s 643ms/step - loss: 3.2680e-05 - val_loss: 3.9562e-05
# Epoch 130/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 4.8149e-05 - val_loss: 1.1535e-04
# Epoch 131/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 2.6175e-05 - val_loss: 1.3737e-04
# Epoch 132/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 2.8669e-05 - val_loss: 5.2466e-05
# Epoch 133/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 3.8581e-05 - val_loss: 5.3392e-05
# Epoch 134/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 4.3252e-05 - val_loss: 8.8523e-05
# Epoch 135/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 2.7051e-05 - val_loss: 4.6936e-05
# Epoch 136/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 2.9939e-05 - val_loss: 7.1061e-05
# Epoch 137/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 4.3918e-05 - val_loss: 8.1498e-05
# Epoch 138/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 2.7546e-05 - val_loss: 5.3427e-05
# Epoch 139/1000
# 3/3 [==============================] - 2s 663ms/step - loss: 2.9516e-05 - val_loss: 3.5583e-05
# Epoch 140/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 4.2211e-05 - val_loss: 1.1617e-04
# Epoch 141/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 3.8664e-05 - val_loss: 8.1487e-05
# Epoch 142/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 2.6262e-05 - val_loss: 3.7827e-05
# Epoch 143/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 3.0784e-05 - val_loss: 4.1678e-05
# Epoch 144/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 4.1210e-05 - val_loss: 8.0544e-05
# Epoch 145/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 2.5075e-05 - val_loss: 1.0235e-04
# Epoch 146/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 4.4522e-05 - val_loss: 9.9562e-05
# Epoch 147/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 4.6916e-05 - val_loss: 8.4868e-05
# Epoch 148/1000
# 3/3 [==============================] - 2s 842ms/step - loss: 4.4156e-05 - val_loss: 1.6481e-04
# Epoch 149/1000
# 3/3 [==============================] - 1s 546ms/step - loss: 3.7281e-05 - val_loss: 1.7885e-04
# Epoch 150/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 2.6621e-05 - val_loss: 1.2694e-04
# Epoch 151/1000
# 3/3 [==============================] - 1s 551ms/step - loss: 3.0736e-05 - val_loss: 1.1679e-04
# Epoch 152/1000
# 3/3 [==============================] - 2s 554ms/step - loss: 3.0971e-05 - val_loss: 2.0512e-04
# Epoch 153/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 3.8973e-05 - val_loss: 1.9448e-04
# Epoch 154/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 2.7485e-05 - val_loss: 1.3182e-04
# Epoch 155/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 1.7903e-05 - val_loss: 1.2187e-04
# Epoch 156/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 1.6431e-05 - val_loss: 1.1850e-04
# Epoch 157/1000
# 3/3 [==============================] - 1s 548ms/step - loss: 1.8109e-05 - val_loss: 1.4295e-04
# Epoch 158/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 1.6081e-05 - val_loss: 1.6189e-04
# Epoch 159/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 2.0187e-05 - val_loss: 1.1108e-04
# Epoch 160/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 1.9291e-05 - val_loss: 5.5082e-05
# Epoch 161/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 2.7476e-05 - val_loss: 1.2598e-04
# Epoch 162/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 3.3273e-05 - val_loss: 1.1983e-04
# Epoch 163/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 2.7750e-05 - val_loss: 6.3791e-05
# Epoch 164/1000
# 3/3 [==============================] - 1s 536ms/step - loss: 1.9427e-05 - val_loss: 3.8276e-05
# Epoch 165/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 3.0098e-05 - val_loss: 1.0092e-04
# Epoch 166/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 3.7391e-05 - val_loss: 7.9429e-05
# Epoch 167/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 2.2160e-05 - val_loss: 4.5598e-05
# Epoch 168/1000
# 3/3 [==============================] - 2s 713ms/step - loss: 1.9702e-05 - val_loss: 2.8910e-05
# Epoch 169/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 3.5028e-05 - val_loss: 9.0304e-05
# Epoch 170/1000
# 3/3 [==============================] - 2s 553ms/step - loss: 2.4652e-05 - val_loss: 9.5878e-05
# Epoch 171/1000
# 3/3 [==============================] - 2s 640ms/step - loss: 2.6019e-05 - val_loss: 2.8189e-05
# Epoch 172/1000
# 3/3 [==============================] - 2s 658ms/step - loss: 2.4567e-05 - val_loss: 1.7853e-05
# Epoch 173/1000
# 3/3 [==============================] - 1s 530ms/step - loss: 2.5637e-05 - val_loss: 8.3978e-05
# Epoch 174/1000
# 3/3 [==============================] - 1s 504ms/step - loss: 2.2186e-05 - val_loss: 9.0298e-05
# Epoch 175/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 2.7065e-05 - val_loss: 2.5124e-05
# Epoch 176/1000
# 3/3 [==============================] - 1s 503ms/step - loss: 2.4611e-05 - val_loss: 1.9972e-05
# Epoch 177/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 1.8616e-05 - val_loss: 6.3229e-05
# Epoch 178/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 2.2171e-05 - val_loss: 6.8167e-05
# Epoch 179/1000
# 3/3 [==============================] - 2s 661ms/step - loss: 2.7403e-05 - val_loss: 1.4996e-05
# Epoch 180/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 1.9998e-05 - val_loss: 1.7545e-05
# Epoch 181/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 2.7561e-05 - val_loss: 4.4910e-05
# Epoch 182/1000
# 3/3 [==============================] - 1s 541ms/step - loss: 2.3752e-05 - val_loss: 5.1003e-05
# Epoch 183/1000
# 3/3 [==============================] - 2s 693ms/step - loss: 2.2407e-05 - val_loss: 1.3134e-05
# Epoch 184/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 2.2516e-05 - val_loss: 1.5468e-05
# Epoch 185/1000
# 3/3 [==============================] - 1s 503ms/step - loss: 2.3583e-05 - val_loss: 4.3737e-05
# Epoch 186/1000
# 3/3 [==============================] - 1s 548ms/step - loss: 2.7392e-05 - val_loss: 4.1572e-05
# Epoch 187/1000
# 3/3 [==============================] - 2s 659ms/step - loss: 2.0568e-05 - val_loss: 1.0734e-05
# Epoch 188/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 1.6941e-05 - val_loss: 1.4913e-05
# Epoch 189/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 2.3477e-05 - val_loss: 4.9750e-05
# Epoch 190/1000
# 3/3 [==============================] - 1s 538ms/step - loss: 2.5659e-05 - val_loss: 4.1071e-05
# Epoch 191/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 1.8430e-05 - val_loss: 1.3530e-05
# Epoch 192/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 1.9202e-05 - val_loss: 2.5969e-05
# Epoch 193/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 3.2470e-05 - val_loss: 3.8472e-05
# Epoch 194/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 1.6855e-05 - val_loss: 4.8581e-05
# Epoch 195/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 2.1621e-05 - val_loss: 1.3219e-05
# Epoch 196/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 2.4249e-05 - val_loss: 1.3062e-05
# Epoch 197/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 1.9907e-05 - val_loss: 3.6603e-05
# Epoch 198/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 1.6636e-05 - val_loss: 5.3819e-05
# Epoch 199/1000
# 3/3 [==============================] - 2s 664ms/step - loss: 2.3455e-05 - val_loss: 1.0083e-05
# Epoch 200/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 2.2105e-05 - val_loss: 1.1919e-05
# Epoch 201/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 2.1977e-05 - val_loss: 3.2814e-05
# Epoch 202/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 1.8350e-05 - val_loss: 5.4514e-05
# Epoch 203/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 2.4310e-05 - val_loss: 1.5826e-05
# Epoch 204/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 1.8049e-05 - val_loss: 1.5851e-05
# Epoch 205/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 1.6757e-05 - val_loss: 2.7819e-05
# Epoch 206/1000
# 3/3 [==============================] - 1s 500ms/step - loss: 1.6152e-05 - val_loss: 4.4770e-05
# Epoch 207/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 2.6540e-05 - val_loss: 1.1003e-05
# Epoch 208/1000
# 3/3 [==============================] - 1s 538ms/step - loss: 1.8121e-05 - val_loss: 1.3404e-05
# Epoch 209/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 1.7146e-05 - val_loss: 3.4181e-05
# Epoch 210/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 1.9377e-05 - val_loss: 4.8236e-05
# Epoch 211/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 2.8361e-05 - val_loss: 1.3233e-05
# Epoch 212/1000
# 3/3 [==============================] - 1s 496ms/step - loss: 1.5670e-05 - val_loss: 1.4987e-05
# Epoch 213/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 2.0643e-05 - val_loss: 1.9622e-05
# Epoch 214/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 1.8306e-05 - val_loss: 4.0968e-05
# Epoch 215/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 2.2895e-05 - val_loss: 1.4611e-05
# Epoch 216/1000
# 3/3 [==============================] - 1s 503ms/step - loss: 1.5544e-05 - val_loss: 1.5888e-05
# Epoch 217/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 1.7353e-05 - val_loss: 2.7086e-05
# Epoch 218/1000
# 3/3 [==============================] - 1s 525ms/step - loss: 1.7517e-05 - val_loss: 4.2569e-05
# Epoch 219/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 2.4797e-05 - val_loss: 1.2785e-05
# Epoch 220/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 1.5464e-05 - val_loss: 1.1988e-05
# Epoch 221/1000
# 3/3 [==============================] - 1s 525ms/step - loss: 1.2828e-05 - val_loss: 1.9037e-05
# Epoch 222/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 1.0149e-05 - val_loss: 2.7062e-05
# Epoch 223/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 8.6407e-06 - val_loss: 2.1565e-05
# Epoch 224/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 8.1267e-06 - val_loss: 1.1112e-05
# Epoch 225/1000
# 3/3 [==============================] - 2s 671ms/step - loss: 7.7811e-06 - val_loss: 8.5131e-06
# Epoch 226/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 9.0025e-06 - val_loss: 1.0482e-05
# Epoch 227/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 8.8295e-06 - val_loss: 1.4316e-05
# Epoch 228/1000
# 3/3 [==============================] - 1s 530ms/step - loss: 8.0492e-06 - val_loss: 1.2297e-05
# Epoch 229/1000
# 3/3 [==============================] - 1s 535ms/step - loss: 7.8010e-06 - val_loss: 8.9941e-06
# Epoch 230/1000
# 3/3 [==============================] - 2s 654ms/step - loss: 8.5246e-06 - val_loss: 8.4995e-06
# Epoch 231/1000
# 3/3 [==============================] - 1s 500ms/step - loss: 7.6544e-06 - val_loss: 1.0688e-05
# Epoch 232/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 6.6520e-06 - val_loss: 9.5178e-06
# Epoch 233/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 7.6036e-06 - val_loss: 1.1076e-05
# Epoch 234/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 6.8369e-06 - val_loss: 9.5612e-06
# Epoch 235/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 7.4642e-06 - val_loss: 1.1322e-05
# Epoch 236/1000
# 3/3 [==============================] - 2s 676ms/step - loss: 8.3048e-06 - val_loss: 8.0141e-06
# Epoch 237/1000
# 3/3 [==============================] - 2s 632ms/step - loss: 7.8687e-06 - val_loss: 6.8715e-06
# Epoch 238/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 8.5914e-06 - val_loss: 9.5609e-06
# Epoch 239/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 6.5324e-06 - val_loss: 1.3044e-05
# Epoch 240/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 6.3892e-06 - val_loss: 1.2710e-05
# Epoch 241/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 5.5720e-06 - val_loss: 8.6899e-06
# Epoch 242/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 5.8779e-06 - val_loss: 7.8096e-06
# Epoch 243/1000
# 3/3 [==============================] - 1s 545ms/step - loss: 6.3532e-06 - val_loss: 8.2216e-06
# Epoch 244/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 6.0168e-06 - val_loss: 9.9914e-06
# Epoch 245/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 5.6747e-06 - val_loss: 1.2509e-05
# Epoch 246/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 7.0184e-06 - val_loss: 1.2056e-05
# Epoch 247/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 6.1086e-06 - val_loss: 1.0866e-05
# Epoch 248/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 4.5793e-06 - val_loss: 9.1683e-06
# Epoch 249/1000
# 3/3 [==============================] - 1s 539ms/step - loss: 4.7009e-06 - val_loss: 8.1061e-06
# Epoch 250/1000
# 3/3 [==============================] - 1s 536ms/step - loss: 7.1614e-06 - val_loss: 8.2893e-06
# Epoch 251/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 4.5389e-06 - val_loss: 9.2718e-06
# Epoch 252/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 4.8814e-06 - val_loss: 9.0860e-06
# Epoch 253/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 4.7660e-06 - val_loss: 8.4336e-06
# Epoch 254/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 7.1048e-06 - val_loss: 8.6002e-06
# Epoch 255/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 5.7795e-06 - val_loss: 9.3742e-06
# Epoch 256/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 4.6403e-06 - val_loss: 8.1087e-06
# Epoch 257/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 6.1308e-06 - val_loss: 7.5814e-06
# Epoch 258/1000
# 3/3 [==============================] - 2s 669ms/step - loss: 6.2684e-06 - val_loss: 6.7160e-06
# Epoch 259/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 5.6083e-06 - val_loss: 7.4104e-06
# Epoch 260/1000
# 3/3 [==============================] - 1s 500ms/step - loss: 5.6859e-06 - val_loss: 1.3758e-05
# Epoch 261/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 5.7472e-06 - val_loss: 1.7623e-05
# Epoch 262/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 8.4725e-06 - val_loss: 1.2229e-05
# Epoch 263/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 7.6045e-06 - val_loss: 8.9283e-06
# Epoch 264/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 7.1278e-06 - val_loss: 7.9495e-06
# Epoch 265/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 7.1460e-06 - val_loss: 9.7988e-06
# Epoch 266/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 6.9180e-06 - val_loss: 1.0138e-05
# Epoch 267/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 6.5088e-06 - val_loss: 8.5115e-06
# Epoch 268/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 6.2989e-06 - val_loss: 7.9961e-06
# Epoch 269/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 7.4488e-06 - val_loss: 7.1307e-06
# Epoch 270/1000
# 3/3 [==============================] - 2s 671ms/step - loss: 7.1986e-06 - val_loss: 6.3005e-06
# Epoch 271/1000
# 3/3 [==============================] - 1s 548ms/step - loss: 6.0667e-06 - val_loss: 6.5244e-06
# Epoch 272/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 5.7667e-06 - val_loss: 6.9881e-06
# Epoch 273/1000
# 3/3 [==============================] - 1s 534ms/step - loss: 5.8787e-06 - val_loss: 6.5748e-06
# Epoch 274/1000
# 3/3 [==============================] - 2s 666ms/step - loss: 5.0449e-06 - val_loss: 5.6444e-06
# Epoch 275/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 5.8396e-06 - val_loss: 5.7675e-06
# Epoch 276/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 6.3565e-06 - val_loss: 6.2476e-06
# Epoch 277/1000
# 3/3 [==============================] - 1s 549ms/step - loss: 5.2213e-06 - val_loss: 6.2896e-06
# Epoch 278/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 6.2373e-06 - val_loss: 6.1969e-06
# Epoch 279/1000
# 3/3 [==============================] - 1s 500ms/step - loss: 5.5075e-06 - val_loss: 5.9211e-06
# Epoch 280/1000
# 3/3 [==============================] - 2s 556ms/step - loss: 5.5983e-06 - val_loss: 6.1646e-06
# Epoch 281/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 6.2211e-06 - val_loss: 6.6599e-06
# Epoch 282/1000
# 3/3 [==============================] - 1s 530ms/step - loss: 4.5085e-06 - val_loss: 7.0127e-06
# Epoch 283/1000
# 3/3 [==============================] - 1s 545ms/step - loss: 5.6705e-06 - val_loss: 7.5993e-06
# Epoch 284/1000
# 3/3 [==============================] - 1s 525ms/step - loss: 4.8474e-06 - val_loss: 6.9947e-06
# Epoch 285/1000
# 3/3 [==============================] - 1s 530ms/step - loss: 4.8131e-06 - val_loss: 6.2166e-06
# Epoch 286/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 5.5880e-06 - val_loss: 7.8115e-06
# Epoch 287/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 6.2834e-06 - val_loss: 1.0487e-05
# Epoch 288/1000
# 3/3 [==============================] - 1s 495ms/step - loss: 5.4856e-06 - val_loss: 9.0792e-06
# Epoch 289/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 5.0796e-06 - val_loss: 9.7898e-06
# Epoch 290/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 7.8220e-06 - val_loss: 1.0207e-05
# Epoch 291/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 9.4148e-06 - val_loss: 9.2135e-06
# Epoch 292/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 7.7856e-06 - val_loss: 7.7896e-06
# Epoch 293/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 5.6276e-06 - val_loss: 8.0398e-06
# Epoch 294/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 5.8746e-06 - val_loss: 8.2748e-06
# Epoch 295/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 5.2989e-06 - val_loss: 6.5013e-06
# Epoch 296/1000
# 3/3 [==============================] - 2s 671ms/step - loss: 4.8233e-06 - val_loss: 5.2643e-06
# Epoch 297/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 4.8467e-06 - val_loss: 5.6181e-06
# Epoch 298/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 6.5135e-06 - val_loss: 6.6568e-06
# Epoch 299/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 5.0497e-06 - val_loss: 6.7118e-06
# Epoch 300/1000
# 3/3 [==============================] - 1s 495ms/step - loss: 6.6888e-06 - val_loss: 8.4274e-06
# Epoch 301/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 4.8125e-06 - val_loss: 8.9087e-06
# Epoch 302/1000
# 3/3 [==============================] - 2s 820ms/step - loss: 7.4756e-06 - val_loss: 5.9994e-06
# Epoch 303/1000
# 3/3 [==============================] - 2s 555ms/step - loss: 6.2024e-06 - val_loss: 5.7314e-06
# Epoch 304/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 4.7669e-06 - val_loss: 6.1304e-06
# Epoch 305/1000
# 3/3 [==============================] - 1s 548ms/step - loss: 5.6211e-06 - val_loss: 6.0573e-06
# Epoch 306/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 4.3656e-06 - val_loss: 5.4969e-06
# Epoch 307/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 5.2637e-06 - val_loss: 5.2858e-06
# Epoch 308/1000
# 3/3 [==============================] - 2s 552ms/step - loss: 4.8576e-06 - val_loss: 5.4278e-06
# Epoch 309/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 4.9409e-06 - val_loss: 5.5808e-06
# Epoch 310/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 4.0398e-06 - val_loss: 5.5957e-06
# Epoch 311/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 4.2527e-06 - val_loss: 5.3178e-06
# Epoch 312/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 5.0160e-06 - val_loss: 5.5692e-06
# Epoch 313/1000
# 3/3 [==============================] - 2s 677ms/step - loss: 5.6243e-06 - val_loss: 5.2378e-06
# Epoch 314/1000
# 3/3 [==============================] - 1s 503ms/step - loss: 4.7129e-06 - val_loss: 6.6978e-06
# Epoch 315/1000
# 3/3 [==============================] - 1s 542ms/step - loss: 5.8024e-06 - val_loss: 6.6794e-06
# Epoch 316/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 5.1694e-06 - val_loss: 7.5889e-06
# Epoch 317/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 5.3402e-06 - val_loss: 5.3731e-06
# Epoch 318/1000
# 3/3 [==============================] - 2s 661ms/step - loss: 5.5136e-06 - val_loss: 4.8841e-06
# Epoch 319/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 4.5036e-06 - val_loss: 5.1447e-06
# Epoch 320/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 4.0019e-06 - val_loss: 5.2564e-06
# Epoch 321/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 3.8974e-06 - val_loss: 5.1910e-06
# Epoch 322/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 4.3168e-06 - val_loss: 4.8966e-06
# Epoch 323/1000
# 3/3 [==============================] - 2s 647ms/step - loss: 4.1961e-06 - val_loss: 4.8511e-06
# Epoch 324/1000
# 3/3 [==============================] - 2s 656ms/step - loss: 4.5495e-06 - val_loss: 4.3509e-06
# Epoch 325/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 5.2871e-06 - val_loss: 4.8985e-06
# Epoch 326/1000
# 3/3 [==============================] - 2s 552ms/step - loss: 4.0253e-06 - val_loss: 4.5826e-06
# Epoch 327/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 4.0099e-06 - val_loss: 5.0416e-06
# Epoch 328/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 4.4317e-06 - val_loss: 5.3403e-06
# Epoch 329/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 4.3039e-06 - val_loss: 4.6124e-06
# Epoch 330/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 4.4835e-06 - val_loss: 5.0342e-06
# Epoch 331/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 4.4854e-06 - val_loss: 5.2662e-06
# Epoch 332/1000
# 3/3 [==============================] - 1s 525ms/step - loss: 4.2480e-06 - val_loss: 5.1609e-06
# Epoch 333/1000
# 3/3 [==============================] - 1s 542ms/step - loss: 4.7661e-06 - val_loss: 4.5039e-06
# Epoch 334/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 4.9923e-06 - val_loss: 5.2464e-06
# Epoch 335/1000
# 3/3 [==============================] - 1s 535ms/step - loss: 4.5891e-06 - val_loss: 5.1666e-06
# Epoch 336/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 3.4771e-06 - val_loss: 5.3612e-06
# Epoch 337/1000
# 3/3 [==============================] - 1s 500ms/step - loss: 4.6802e-06 - val_loss: 4.6320e-06
# Epoch 338/1000
# 3/3 [==============================] - 2s 558ms/step - loss: 4.3497e-06 - val_loss: 6.0582e-06
# Epoch 339/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 4.7000e-06 - val_loss: 4.6332e-06
# Epoch 340/1000
# 3/3 [==============================] - 1s 550ms/step - loss: 5.3766e-06 - val_loss: 4.9580e-06
# Epoch 341/1000
# 3/3 [==============================] - 1s 550ms/step - loss: 4.5943e-06 - val_loss: 5.4801e-06
# Epoch 342/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 4.0653e-06 - val_loss: 5.7323e-06
# Epoch 343/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 4.1081e-06 - val_loss: 5.5939e-06
# Epoch 344/1000
# 3/3 [==============================] - 1s 543ms/step - loss: 4.2125e-06 - val_loss: 4.7041e-06
# Epoch 345/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 4.5025e-06 - val_loss: 5.5918e-06
# Epoch 346/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 4.3404e-06 - val_loss: 5.6481e-06
# Epoch 347/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 3.8844e-06 - val_loss: 4.8621e-06
# Epoch 348/1000
# 3/3 [==============================] - 2s 681ms/step - loss: 4.1195e-06 - val_loss: 4.1883e-06
# Epoch 349/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 3.7026e-06 - val_loss: 5.0090e-06
# Epoch 350/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 4.5030e-06 - val_loss: 4.4534e-06
# Epoch 351/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 3.6063e-06 - val_loss: 4.2859e-06
# Epoch 352/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 4.1242e-06 - val_loss: 4.3345e-06
# Epoch 353/1000
# 3/3 [==============================] - 1s 546ms/step - loss: 4.5138e-06 - val_loss: 4.4209e-06
# Epoch 354/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 4.2214e-06 - val_loss: 4.6390e-06
# Epoch 355/1000
# 3/3 [==============================] - 2s 661ms/step - loss: 3.9054e-06 - val_loss: 4.1133e-06
# Epoch 356/1000
# 3/3 [==============================] - 2s 652ms/step - loss: 4.8765e-06 - val_loss: 4.0257e-06
# Epoch 357/1000
# 3/3 [==============================] - 1s 547ms/step - loss: 4.3036e-06 - val_loss: 4.5698e-06
# Epoch 358/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 3.6706e-06 - val_loss: 4.5921e-06
# Epoch 359/1000
# 3/3 [==============================] - 1s 530ms/step - loss: 3.9431e-06 - val_loss: 4.4481e-06
# Epoch 360/1000
# 3/3 [==============================] - 2s 688ms/step - loss: 4.2158e-06 - val_loss: 3.6857e-06
# Epoch 361/1000
# 3/3 [==============================] - 1s 504ms/step - loss: 4.0394e-06 - val_loss: 4.1163e-06
# Epoch 362/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 3.3608e-06 - val_loss: 4.3732e-06
# Epoch 363/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 3.7615e-06 - val_loss: 3.8190e-06
# Epoch 364/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 3.6469e-06 - val_loss: 5.1857e-06
# Epoch 365/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 3.8777e-06 - val_loss: 4.5398e-06
# Epoch 366/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 5.3453e-06 - val_loss: 4.0089e-06
# Epoch 367/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 3.9861e-06 - val_loss: 4.5196e-06
# Epoch 368/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 4.4444e-06 - val_loss: 4.0599e-06
# Epoch 369/1000
# 3/3 [==============================] - 2s 690ms/step - loss: 3.7383e-06 - val_loss: 3.6333e-06
# Epoch 370/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 4.0061e-06 - val_loss: 4.7158e-06
# Epoch 371/1000
# 3/3 [==============================] - 1s 536ms/step - loss: 3.5038e-06 - val_loss: 4.4609e-06
# Epoch 372/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 3.7553e-06 - val_loss: 3.7223e-06
# Epoch 373/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 3.5888e-06 - val_loss: 4.1589e-06
# Epoch 374/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 3.9904e-06 - val_loss: 3.8114e-06
# Epoch 375/1000
# 3/3 [==============================] - 1s 503ms/step - loss: 3.7957e-06 - val_loss: 3.8807e-06
# Epoch 376/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 4.3867e-06 - val_loss: 8.0248e-06
# Epoch 377/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 5.7420e-06 - val_loss: 8.9714e-06
# Epoch 378/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 6.0330e-06 - val_loss: 8.3849e-06
# Epoch 379/1000
# 3/3 [==============================] - 1s 546ms/step - loss: 4.3146e-06 - val_loss: 5.7460e-06
# Epoch 380/1000
# 3/3 [==============================] - 2s 681ms/step - loss: 4.3542e-06 - val_loss: 3.5160e-06
# Epoch 381/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 3.9235e-06 - val_loss: 3.9143e-06
# Epoch 382/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 5.6430e-06 - val_loss: 1.1209e-05
# Epoch 383/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 5.8121e-06 - val_loss: 1.0177e-05
# Epoch 384/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 5.9880e-06 - val_loss: 3.8928e-06
# Epoch 385/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 5.4882e-06 - val_loss: 4.1714e-06
# Epoch 386/1000
# 3/3 [==============================] - 2s 702ms/step - loss: 4.6328e-06 - val_loss: 3.4570e-06
# Epoch 387/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 4.0910e-06 - val_loss: 4.5919e-06
# Epoch 388/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 4.1661e-06 - val_loss: 3.5059e-06
# Epoch 389/1000
# 3/3 [==============================] - 1s 536ms/step - loss: 3.6931e-06 - val_loss: 4.2507e-06
# Epoch 390/1000
# 3/3 [==============================] - 2s 664ms/step - loss: 3.4374e-06 - val_loss: 3.3541e-06
# Epoch 391/1000
# 3/3 [==============================] - 2s 656ms/step - loss: 4.1862e-06 - val_loss: 3.3329e-06
# Epoch 392/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 3.9899e-06 - val_loss: 3.4721e-06
# Epoch 393/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 3.6578e-06 - val_loss: 3.6936e-06
# Epoch 394/1000
# ...
# Epoch 858/1000
# 3/3 [==============================] - 3s 887ms/step - loss: 1.9092e-06 - val_loss: 1.7504e-06
# Epoch 859/1000
# 3/3 [==============================] - 2s 856ms/step - loss: 2.2435e-06 - val_loss: 1.8338e-06
# Epoch 860/1000
# 3/3 [==============================] - 2s 848ms/step - loss: 2.0915e-06 - val_loss: 1.8370e-06
# Epoch 861/1000
# 3/3 [==============================] - 2s 854ms/step - loss: 2.0952e-06 - val_loss: 1.9328e-06
# Epoch 862/1000
# 3/3 [==============================] - 2s 859ms/step - loss: 1.9504e-06 - val_loss: 1.8022e-06
# Epoch 863/1000
# 3/3 [==============================] - 3s 920ms/step - loss: 1.9623e-06 - val_loss: 1.7752e-06
# Epoch 864/1000
# 3/3 [==============================] - 2s 872ms/step - loss: 2.1190e-06 - val_loss: 1.7943e-06
# Epoch 865/1000
# 3/3 [==============================] - 3s 921ms/step - loss: 2.0278e-06 - val_loss: 1.7712e-06
# Epoch 866/1000
# 3/3 [==============================] - 3s 896ms/step - loss: 1.9136e-06 - val_loss: 1.7792e-06
# Epoch 867/1000
# 3/3 [==============================] - 3s 884ms/step - loss: 1.8772e-06 - val_loss: 1.8259e-06
# Epoch 868/1000
# 3/3 [==============================] - 3s 942ms/step - loss: 3.4210e-06 - val_loss: 2.3503e-06
# Epoch 869/1000
# 3/3 [==============================] - 3s 953ms/step - loss: 2.2340e-06 - val_loss: 2.4740e-06
# Epoch 870/1000
# 3/3 [==============================] - 3s 903ms/step - loss: 2.3177e-06 - val_loss: 1.9639e-06
# Epoch 871/1000
# 3/3 [==============================] - 3s 929ms/step - loss: 2.2363e-06 - val_loss: 1.9753e-06
# Epoch 872/1000
# 3/3 [==============================] - 3s 886ms/step - loss: 1.9324e-06 - val_loss: 1.7479e-06
# Epoch 873/1000
# 3/3 [==============================] - 2s 832ms/step - loss: 3.1389e-06 - val_loss: 2.0785e-06
# Epoch 874/1000
# 3/3 [==============================] - 2s 862ms/step - loss: 2.1954e-06 - val_loss: 1.7786e-06
# Epoch 875/1000
# 3/3 [==============================] - 2s 855ms/step - loss: 2.0377e-06 - val_loss: 2.0127e-06
# Epoch 876/1000
# 3/3 [==============================] - 3s 926ms/step - loss: 1.8538e-06 - val_loss: 2.0630e-06
# Epoch 877/1000
# 3/3 [==============================] - 3s 944ms/step - loss: 1.9682e-06 - val_loss: 2.0900e-06
# Epoch 878/1000
# 3/3 [==============================] - 3s 882ms/step - loss: 1.9832e-06 - val_loss: 2.5058e-06
# Epoch 879/1000
# 3/3 [==============================] - 3s 925ms/step - loss: 1.9477e-06 - val_loss: 2.0186e-06
# Epoch 880/1000
# 3/3 [==============================] - 3s 892ms/step - loss: 2.0951e-06 - val_loss: 2.4331e-06
# Epoch 881/1000
# 3/3 [==============================] - 3s 887ms/step - loss: 2.0643e-06 - val_loss: 2.4747e-06
# Epoch 882/1000
# 3/3 [==============================] - 3s 901ms/step - loss: 1.9128e-06 - val_loss: 2.0010e-06
# Epoch 883/1000
# 3/3 [==============================] - 3s 936ms/step - loss: 1.8380e-06 - val_loss: 2.7382e-06
# Epoch 884/1000
# 3/3 [==============================] - 3s 865ms/step - loss: 2.0006e-06 - val_loss: 2.0287e-06
# Epoch 885/1000
# 3/3 [==============================] - 3s 930ms/step - loss: 2.0160e-06 - val_loss: 2.4048e-06
# Epoch 886/1000
# 3/3 [==============================] - 3s 907ms/step - loss: 1.7983e-06 - val_loss: 1.8973e-06
# Epoch 887/1000
# 3/3 [==============================] - 3s 878ms/step - loss: 1.8623e-06 - val_loss: 1.8305e-06
# Epoch 888/1000
# 3/3 [==============================] - 3s 864ms/step - loss: 1.9125e-06 - val_loss: 2.0236e-06
# Epoch 889/1000
# 3/3 [==============================] - 3s 919ms/step - loss: 1.9011e-06 - val_loss: 1.9305e-06
# Epoch 890/1000
# 3/3 [==============================] - 3s 906ms/step - loss: 1.9329e-06 - val_loss: 2.0820e-06
# Epoch 891/1000
# 3/3 [==============================] - 3s 890ms/step - loss: 1.8710e-06 - val_loss: 1.9390e-06
# Epoch 892/1000
# 3/3 [==============================] - 3s 865ms/step - loss: 1.9192e-06 - val_loss: 1.9538e-06
# Epoch 893/1000
# 3/3 [==============================] - 3s 888ms/step - loss: 1.8686e-06 - val_loss: 2.0076e-06
# Epoch 894/1000
# 3/3 [==============================] - 3s 974ms/step - loss: 1.9353e-06 - val_loss: 1.8457e-06
# Epoch 895/1000
# 3/3 [==============================] - 3s 955ms/step - loss: 1.9754e-06 - val_loss: 1.9152e-06
# Epoch 896/1000
# 3/3 [==============================] - 3s 907ms/step - loss: 1.9145e-06 - val_loss: 1.8808e-06
# Epoch 897/1000
# 3/3 [==============================] - 3s 909ms/step - loss: 1.9224e-06 - val_loss: 1.9182e-06
# Epoch 898/1000
# 3/3 [==============================] - 3s 929ms/step - loss: 1.8520e-06 - val_loss: 1.8167e-06
# Epoch 899/1000
# 3/3 [==============================] - 3s 950ms/step - loss: 1.7982e-06 - val_loss: 1.7471e-06
# Epoch 900/1000
# 3/3 [==============================] - 3s 900ms/step - loss: 1.8063e-06 - val_loss: 2.3340e-06
# Epoch 901/1000
# 3/3 [==============================] - 3s 877ms/step - loss: 1.8240e-06 - val_loss: 1.7390e-06
# Epoch 902/1000
# 3/3 [==============================] - 2s 869ms/step - loss: 2.0710e-06 - val_loss: 1.7479e-06
# Epoch 903/1000
# 3/3 [==============================] - 2s 919ms/step - loss: 1.8919e-06 - val_loss: 1.7011e-06
# Epoch 904/1000
# 3/3 [==============================] - 2s 919ms/step - loss: 1.9080e-06 - val_loss: 1.7620e-06
# Epoch 905/1000
# 3/3 [==============================] - 2s 911ms/step - loss: 2.0703e-06 - val_loss: 1.6961e-06
# Epoch 906/1000
# 3/3 [==============================] - 3s 1s/step - loss: 1.6693e-06 - val_loss: 1.6816e-06
# Epoch 907/1000
# 3/3 [==============================] - 2s 937ms/step - loss: 1.9773e-06 - val_loss: 1.7160e-06
# Epoch 908/1000
# 3/3 [==============================] - 2s 892ms/step - loss: 2.1729e-06 - val_loss: 1.7185e-06
# Epoch 909/1000
# 3/3 [==============================] - 2s 860ms/step - loss: 1.7042e-06 - val_loss: 1.7843e-06
# Epoch 910/1000
# 3/3 [==============================] - 2s 885ms/step - loss: 1.8584e-06 - val_loss: 1.6878e-06
# Epoch 911/1000
# 3/3 [==============================] - 2s 753ms/step - loss: 1.8062e-06 - val_loss: 1.7598e-06
# Epoch 912/1000
# 3/3 [==============================] - 2s 738ms/step - loss: 1.8209e-06 - val_loss: 1.7232e-06
# Epoch 913/1000
# 3/3 [==============================] - 2s 681ms/step - loss: 1.8606e-06 - val_loss: 2.0291e-06
# Epoch 914/1000
# 3/3 [==============================] - 2s 751ms/step - loss: 1.7851e-06 - val_loss: 1.7174e-06
# Epoch 915/1000
# 3/3 [==============================] - 2s 765ms/step - loss: 1.7503e-06 - val_loss: 1.8615e-06
# Epoch 916/1000
# 3/3 [==============================] - 2s 762ms/step - loss: 1.6828e-06 - val_loss: 1.8396e-06
# Epoch 917/1000
# 3/3 [==============================] - 3s 837ms/step - loss: 1.7465e-06 - val_loss: 1.7578e-06
# Epoch 918/1000
# 3/3 [==============================] - 3s 1s/step - loss: 2.8561e-06 - val_loss: 2.1254e-06
# Epoch 919/1000
# 3/3 [==============================] - 2s 927ms/step - loss: 2.2043e-06 - val_loss: 1.8748e-06
# Epoch 920/1000
# 3/3 [==============================] - 2s 938ms/step - loss: 1.9148e-06 - val_loss: 2.3240e-06
# Epoch 921/1000
# 3/3 [==============================] - 2s 915ms/step - loss: 1.8297e-06 - val_loss: 2.0975e-06
# Epoch 922/1000
# 3/3 [==============================] - 2s 943ms/step - loss: 1.8074e-06 - val_loss: 2.3228e-06
# Epoch 923/1000
# 3/3 [==============================] - 2s 873ms/step - loss: 1.8596e-06 - val_loss: 2.2959e-06
# Epoch 924/1000
# 3/3 [==============================] - 2s 875ms/step - loss: 2.0159e-06 - val_loss: 2.1806e-06
# Epoch 925/1000
# 3/3 [==============================] - 2s 860ms/step - loss: 2.0961e-06 - val_loss: 1.9806e-06
# Epoch 926/1000
# 3/3 [==============================] - 3s 938ms/step - loss: 1.8240e-06 - val_loss: 3.1435e-06
# Epoch 927/1000
# 3/3 [==============================] - 3s 956ms/step - loss: 1.8322e-06 - val_loss: 2.2684e-06
# Epoch 928/1000
# 3/3 [==============================] - 2s 917ms/step - loss: 1.8384e-06 - val_loss: 2.6975e-06
# Epoch 929/1000
# 3/3 [==============================] - 2s 890ms/step - loss: 1.9609e-06 - val_loss: 2.6050e-06
# Epoch 930/1000
# 3/3 [==============================] - 2s 916ms/step - loss: 2.0288e-06 - val_loss: 1.9895e-06
# Epoch 931/1000
# 3/3 [==============================] - 2s 846ms/step - loss: 1.9203e-06 - val_loss: 3.0934e-06
# Epoch 932/1000
# 3/3 [==============================] - 2s 890ms/step - loss: 1.7731e-06 - val_loss: 1.6936e-06
# Epoch 933/1000
# 3/3 [==============================] - 2s 875ms/step - loss: 1.9036e-06 - val_loss: 2.6288e-06
# Epoch 934/1000
# 3/3 [==============================] - 2s 831ms/step - loss: 1.9927e-06 - val_loss: 1.8160e-06
# Epoch 935/1000
# 3/3 [==============================] - 2s 857ms/step - loss: 2.0678e-06 - val_loss: 2.3110e-06
# Epoch 936/1000
# 3/3 [==============================] - 2s 781ms/step - loss: 1.9938e-06 - val_loss: 1.7424e-06
# Epoch 937/1000
# 3/3 [==============================] - 2s 726ms/step - loss: 2.0760e-06 - val_loss: 2.3497e-06
# Epoch 938/1000
# 3/3 [==============================] - 2s 697ms/step - loss: 1.9004e-06 - val_loss: 1.8040e-06
# Epoch 939/1000
# 3/3 [==============================] - 2s 750ms/step - loss: 1.9140e-06 - val_loss: 2.3249e-06
# Epoch 940/1000
# 3/3 [==============================] - 2s 726ms/step - loss: 1.8104e-06 - val_loss: 1.7740e-06
# Epoch 941/1000
# 3/3 [==============================] - 2s 766ms/step - loss: 1.8031e-06 - val_loss: 1.9304e-06
# Epoch 942/1000
# 3/3 [==============================] - 3s 962ms/step - loss: 1.7871e-06 - val_loss: 1.6815e-06
# Epoch 943/1000
# 3/3 [==============================] - 2s 856ms/step - loss: 1.8380e-06 - val_loss: 1.7002e-06
# Epoch 944/1000
# 3/3 [==============================] - 2s 859ms/step - loss: 1.8377e-06 - val_loss: 2.0164e-06
# Epoch 945/1000
# 3/3 [==============================] - 2s 862ms/step - loss: 1.9049e-06 - val_loss: 1.8146e-06
# Epoch 946/1000
# 3/3 [==============================] - 2s 852ms/step - loss: 1.8749e-06 - val_loss: 1.7445e-06
# Epoch 947/1000
# 3/3 [==============================] - 2s 844ms/step - loss: 1.7819e-06 - val_loss: 1.6847e-06
# Epoch 948/1000
# 3/3 [==============================] - 2s 824ms/step - loss: 1.7715e-06 - val_loss: 1.7279e-06
# Epoch 949/1000
# 3/3 [==============================] - 2s 693ms/step - loss: 1.6609e-06 - val_loss: 1.7502e-06
# Epoch 950/1000
# 3/3 [==============================] - 3s 993ms/step - loss: 1.7358e-06 - val_loss: 1.6706e-06
# Epoch 951/1000
# 3/3 [==============================] - 2s 852ms/step - loss: 1.6782e-06 - val_loss: 1.7421e-06
# Epoch 952/1000
# 3/3 [==============================] - 3s 1s/step - loss: 1.8448e-06 - val_loss: 1.6252e-06
# Epoch 953/1000
# 3/3 [==============================] - 2s 967ms/step - loss: 1.7861e-06 - val_loss: 1.7009e-06
# Epoch 954/1000
# 3/3 [==============================] - 2s 967ms/step - loss: 1.6767e-06 - val_loss: 1.6441e-06
# Epoch 955/1000
# 3/3 [==============================] - 2s 934ms/step - loss: 1.7398e-06 - val_loss: 1.7002e-06
# Epoch 956/1000
# 3/3 [==============================] - 3s 931ms/step - loss: 1.7623e-06 - val_loss: 1.7396e-06
# Epoch 957/1000
# 3/3 [==============================] - 2s 918ms/step - loss: 1.7206e-06 - val_loss: 1.7876e-06
# Epoch 958/1000
# 3/3 [==============================] - 2s 885ms/step - loss: 1.7237e-06 - val_loss: 1.8664e-06
# Epoch 959/1000
# 3/3 [==============================] - 2s 871ms/step - loss: 1.7273e-06 - val_loss: 1.7260e-06
# Epoch 960/1000
# 3/3 [==============================] - 2s 924ms/step - loss: 1.7093e-06 - val_loss: 1.7043e-06
# Epoch 961/1000
# 3/3 [==============================] - 2s 903ms/step - loss: 1.7375e-06 - val_loss: 1.6367e-06
# Epoch 962/1000
# 3/3 [==============================] - 2s 912ms/step - loss: 1.6257e-06 - val_loss: 1.7192e-06
# Epoch 963/1000
# 3/3 [==============================] - 2s 890ms/step - loss: 1.6670e-06 - val_loss: 1.7556e-06
# Epoch 964/1000
# 3/3 [==============================] - 2s 918ms/step - loss: 1.7592e-06 - val_loss: 1.7666e-06
# Epoch 965/1000
# 3/3 [==============================] - 2s 939ms/step - loss: 1.6733e-06 - val_loss: 1.7567e-06
# Epoch 966/1000
# 3/3 [==============================] - 2s 958ms/step - loss: 1.9766e-06 - val_loss: 1.8138e-06
# Epoch 967/1000
# 3/3 [==============================] - 2s 822ms/step - loss: 1.7689e-06 - val_loss: 1.7015e-06
# Epoch 968/1000
# 3/3 [==============================] - 2s 890ms/step - loss: 1.6436e-06 - val_loss: 1.6571e-06
# Epoch 969/1000
# 3/3 [==============================] - 2s 881ms/step - loss: 1.6688e-06 - val_loss: 1.6992e-06
# Epoch 970/1000
# 3/3 [==============================] - 2s 887ms/step - loss: 1.7901e-06 - val_loss: 1.7130e-06
# Epoch 971/1000
# 3/3 [==============================] - 2s 867ms/step - loss: 2.7284e-06 - val_loss: 1.6974e-06
# Epoch 972/1000
# 3/3 [==============================] - 2s 872ms/step - loss: 1.8091e-06 - val_loss: 2.2865e-06
# Epoch 973/1000
# 3/3 [==============================] - 2s 834ms/step - loss: 2.0420e-06 - val_loss: 2.0347e-06
# Epoch 974/1000
# 3/3 [==============================] - 2s 867ms/step - loss: 1.7001e-06 - val_loss: 2.8287e-06
# Epoch 975/1000
# 3/3 [==============================] - 2s 826ms/step - loss: 1.7523e-06 - val_loss: 2.1579e-06
# Epoch 976/1000
# 3/3 [==============================] - 2s 680ms/step - loss: 1.8017e-06 - val_loss: 2.7299e-06
# Epoch 977/1000
# 3/3 [==============================] - 2s 738ms/step - loss: 1.8842e-06 - val_loss: 2.5338e-06
# Epoch 978/1000
# 3/3 [==============================] - 2s 840ms/step - loss: 2.0588e-06 - val_loss: 2.3748e-06
# Epoch 979/1000
# 3/3 [==============================] - 2s 851ms/step - loss: 2.0914e-06 - val_loss: 3.0761e-06
# Epoch 980/1000
# 3/3 [==============================] - 2s 833ms/step - loss: 1.7893e-06 - val_loss: 1.8922e-06
# Epoch 981/1000
# 3/3 [==============================] - 2s 708ms/step - loss: 1.7443e-06 - val_loss: 2.2697e-06
# Epoch 982/1000
# 3/3 [==============================] - 2s 829ms/step - loss: 1.8863e-06 - val_loss: 2.1151e-06
# Epoch 983/1000
# 3/3 [==============================] - 3s 914ms/step - loss: 1.8651e-06 - val_loss: 2.0654e-06
# Epoch 984/1000
# 3/3 [==============================] - 3s 936ms/step - loss: 1.7669e-06 - val_loss: 2.2399e-06
# Epoch 985/1000
# 3/3 [==============================] - 2s 796ms/step - loss: 1.8325e-06 - val_loss: 2.0979e-06
# Epoch 986/1000
# 3/3 [==============================] - 3s 903ms/step - loss: 1.7522e-06 - val_loss: 2.1147e-06
# Epoch 987/1000
# 3/3 [==============================] - 3s 936ms/step - loss: 1.9329e-06 - val_loss: 1.8452e-06
# Epoch 988/1000
# 3/3 [==============================] - 3s 958ms/step - loss: 1.7427e-06 - val_loss: 1.8378e-06
# Epoch 989/1000
# 3/3 [==============================] - 2s 802ms/step - loss: 1.9302e-06 - val_loss: 2.0496e-06
# Epoch 990/1000
# 3/3 [==============================] - 3s 858ms/step - loss: 1.7899e-06 - val_loss: 1.8552e-06
# Epoch 991/1000
# 3/3 [==============================] - 2s 806ms/step - loss: 1.7514e-06 - val_loss: 2.0036e-06
# Epoch 992/1000
# 3/3 [==============================] - 3s 890ms/step - loss: 1.8206e-06 - val_loss: 2.2816e-06
# Epoch 993/1000
# 3/3 [==============================] - 2s 922ms/step - loss: 1.8561e-06 - val_loss: 1.7348e-06
# Epoch 994/1000
# 3/3 [==============================] - 2s 954ms/step - loss: 1.8937e-06 - val_loss: 1.8472e-06
# Epoch 995/1000
# 3/3 [==============================] - 3s 1s/step - loss: 1.8765e-06 - val_loss: 1.6009e-06
# Epoch 996/1000
# 3/3 [==============================] - 3s 877ms/step - loss: 1.8822e-06 - val_loss: 1.7320e-06
# Epoch 997/1000
# 3/3 [==============================] - 3s 945ms/step - loss: 1.8215e-06 - val_loss: 2.0444e-06
# Epoch 998/1000
# 3/3 [==============================] - 3s 875ms/step - loss: 1.8487e-06 - val_loss: 1.8547e-06
# Epoch 999/1000
# 3/3 [==============================] - 3s 947ms/step - loss: 1.7592e-06 - val_loss: 1.6745e-06
# Epoch 1000/1000
# 3/3 [==============================] - 2s 835ms/step - loss: 1.9231e-06 - val_loss: 1.8442e-06
# INFO:tensorflow:Assets written to: /home/user/workdir/CMAQ_Emulator/main/src/model/o3_prediction/v6/final_model(adjusted_v3)/assets
# INFO:tensorflow:Assets written to: /home/user/workdir/CMAQ_Emulator/main/src/model/o3_prediction/v6/final_model(adjusted_v3)/assets
# ' 16min '

# %%
plot_loss(history)

# %% [markdown]
# # Prediction & Performance

# %%
# 2D Map 결과 도출을 위한 지도 파라미터 세팅
proj = '+proj=lcc +lat_1=30 +lat_2=60 +lon_1=126 +lat_0=38 +lon_0=126 +ellps=GRS80 +units=m'
atob = {
    0: 'G', 1: 'F', 2: 'K', 3: 'J', 4: 'E', 5: 'D',
    6: 'O', 7: 'C', 8: 'A', 9: 'Q', 10: 'P', 11: 'B',
    12: 'M', 13: 'L', 14: 'N', 15: 'I', 16: 'H'}
region_columns = {
    'A': 'Seoul City', 'B': 'Incheon City', 'C': 'Busan City', 'D': 'Daegu City',
    'E': 'Gwangju City', 'F': 'Gyeonggi-do', 'G': 'Gangwon-do', 'H': 'Chungbuk-do',
    'I': 'Chungnam-do', 'J': 'Gyeongbuk-do', 'K': 'Gyeongnam-do', 'L': 'Jeonbuk-do',
    'M': 'Jeonnam-do', 'N': 'Jeju-do', 'O': 'Daejeon City', 'P': 'Ulsan City', 'Q': 'Sejong City'}

def get_ctprvn_map() -> gpd.GeoDataFrame:
    path = '/home/user/workdir/CMAQ_Emulator/main/resources/geom/ctp_rvn.shp'
    ctprvn = gpd.GeoDataFrame.from_file(path, encoding='cp949')
    ctprvn.crs = 'EPSG:5179'
    return ctprvn

def get_base_raster(ctprvn:gpd.GeoDataFrame) -> gpd.GeoDataFrame:
    points = [Point(i, j)
                for i in range(-180000, -180000 + 9000 * 67, 9000)
                for j in range(-585000, -585000 + 9000 * 82, 9000)]
    grid_data = gpd.GeoDataFrame(points, geometry='geometry', columns=['geometry'])
    grid_data.crs = ctprvn.to_crs(proj).crs
    grid_data.loc[:,'x_m'] = grid_data.geometry.x
    grid_data.loc[:,'y_m'] = grid_data.geometry.y
    grid_data.loc[:,'value'] = 0
    grid_data.loc[:,'index'] = grid_data.index
    return grid_data

def get_region_pixel_indices() -> list:
    ctprvn = get_ctprvn_map()
    grid_data = get_base_raster(ctprvn)
 
    cities = {
        0: '강원도', 1: '경기도', 2: '경상남도', 3: '경상북도',
        4: '광주광역시', 5: '대구광역시', 6: '대전광역시', 7: '부산광역시',
        8: '서울특별시', 9: '세종특별자치시', 10: '울산광역시', 11: '인천광역시',
        12: '전라남도', 13: '전라북도', 14: '제주특별자치도', 15: '충청남도',
        16: '충청북도'
    }

    gdf_joined_loc = ['CTPRVN_CD', 'CTP_ENG_NM', 'CTP_KOR_NM', 'index_right0']
    gdf_joined = gpd.sjoin(ctprvn, grid_data.to_crs(5179), predicate='contains')

    indices = gpd.GeoDataFrame(pd.merge(
        left=grid_data, right=gdf_joined.loc[:,gdf_joined_loc], 
        how='left', left_on='index', right_on='index_right0'
    ), geometry='geometry').dropna()
    pixel_indices = \
        [[(idx%82, idx//82) for idx in indices.loc[indices.CTP_KOR_NM==cities[region]].index.tolist()]
         for region, _ in cities.items()]
    return pixel_indices

ctprvn = get_ctprvn_map()
ctprvn_proj = ctprvn.to_crs(proj)

# 건국대(서울대)에서 제공한 대한민국 국토 grid 정보
grid_alloc = (
    pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/geom/grid_allocation.csv') # load grid allocation data
    .sort_values(by=['Row', 'Column', 'Ratio'], ascending=[True, True, False]) # sort by row, column, ratio
    .drop_duplicates(subset=['Row', 'Column'], keep='first') # drop duplicates
    .reset_index(drop=True) # reset index
)

# 정부에서 배포하는 대한민국 국토 grid 정보
pixel_indices = get_region_pixel_indices()
total_index = []
for idx, grids in enumerate(pixel_indices):
    for grid in grids:
        total_index.append([
            grid[1], grid[0], 100.0, atob[idx], region_columns[atob[idx]]
        ])
total_index = pd.DataFrame(total_index, columns=grid_alloc.columns)

# 두 기관에서 주는 grid에 한두픽셀씩 비어있는 부분이 있어, 두 기관 데이터를 모두 참조하여 중복되는 픽셀을 정리 후 최종 국토 grid 정보를 취득
grid_alloc = pd.concat([
    grid_alloc.drop(columns=['Ratio', 'Region_Name']),
    total_index.drop(columns=['Ratio', 'Region_Name'])
]).sort_values(by=['Region_Code']).drop_duplicates().reset_index(drop=True)
grid_alloc[['Row', 'Column']] = grid_alloc[['Row', 'Column']] - 1

row_indices, col_indices = zip(*grid_alloc[['Row', 'Column']].values)
offset_x, offset_y = 4500, 4500 # 지도 위치 맞추기

# 마스킹 처리
mask = np.zeros((82, 67))
mask[row_indices, col_indices] = 1

cmap_white = mpl.colormaps['jet']
cmap_white.set_under('white')

# %%
test_split = 0.4  # 테스트 데이터 비율 (20%)
random_seed = 42  # 랜덤 시드
model = tf.keras.models.load_model('/home/user/workdir/CMAQ_Emulator/main/src/model/o3_prediction/v6/final_model(adjusted_v3)')

pred_emis_data = []

# Load Test Data
dataset_2013 = pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/ctrl/dataset_for_o3_interaction_v2.csv')
ctrl_data = pd.concat([dataset_2013], axis=0)
ctrl_data = ctrl_data.reset_index(drop=True).values
base_path_2013 = "/home/user/workdir/CMAQ_Emulator/main/datasets/concentration/2013"
conc_path = []
for i in range(1, 120): 
    conc_path.append(os.path.join(base_path_2013, '1.00', f'ACONC.{i}'))
conc_data = []
for path in conc_path:
    with nc.Dataset(path) as f:
        conc_data.append(f.variables['O3'][:].data.squeeze())  # ncf 파일 내 목적변수를 지정 
conc_data = np.array(conc_data).reshape(len(conc_path), 82, 67, 1)
    
pred_emis_data = ctrl_data[:, :17*7]

_, X_emis_test, _, y_test = train_test_split(pred_emis_data, conc_data, test_size=test_split, random_state=random_seed)

y_preds = model.predict([X_emis_test])
y_pred = y_preds.squeeze()
y_true = y_test.squeeze()
# Out:
# 2025-03-05 17:04:20.719072: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13769 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:19:00.0, compute capability: 8.6
# 2025-03-05 17:04:20.720644: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13769 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1a:00.0, compute capability: 8.6
# 2025-03-05 17:04:20.722121: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 13769 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:67:00.0, compute capability: 8.6
# 2025-03-05 17:04:20.725494: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 13700 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:68:00.0, compute capability: 8.6
# 2025-03-05 17:04:26.017446: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2/2 [==============================] - 25s 9s/step

# %%
mask_expanded = np.repeat(mask[np.newaxis, :, :], repeats=y_true.shape[0], axis=0) # (24, 82, 67)

pred_conc_map_w_lines = np.where(mask_expanded == 1, y_pred, 0)  # 마스킹 적용
true_conc_map_w_lines = np.where(mask_expanded == 1, y_true, 0) # 마스킹 적용
print(y_pred.shape)
print(y_true.shape)
print(pred_conc_map_w_lines.shape)
print(true_conc_map_w_lines.shape)
# Out:
# (48, 82, 67)
# (48, 82, 67)
# (48, 82, 67)
# (48, 82, 67)

# %%
def plot_scatter(ax, y_true, y_pred):
    r_x, r_y = np.polyfit(y_true, y_pred, 1)
    ax.hist2d(
        y_true, y_pred,
        bins=150, cmap='jet', cmin=1,
        norm=mpl.colors.LogNorm(vmin=1, vmax=1000),
    )
    ax.plot(
        y_true, r_x*y_true + r_y,
        color='red', label=f"y={r_x:.4f}x+{r_y:.4f}")
    r2 = r2_score(y_true, y_pred)
    ax.text(
        0.05, 0.95, f"$R^2={r2:.4f}$ \nSlope={r_x:.4f}\nIntercept={r_y:.4f}",
        verticalalignment='top', horizontalalignment='left',
        transform=ax.transAxes, fontsize=11
    )
    ax.grid(alpha=0.25)
    return ax

def get_score(y_true, y_pred):
    batch_size = y_true.shape[0]
    y_true = y_true.reshape(batch_size, -1)
    y_pred = y_pred.reshape(batch_size, -1)
    y_norm_err = np.abs(y_true - y_pred) / np.mean(y_true, axis=1, keepdims=True)
    y_err_mean = np.mean(y_norm_err, axis=1)
    y_err_std = np.percentile(y_norm_err, q=5, axis=1)
    return y_err_mean, y_err_std

# %%
print(y_pred.shape)
print(y_true.shape)
print(pred_conc_map_w_lines.shape)
print(true_conc_map_w_lines.shape)
# Out:
# (48, 82, 67)
# (48, 82, 67)
# (48, 82, 67)
# (48, 82, 67)

# %%
y_true_modi = true_conc_map_w_lines.reshape(-1)
y_pred_modi = pred_conc_map_w_lines.reshape(-1)

fig, axes = plt.subplots(1, 1, figsize=(5, 5), dpi=300)
axes = plot_scatter(axes, y_true_modi, y_pred_modi)
axes.grid(alpha=0.25)
axes.set_title("True vs. Pred scatter plot")
axes.set_xlabel('True O3 [$\mu \mathrm{g}/\mathrm{m}^3$]')
axes.set_ylabel('Pred O3 [$\mu \mathrm{g}/\mathrm{m}^3$]')
cbaxes = axes.inset_axes([0.5, 0.2, 0.35, 0.03])
cb = plt.colorbar(
    mpl.cm.ScalarMappable(norm=mpl.colors.LogNorm(vmin=1, vmax=1000), cmap='jet'),
    cax=cbaxes, label='Number of samples', orientation='horizontal')
cb.set_label(label='Number of samples', fontsize=10)

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 6), dpi=300)
score, score_std = get_score(true_conc_map_w_lines, pred_conc_map_w_lines)
label_text = f'NMAE: {np.mean(score):.3f}±{np.std(score):.3f}'

axes.bar(np.arange(y_test.shape[0]), score, yerr=score_std, label=label_text, capsize=2)
axes.set_xticks(np.arange(y_test.shape[0]), range(y_test.shape[0]))
axes.grid(alpha=0.25)
axes.legend()
axes.set_title("NMAE of Cond. U-Net Nitrate")
axes.set_xlabel('Scenario')
axes.set_ylabel('NMAE [%]')
plt.show()

# %%
# np.set_printoptions(threshold=sys.maxsize)
# print(true_conc_map_w_lines[17])

# %%
cmap_with_white = plt.get_cmap('jet').copy()   # 예: jet 컬러맵 복사
cmap_with_white.set_bad('white')               # 마스킹된 부분을 흰색으로

def plot_prediction_loss(y_true, y_pred, num_samples=1, indices=-1):
    if indices == -1 or indices < 0:
        indices = np.random.choice(len(y_true), num_samples, replace=False)
    else:
        index = indices
        indices = [index]
    
    # (예시) "선택된 인덱스들"만 고려한 local_min/local_max
    local_min = min(y_true[indices].min(), y_pred[indices].min())
    local_max = max(y_true[indices].max(), y_pred[indices].max())
    local_diff = np.abs(y_true[indices] - y_pred[indices])
    local_max = max(local_max, local_diff.max())

    fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))
    if num_samples == 1:
        axes = axes[np.newaxis, :]  # (1, 3) 형태로 맞춤

    # 지도 투영 좌표 범위
    x_min = -180000 + offset_x
    x_max =  414000 + offset_x
    y_min = -585000 + offset_y
    y_max =  144000 + offset_y

    x_ticks = np.linspace(x_min, x_max, 8)
    x_labels = [str(i) for i in range(124, 132)]
    y_ticks = np.linspace(y_min, y_max, 8)
    y_labels = [str(i) for i in range(32, 40)]

    # "0 이하이면 흰색"으로 표시하고 싶다면:
    threshold = 0.0005  # 또는 원하는 임계값(예: local_min 등)

    for i, idx in enumerate(indices):
        # (A) True 데이터
        data_true = y_true[idx][::-1]
        # 2) 마스킹: threshold 이하 부분을 마스크
        masked_true = np.ma.masked_where(data_true <= threshold, data_true)
        
        im_true = axes[i, 0].imshow(
            masked_true,
            cmap=cmap_with_white,          # 마스킹 컬러맵
            extent=(x_min, x_max, y_min, y_max),
            vmin=threshold,                # 컬러 스케일 최소
            vmax=local_max                 # 컬러 스케일 최대
        )
        ctprvn_proj.boundary.plot(
            ax=axes[i, 0], edgecolor='black', facecolor='none', linewidth=1, alpha=0.25
        )
        axes[i, 0].set_title(f"True (#{idx})")
        axes[i, 0].set_xlabel('Longitude [°]')
        axes[i, 0].set_ylabel('Latitude [°]')
        axes[i, 0].set_xlim(x_min, x_max)
        axes[i, 0].set_ylim(y_min, y_max)
        axes[i, 0].set_xticks(x_ticks)
        axes[i, 0].set_yticks(y_ticks)
        axes[i, 0].set_xticklabels(x_labels)
        axes[i, 0].set_yticklabels(y_labels)
        axes[i, 0].grid(alpha=0.25, color='silver')

        # (B) Predicted
        data_pred = y_pred[idx][::-1]
        masked_pred = np.ma.masked_where(data_pred <= threshold, data_pred)

        im_pred = axes[i, 1].imshow(
            masked_pred,
            cmap=cmap_with_white,
            extent=(x_min, x_max, y_min, y_max),
            vmin=threshold,
            vmax=local_max
        )
        ctprvn_proj.boundary.plot(
            ax=axes[i, 1], edgecolor='black', facecolor='none', linewidth=1, alpha=0.25
        )
        axes[i, 1].set_title(f"Predicted (#{idx})")
        axes[i, 1].set_xlabel('Longitude [°]')
        axes[i, 1].set_ylabel('Latitude [°]')
        axes[i, 1].set_xlim(x_min, x_max)
        axes[i, 1].set_ylim(y_min, y_max)
        axes[i, 1].set_xticks(x_ticks)
        axes[i, 1].set_yticks(y_ticks)
        axes[i, 1].set_xticklabels(x_labels)
        axes[i, 1].set_yticklabels(y_labels)
        axes[i, 1].grid(alpha=0.25, color='silver')

        # (C) Difference
        data_diff = np.abs(y_true[idx] - y_pred[idx])[::-1]
        masked_diff = np.ma.masked_where(data_diff <= threshold, data_diff)

        im_diff = axes[i, 2].imshow(
            masked_diff,
            cmap=cmap_with_white,
            extent=(x_min, x_max, y_min, y_max),
            vmin=threshold,
            vmax=local_max
        )
        ctprvn_proj.boundary.plot(
            ax=axes[i, 2], edgecolor='black', facecolor='none', linewidth=1, alpha=0.25
        )
        axes[i, 2].set_title(f"Difference (#{idx})")
        axes[i, 2].set_xlabel('Longitude [°]')
        axes[i, 2].set_ylabel('Latitude [°]')
        axes[i, 2].set_xlim(x_min, x_max)
        axes[i, 2].set_ylim(y_min, y_max)
        axes[i, 2].set_xticks(x_ticks)
        axes[i, 2].set_yticks(y_ticks)
        axes[i, 2].set_xticklabels(x_labels)
        axes[i, 2].set_yticklabels(y_labels)
        axes[i, 2].grid(alpha=0.25, color='silver')

    # 서브플롯 간격/레이아웃 조정
    plt.subplots_adjust(wspace=-0.4, hspace=0.2)
    plt.tight_layout(rect=[0, 0, 0.88, 0.96])

    # (3) 단일 컬러바
    cbar = fig.colorbar(
        im_true,
        ax=axes.ravel().tolist(),
        orientation='vertical',
        fraction=0.03,
        pad=0.02,
        shrink=0.8
    )
    cbar.set_label('conc. [$\\mu \\mathrm{g}/\\mathrm{m}^3$]')

    plt.show()

# ==============================
print(np.argmax(score))
plot_prediction_loss(true_conc_map_w_lines, pred_conc_map_w_lines, indices=np.argmax(score))
# Out:
# 17

# %%
true_conc_map_w_lines_re = true_conc_map_w_lines
pred_conc_map_w_lines_re = pred_conc_map_w_lines

true_conc_map_w_lines_re = np.delete(true_conc_map_w_lines, np.argmax(score), axis=0)
pred_conc_map_w_lines_re = np.delete(pred_conc_map_w_lines, np.argmax(score), axis=0)

print(true_conc_map_w_lines_re.shape)
print(pred_conc_map_w_lines_re.shape)
# Out:
# (47, 82, 67)
# (47, 82, 67)

# %%
y_true_modi = true_conc_map_w_lines_re.reshape(-1)
y_pred_modi = pred_conc_map_w_lines_re.reshape(-1)

fig, axes = plt.subplots(1, 1, figsize=(5, 5), dpi=300)
axes = plot_scatter(axes, y_true_modi, y_pred_modi)
axes.grid(alpha=0.25)
axes.set_title("True vs. Pred scatter plot")
axes.set_xlabel('True O3 [$\mu \mathrm{g}/\mathrm{m}^3$]')
axes.set_ylabel('Pred O3 [$\mu \mathrm{g}/\mathrm{m}^3$]')
cbaxes = axes.inset_axes([0.5, 0.2, 0.35, 0.03])
cb = plt.colorbar(
    mpl.cm.ScalarMappable(norm=mpl.colors.LogNorm(vmin=1, vmax=1000), cmap='jet'),
    cax=cbaxes, label='Number of samples', orientation='horizontal')
cb.set_label(label='Number of samples', fontsize=10)

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 6), dpi=300)
score, score_std = get_score(true_conc_map_w_lines_re, pred_conc_map_w_lines_re)
label_text = f'NMAE: {np.mean(score):.3f}±{np.std(score):.3f}'

axes.bar(np.arange(y_test.shape[0]-1), score, yerr=score_std, label=label_text, capsize=2)
axes.set_xticks(np.arange(y_test.shape[0]-1), range(y_test.shape[0]-1))
axes.grid(alpha=0.25)
axes.legend()
axes.set_title("NMAE of Cond. U-Net O3")
axes.set_xlabel('Scenario')
axes.set_ylabel('NMAE [%]')
plt.show()
