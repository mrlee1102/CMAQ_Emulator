# %% [markdown]
# # 라이브러리 및 Geometric 설정

# %%
# Import
import os
import sys
sys.path.append('/home/user/workdir/CMAQ_Emulator/main')

# 모델 라이브러리
from src.model.cmaqnet_unet import build_model

# 학습 및 처리/분석 관련 라이브러리
import numpy as np
import pandas as pd
import netCDF4 as nc
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

# Geometric 및 시각화 라이브러리
import geopandas as gpd
from shapely.geometry import Point
import matplotlib as mpl
import matplotlib.pyplot as plt

# 데이터 스케일러 설정
import joblib
scaler = StandardScaler()

# 2D Map 결과 도출을 위한 지도 파라미터 세팅
proj = '+proj=lcc +lat_1=30 +lat_2=60 +lon_1=126 +lat_0=38 +lon_0=126 +ellps=GRS80 +units=m'
atob = {
    0: 'G', 1: 'F', 2: 'K', 3: 'J', 4: 'E', 5: 'D',
    6: 'O', 7: 'C', 8: 'A', 9: 'Q', 10: 'P', 11: 'B',
    12: 'M', 13: 'L', 14: 'N', 15: 'I', 16: 'H'}
region_columns = {
    'A': 'Seoul City', 'B': 'Incheon City', 'C': 'Busan City', 'D': 'Daegu City',
    'E': 'Gwangju City', 'F': 'Gyeonggi-do', 'G': 'Gangwon-do', 'H': 'Chungbuk-do',
    'I': 'Chungnam-do', 'J': 'Gyeongbuk-do', 'K': 'Gyeongnam-do', 'L': 'Jeonbuk-do',
    'M': 'Jeonnam-do', 'N': 'Jeju-do', 'O': 'Daejeon City', 'P': 'Ulsan City', 'Q': 'Sejong City'}

def get_ctprvn_map() -> gpd.GeoDataFrame:
    path = '/home/user/workdir/CMAQ_Emulator/main/resources/geom/ctp_rvn.shp'
    ctprvn = gpd.GeoDataFrame.from_file(path, encoding='cp949')
    ctprvn.crs = 'EPSG:5179'
    return ctprvn

def get_base_raster(ctprvn:gpd.GeoDataFrame) -> gpd.GeoDataFrame:
    points = [Point(i, j)
                for i in range(-180000, -180000 + 9000 * 67, 9000)
                for j in range(-585000, -585000 + 9000 * 82, 9000)]
    grid_data = gpd.GeoDataFrame(points, geometry='geometry', columns=['geometry'])
    grid_data.crs = ctprvn.to_crs(proj).crs
    grid_data.loc[:,'x_m'] = grid_data.geometry.x
    grid_data.loc[:,'y_m'] = grid_data.geometry.y
    grid_data.loc[:,'value'] = 0
    grid_data.loc[:,'index'] = grid_data.index
    return grid_data

def get_region_pixel_indices() -> list:
    ctprvn = get_ctprvn_map()
    grid_data = get_base_raster(ctprvn)
 
    cities = {
        0: '강원도', 1: '경기도', 2: '경상남도', 3: '경상북도',
        4: '광주광역시', 5: '대구광역시', 6: '대전광역시', 7: '부산광역시',
        8: '서울특별시', 9: '세종특별자치시', 10: '울산광역시', 11: '인천광역시',
        12: '전라남도', 13: '전라북도', 14: '제주특별자치도', 15: '충청남도',
        16: '충청북도'
    }

    gdf_joined_loc = ['CTPRVN_CD', 'CTP_ENG_NM', 'CTP_KOR_NM', 'index_right0']
    gdf_joined = gpd.sjoin(ctprvn, grid_data.to_crs(5179), predicate='contains')

    indices = gpd.GeoDataFrame(pd.merge(
        left=grid_data, right=gdf_joined.loc[:,gdf_joined_loc], 
        how='left', left_on='index', right_on='index_right0'
    ), geometry='geometry').dropna()
    pixel_indices = \
        [[(idx%82, idx//82) for idx in indices.loc[indices.CTP_KOR_NM==cities[region]].index.tolist()]
         for region, _ in cities.items()]
    return pixel_indices

ctprvn = get_ctprvn_map()
ctprvn_proj = ctprvn.to_crs(proj)

# 건국대(서울대)에서 제공한 대한민국 국토 grid 정보
grid_alloc = (
    pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/geom/grid_allocation.csv') # load grid allocation data
    .sort_values(by=['Row', 'Column', 'Ratio'], ascending=[True, True, False]) # sort by row, column, ratio
    .drop_duplicates(subset=['Row', 'Column'], keep='first') # drop duplicates
    .reset_index(drop=True) # reset index
)

# 정부에서 배포하는 대한민국 국토 grid 정보
pixel_indices = get_region_pixel_indices()
total_index = []
for idx, grids in enumerate(pixel_indices):
    for grid in grids:
        total_index.append([
            grid[1], grid[0], 100.0, atob[idx], region_columns[atob[idx]]
        ])
total_index = pd.DataFrame(total_index, columns=grid_alloc.columns)

# 두 기관에서 주는 grid에 한두픽셀씩 비어있는 부분이 있어, 두 기관 데이터를 모두 참조하여 중복되는 픽셀을 정리 후 최종 국토 grid 정보를 취득
grid_alloc = pd.concat([
    grid_alloc.drop(columns=['Ratio', 'Region_Name']),
    total_index.drop(columns=['Ratio', 'Region_Name'])
]).sort_values(by=['Region_Code']).drop_duplicates().reset_index(drop=True)
grid_alloc[['Row', 'Column']] = grid_alloc[['Row', 'Column']] - 1

row_indices, col_indices = zip(*grid_alloc[['Row', 'Column']].values)
offset_x, offset_y = 4500, 4500 # 지도 위치 맞추기

# 마스킹 처리
mask = np.zeros((82, 67))
mask[row_indices, col_indices] = 1

cmap_white = mpl.colormaps['jet']
cmap_white.set_under('white')

# %% [markdown]
# # Training

# %%
# 입력 데이터셋 로드
dataset_2013 = pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/ctrl/dataset_for_o3_interaction_v3.csv')
ctrl_data = pd.concat([dataset_2013], axis=0)
ctrl_data = ctrl_data.reset_index(drop=True).values
emis_data = ctrl_data[:, :17*4]

# 레이블 데이터 로드
label_path_2013 = '/home/user/workdir/CMAQ_Emulator/main/datasets/concentration/2013'
label_path = []
for i in range(1, 120): 
    label_path.append(os.path.join(label_path_2013, '1.00', f'ACONC.{i}'))
label_data = []
for path in label_path:
    with nc.Dataset(path) as f:
        label_data.append(f.variables['O3'][:].data.squeeze())
label_data = np.array(label_data).reshape(len(label_data), 82, 67, 1)

# %%
# 모델 학습 시 저장 경로
model_path = '/home/user/workdir/CMAQ_Emulator/main/src/model/o3_prediction/final_model_origin'

epochs = 1000  # 훈련 반복 횟수
batch_size = 32  # 배치 크기
test_split = 0.4  # 테스트 샘플 비율 (1=100%)
random_seed = 42  # 랜덤 샘플링 시 고정 시드값

X_emis_train, X_emis_test, y_train, y_test = train_test_split(emis_data, label_data, test_size=test_split, random_state=random_seed)

y_train_shape = y_train.shape
y_test_shape  = y_test.shape

# 각 샘플을 flatten
y_train_flat = y_train.reshape(y_train_shape[0], -1)
y_test_flat  = y_test.reshape(y_test_shape[0], -1)

# 샘플 값을 스케일링
y_train_scaled_flat = scaler.fit_transform(y_train_flat)
y_test_scaled_flat  = scaler.transform(y_test_flat)
joblib.dump(scaler, '/home/user/workdir/CMAQ_Emulator/main/o3_training/o3_prediction_origin.pkl')
print("Scaler saved successfully.")

# 다시 원래 shape으로 복원
y_train_scaled = y_train_scaled_flat.reshape(y_train_shape)
y_test_scaled  = y_test_scaled_flat.reshape(y_test_shape)

# Cosine Decay 스케줄 설정
steps_per_epoch = len(X_emis_train) // batch_size 
total_steps = epochs * steps_per_epoch

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("Memory growth enabled for GPUs")
    except RuntimeError as e:
        print(e)

strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=1e-3,
        decay_steps=total_steps,
        alpha=0.1  # 최종 lr 비율 (0이면 최솟값이 0)
    )
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
    model = build_model(
        ctrl_dim=17*4,
        out_channel=1,
        hidden_size=[256, 128],
        hidden_depth=5,
        in_filters=64,
        kernel_size=3,
        activation='silu',
        dropout=0.0,
        use_abs=True
    )
    model.compile(
        optimizer=optimizer, 
        loss=tf.keras.losses.Huber(delta=1)  # delta는 Huber 손실 전환점
    )

early_stop = EarlyStopping(monitor='val_loss', patience=150, restore_best_weights=True)
history = model.fit(
    x=[X_emis_train],
    y=y_train_scaled,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=[[X_emis_test], y_test],
    callbacks=[early_stop]
)

model.save(model_path)
# Out:
# Scaler saved successfully.
# Memory growth enabled for GPUs
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/1000
# INFO:tensorflow:Collective all_reduce tensors: 82 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 82 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 3/3 [==============================] - 49s 5s/step - loss: 0.9574 - val_loss: 347.2214
# Epoch 2/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 0.4874 - val_loss: 6883.8438
# Epoch 3/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.4433 - val_loss: 6927.6499
# Epoch 4/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.4291 - val_loss: 3606.5837
# Epoch 5/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.4316 - val_loss: 1532.6466
# Epoch 6/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.4282 - val_loss: 604.7756
# Epoch 7/1000
# 3/3 [==============================] - 2s 651ms/step - loss: 0.4259 - val_loss: 279.0705
# Epoch 8/1000
# 3/3 [==============================] - 2s 637ms/step - loss: 0.4256 - val_loss: 126.1554
# Epoch 9/1000
# 3/3 [==============================] - 2s 680ms/step - loss: 0.4256 - val_loss: 55.8151
# Epoch 10/1000
# 3/3 [==============================] - 2s 636ms/step - loss: 0.4260 - val_loss: 27.5308
# Epoch 11/1000
# 3/3 [==============================] - 2s 622ms/step - loss: 0.4249 - val_loss: 13.7711
# Epoch 12/1000
# 3/3 [==============================] - 2s 651ms/step - loss: 0.4238 - val_loss: 6.9006
# Epoch 13/1000
# 3/3 [==============================] - 2s 669ms/step - loss: 0.4234 - val_loss: 3.8966
# Epoch 14/1000
# 3/3 [==============================] - 2s 657ms/step - loss: 0.4230 - val_loss: 2.1128
# Epoch 15/1000
# 3/3 [==============================] - 2s 657ms/step - loss: 0.4231 - val_loss: 1.2111
# Epoch 16/1000
# 3/3 [==============================] - 2s 662ms/step - loss: 0.4228 - val_loss: 0.7431
# Epoch 17/1000
# 3/3 [==============================] - 2s 658ms/step - loss: 0.4223 - val_loss: 0.4181
# Epoch 18/1000
# 3/3 [==============================] - 2s 654ms/step - loss: 0.4219 - val_loss: 0.2718
# Epoch 19/1000
# 3/3 [==============================] - 2s 648ms/step - loss: 0.4209 - val_loss: 0.1721
# Epoch 20/1000
# 3/3 [==============================] - 2s 653ms/step - loss: 0.4195 - val_loss: 0.1124
# Epoch 21/1000
# 3/3 [==============================] - 2s 680ms/step - loss: 0.4194 - val_loss: 0.0808
# Epoch 22/1000
# 3/3 [==============================] - 2s 630ms/step - loss: 0.4150 - val_loss: 0.0505
# Epoch 23/1000
# 3/3 [==============================] - 2s 668ms/step - loss: 0.4133 - val_loss: 0.0402
# Epoch 24/1000
# 3/3 [==============================] - 2s 653ms/step - loss: 0.4090 - val_loss: 0.0340
# Epoch 25/1000
# 3/3 [==============================] - 2s 671ms/step - loss: 0.4057 - val_loss: 0.0306
# Epoch 26/1000
# 3/3 [==============================] - 2s 633ms/step - loss: 0.4052 - val_loss: 0.0294
# Epoch 27/1000
# 3/3 [==============================] - 2s 658ms/step - loss: 0.4090 - val_loss: 0.0255
# Epoch 28/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.4102 - val_loss: 0.0294
# Epoch 29/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 0.4056 - val_loss: 0.0363
# Epoch 30/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 0.4122 - val_loss: 0.0288
# Epoch 31/1000
# 3/3 [==============================] - 2s 664ms/step - loss: 0.4057 - val_loss: 0.0170
# Epoch 32/1000
# 3/3 [==============================] - 2s 663ms/step - loss: 0.4025 - val_loss: 0.0147
# Epoch 33/1000
# 3/3 [==============================] - 2s 654ms/step - loss: 0.4021 - val_loss: 0.0126
# Epoch 34/1000
# 3/3 [==============================] - 2s 681ms/step - loss: 0.4034 - val_loss: 0.0114
# Epoch 35/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 0.4018 - val_loss: 0.0202
# Epoch 36/1000
# 3/3 [==============================] - 2s 737ms/step - loss: 0.4027 - val_loss: 0.0311
# Epoch 37/1000
# 3/3 [==============================] - 1s 547ms/step - loss: 0.4045 - val_loss: 0.0222
# Epoch 38/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.4005 - val_loss: 0.0182
# Epoch 39/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 0.4007 - val_loss: 0.0167
# Epoch 40/1000
# 3/3 [==============================] - 2s 587ms/step - loss: 0.4013 - val_loss: 0.0153
# Epoch 41/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3995 - val_loss: 0.0242
# Epoch 42/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 0.3998 - val_loss: 0.0254
# Epoch 43/1000
# 3/3 [==============================] - 1s 548ms/step - loss: 0.4020 - val_loss: 0.0218
# Epoch 44/1000
# 3/3 [==============================] - 2s 555ms/step - loss: 0.4061 - val_loss: 0.0403
# Epoch 45/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.4012 - val_loss: 0.0323
# Epoch 46/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.3987 - val_loss: 0.0373
# Epoch 47/1000
# 3/3 [==============================] - 1s 534ms/step - loss: 0.3992 - val_loss: 0.0461
# Epoch 48/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.3996 - val_loss: 0.0605
# Epoch 49/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.4039 - val_loss: 0.0649
# Epoch 50/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 0.4028 - val_loss: 0.0416
# Epoch 51/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 0.4024 - val_loss: 0.0232
# Epoch 52/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 0.4054 - val_loss: 0.0374
# Epoch 53/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 0.4019 - val_loss: 0.0721
# Epoch 54/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 0.4002 - val_loss: 0.1032
# Epoch 55/1000
# 3/3 [==============================] - 1s 530ms/step - loss: 0.4059 - val_loss: 0.0702
# Epoch 56/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 0.4001 - val_loss: 0.0294
# Epoch 57/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.4025 - val_loss: 0.0293
# Epoch 58/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 0.4023 - val_loss: 0.0286
# Epoch 59/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 0.3999 - val_loss: 0.0607
# Epoch 60/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 0.4004 - val_loss: 0.0662
# Epoch 61/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.3994 - val_loss: 0.0410
# Epoch 62/1000
# 3/3 [==============================] - 1s 535ms/step - loss: 0.4014 - val_loss: 0.0383
# Epoch 63/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 0.3993 - val_loss: 0.0487
# Epoch 64/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 0.3973 - val_loss: 0.0476
# Epoch 65/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3973 - val_loss: 0.0324
# Epoch 66/1000
# 3/3 [==============================] - 1s 503ms/step - loss: 0.3982 - val_loss: 0.0630
# Epoch 67/1000
# 3/3 [==============================] - 1s 535ms/step - loss: 0.4011 - val_loss: 0.0884
# Epoch 68/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.4010 - val_loss: 0.0635
# Epoch 69/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.3979 - val_loss: 0.0588
# Epoch 70/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 0.4013 - val_loss: 0.0519
# Epoch 71/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.4000 - val_loss: 0.0279
# Epoch 72/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.4048 - val_loss: 0.0379
# Epoch 73/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 0.4032 - val_loss: 0.0681
# Epoch 74/1000
# 3/3 [==============================] - 1s 504ms/step - loss: 0.4028 - val_loss: 0.0802
# Epoch 75/1000
# 3/3 [==============================] - 1s 544ms/step - loss: 0.4033 - val_loss: 0.0564
# Epoch 76/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.3980 - val_loss: 0.0780
# Epoch 77/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 0.4030 - val_loss: 0.0417
# Epoch 78/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 0.4048 - val_loss: 0.0211
# Epoch 79/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 0.4165 - val_loss: 0.0245
# Epoch 80/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.4192 - val_loss: 0.0241
# Epoch 81/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 0.4190 - val_loss: 0.0277
# Epoch 82/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 0.4171 - val_loss: 0.0269
# Epoch 83/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.4142 - val_loss: 0.0323
# Epoch 84/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 0.4083 - val_loss: 0.0563
# Epoch 85/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.4026 - val_loss: 0.0849
# Epoch 86/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 0.4055 - val_loss: 0.0676
# Epoch 87/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.3996 - val_loss: 0.0370
# Epoch 88/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 0.4040 - val_loss: 0.0342
# Epoch 89/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 0.4031 - val_loss: 0.0475
# Epoch 90/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 0.4000 - val_loss: 0.0617
# Epoch 91/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.4010 - val_loss: 0.0740
# Epoch 92/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 0.3999 - val_loss: 0.0532
# Epoch 93/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 0.3983 - val_loss: 0.0547
# Epoch 94/1000
# 3/3 [==============================] - 2s 557ms/step - loss: 0.3986 - val_loss: 0.0483
# Epoch 95/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 0.3989 - val_loss: 0.0411
# Epoch 96/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 0.3984 - val_loss: 0.0535
# Epoch 97/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.4001 - val_loss: 0.0512
# Epoch 98/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 0.3984 - val_loss: 0.0321
# Epoch 99/1000
# 3/3 [==============================] - 1s 497ms/step - loss: 0.3990 - val_loss: 0.0277
# Epoch 100/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.3987 - val_loss: 0.0290
# Epoch 101/1000
# 3/3 [==============================] - 1s 544ms/step - loss: 0.3981 - val_loss: 0.0385
# Epoch 102/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.3973 - val_loss: 0.0518
# Epoch 103/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.4017 - val_loss: 0.0565
# Epoch 104/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 0.3993 - val_loss: 0.0371
# Epoch 105/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 0.3982 - val_loss: 0.0369
# Epoch 106/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 0.3972 - val_loss: 0.0506
# Epoch 107/1000
# 3/3 [==============================] - 1s 543ms/step - loss: 0.3991 - val_loss: 0.0402
# Epoch 108/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.3982 - val_loss: 0.0285
# Epoch 109/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 0.3974 - val_loss: 0.0247
# Epoch 110/1000
# 3/3 [==============================] - 1s 525ms/step - loss: 0.4004 - val_loss: 0.0227
# Epoch 111/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 0.3993 - val_loss: 0.0272
# Epoch 112/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 0.3965 - val_loss: 0.0381
# Epoch 113/1000
# 3/3 [==============================] - 1s 503ms/step - loss: 0.3968 - val_loss: 0.0351
# Epoch 114/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 0.3986 - val_loss: 0.0223
# Epoch 115/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 0.3984 - val_loss: 0.0205
# Epoch 116/1000
# 3/3 [==============================] - 1s 504ms/step - loss: 0.3990 - val_loss: 0.0183
# Epoch 117/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 0.3987 - val_loss: 0.0252
# Epoch 118/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 0.3953 - val_loss: 0.0507
# Epoch 119/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.4019 - val_loss: 0.0491
# Epoch 120/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.3993 - val_loss: 0.0293
# Epoch 121/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 0.3970 - val_loss: 0.0219
# Epoch 122/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 0.3977 - val_loss: 0.0182
# Epoch 123/1000
# 3/3 [==============================] - 1s 497ms/step - loss: 0.3962 - val_loss: 0.0133
# Epoch 124/1000
# 3/3 [==============================] - 1s 550ms/step - loss: 0.3965 - val_loss: 0.0132
# Epoch 125/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.3962 - val_loss: 0.0183
# Epoch 126/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.3988 - val_loss: 0.0194
# Epoch 127/1000
# 3/3 [==============================] - 2s 722ms/step - loss: 0.3955 - val_loss: 0.0113
# Epoch 128/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.3982 - val_loss: 0.0142
# Epoch 129/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.3966 - val_loss: 0.0221
# Epoch 130/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.3993 - val_loss: 0.0259
# Epoch 131/1000
# 3/3 [==============================] - 1s 538ms/step - loss: 0.3997 - val_loss: 0.0269
# Epoch 132/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 0.3971 - val_loss: 0.0230
# Epoch 133/1000
# 3/3 [==============================] - 1s 545ms/step - loss: 0.3957 - val_loss: 0.0201
# Epoch 134/1000
# 3/3 [==============================] - 1s 496ms/step - loss: 0.3960 - val_loss: 0.0171
# Epoch 135/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 0.3988 - val_loss: 0.0196
# Epoch 136/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 0.3956 - val_loss: 0.0258
# Epoch 137/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.3963 - val_loss: 0.0266
# Epoch 138/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.3966 - val_loss: 0.0433
# Epoch 139/1000
# 3/3 [==============================] - 1s 504ms/step - loss: 0.3980 - val_loss: 0.0445
# Epoch 140/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 0.3981 - val_loss: 0.0356
# Epoch 141/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 0.3945 - val_loss: 0.0253
# Epoch 142/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 0.3949 - val_loss: 0.0172
# Epoch 143/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 0.3962 - val_loss: 0.0212
# Epoch 144/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 0.3935 - val_loss: 0.0315
# Epoch 145/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 0.3938 - val_loss: 0.0220
# Epoch 146/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 0.3946 - val_loss: 0.0175
# Epoch 147/1000
# 3/3 [==============================] - 1s 500ms/step - loss: 0.3961 - val_loss: 0.0238
# Epoch 148/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.3952 - val_loss: 0.0251
# Epoch 149/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 0.3949 - val_loss: 0.0213
# Epoch 150/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 0.3948 - val_loss: 0.0288
# Epoch 151/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 0.3951 - val_loss: 0.0317
# Epoch 152/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.3950 - val_loss: 0.0219
# Epoch 153/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 0.3941 - val_loss: 0.0275
# Epoch 154/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 0.3943 - val_loss: 0.0344
# Epoch 155/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.3974 - val_loss: 0.0247
# Epoch 156/1000
# 3/3 [==============================] - 1s 538ms/step - loss: 0.3939 - val_loss: 0.0194
# Epoch 157/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 0.3931 - val_loss: 0.0260
# Epoch 158/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 0.3941 - val_loss: 0.0456
# Epoch 159/1000
# 3/3 [==============================] - 1s 538ms/step - loss: 0.4017 - val_loss: 0.0433
# Epoch 160/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.4001 - val_loss: 0.0150
# Epoch 161/1000
# 3/3 [==============================] - 1s 496ms/step - loss: 0.3990 - val_loss: 0.0137
# Epoch 162/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 0.4004 - val_loss: 0.0184
# Epoch 163/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 0.3974 - val_loss: 0.0245
# Epoch 164/1000
# 3/3 [==============================] - 1s 534ms/step - loss: 0.3965 - val_loss: 0.0305
# Epoch 165/1000
# 3/3 [==============================] - 1s 536ms/step - loss: 0.3961 - val_loss: 0.0325
# Epoch 166/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 0.3945 - val_loss: 0.0278
# Epoch 167/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 0.3962 - val_loss: 0.0322
# Epoch 168/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.3964 - val_loss: 0.0325
# Epoch 169/1000
# 3/3 [==============================] - 1s 496ms/step - loss: 0.3951 - val_loss: 0.0353
# Epoch 170/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 0.3967 - val_loss: 0.0344
# Epoch 171/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.3960 - val_loss: 0.0241
# Epoch 172/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 0.3955 - val_loss: 0.0257
# Epoch 173/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 0.3942 - val_loss: 0.0342
# Epoch 174/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 0.3960 - val_loss: 0.0413
# Epoch 175/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 0.3964 - val_loss: 0.0368
# Epoch 176/1000
# 3/3 [==============================] - 1s 495ms/step - loss: 0.3937 - val_loss: 0.0230
# Epoch 177/1000
# 3/3 [==============================] - 2s 558ms/step - loss: 0.3944 - val_loss: 0.0230
# Epoch 178/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3913 - val_loss: 0.0384
# Epoch 179/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 0.3917 - val_loss: 0.0386
# Epoch 180/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 0.3936 - val_loss: 0.0357
# Epoch 181/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 0.3938 - val_loss: 0.0459
# Epoch 182/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.3941 - val_loss: 0.0462
# Epoch 183/1000
# 3/3 [==============================] - 1s 497ms/step - loss: 0.3950 - val_loss: 0.0373
# Epoch 184/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 0.3913 - val_loss: 0.0567
# Epoch 185/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.3907 - val_loss: 0.0700
# Epoch 186/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 0.3875 - val_loss: 0.0496
# Epoch 187/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.3878 - val_loss: 0.0518
# Epoch 188/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3842 - val_loss: 0.0640
# Epoch 189/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 0.3840 - val_loss: 0.0595
# Epoch 190/1000
# 3/3 [==============================] - 1s 535ms/step - loss: 0.3830 - val_loss: 0.0523
# Epoch 191/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 0.3783 - val_loss: 0.0537
# Epoch 192/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 0.3766 - val_loss: 0.0418
# Epoch 193/1000
# 3/3 [==============================] - 1s 541ms/step - loss: 0.3826 - val_loss: 0.0391
# Epoch 194/1000
# 3/3 [==============================] - 1s 544ms/step - loss: 0.3839 - val_loss: 0.0515
# Epoch 195/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 0.3762 - val_loss: 0.0480
# Epoch 196/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 0.3723 - val_loss: 0.0482
# Epoch 197/1000
# 3/3 [==============================] - 2s 560ms/step - loss: 0.3607 - val_loss: 0.0426
# Epoch 198/1000
# 3/3 [==============================] - 1s 530ms/step - loss: 0.3667 - val_loss: 0.0386
# Epoch 199/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 0.3563 - val_loss: 0.0387
# Epoch 200/1000
# 3/3 [==============================] - 1s 551ms/step - loss: 0.3584 - val_loss: 0.0410
# Epoch 201/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.3561 - val_loss: 0.0301
# Epoch 202/1000
# 3/3 [==============================] - 1s 540ms/step - loss: 0.3606 - val_loss: 0.0228
# Epoch 203/1000
# 3/3 [==============================] - 1s 538ms/step - loss: 0.3566 - val_loss: 0.0325
# Epoch 204/1000
# 3/3 [==============================] - 1s 540ms/step - loss: 0.3536 - val_loss: 0.0395
# Epoch 205/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 0.3524 - val_loss: 0.0186
# Epoch 206/1000
# 3/3 [==============================] - 1s 530ms/step - loss: 0.3518 - val_loss: 0.0145
# Epoch 207/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 0.3468 - val_loss: 0.0142
# Epoch 208/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.3425 - val_loss: 0.0144
# Epoch 209/1000
# 3/3 [==============================] - 2s 568ms/step - loss: 0.3364 - val_loss: 0.0209
# Epoch 210/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 0.3551 - val_loss: 0.0447
# Epoch 211/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 0.3430 - val_loss: 0.0395
# Epoch 212/1000
# 3/3 [==============================] - 1s 542ms/step - loss: 0.3448 - val_loss: 0.0325
# Epoch 213/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.3386 - val_loss: 0.0210
# Epoch 214/1000
# 3/3 [==============================] - 1s 539ms/step - loss: 0.3355 - val_loss: 0.0476
# Epoch 215/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 0.3373 - val_loss: 0.0163
# Epoch 216/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.3413 - val_loss: 0.0287
# Epoch 217/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 0.3341 - val_loss: 0.0562
# Epoch 218/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 0.3378 - val_loss: 0.0459
# Epoch 219/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.3380 - val_loss: 0.0187
# Epoch 220/1000
# 3/3 [==============================] - 1s 502ms/step - loss: 0.3330 - val_loss: 0.0440
# Epoch 221/1000
# 3/3 [==============================] - 1s 497ms/step - loss: 0.3406 - val_loss: 0.0534
# Epoch 222/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.3262 - val_loss: 0.0794
# Epoch 223/1000
# 3/3 [==============================] - 1s 527ms/step - loss: 0.3304 - val_loss: 0.1116
# Epoch 224/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.3268 - val_loss: 0.1278
# Epoch 225/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 0.3309 - val_loss: 0.0728
# Epoch 226/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 0.3342 - val_loss: 0.0459
# Epoch 227/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 0.3405 - val_loss: 0.0457
# Epoch 228/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 0.3418 - val_loss: 0.0468
# Epoch 229/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 0.3352 - val_loss: 0.0507
# Epoch 230/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.3220 - val_loss: 0.0158
# Epoch 231/1000
# 3/3 [==============================] - 2s 680ms/step - loss: 0.3284 - val_loss: 0.0047
# Epoch 232/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.3322 - val_loss: 0.0077
# Epoch 233/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.3180 - val_loss: 0.0250
# Epoch 234/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 0.3284 - val_loss: 0.0237
# Epoch 235/1000
# 3/3 [==============================] - 1s 540ms/step - loss: 0.3206 - val_loss: 0.0082
# Epoch 236/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.3303 - val_loss: 0.0205
# Epoch 237/1000
# 3/3 [==============================] - 1s 536ms/step - loss: 0.3327 - val_loss: 0.0467
# Epoch 238/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 0.3383 - val_loss: 0.0937
# Epoch 239/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 0.3207 - val_loss: 0.1308
# Epoch 240/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.3198 - val_loss: 0.0967
# Epoch 241/1000
# 3/3 [==============================] - 2s 833ms/step - loss: 0.3232 - val_loss: 0.0480
# Epoch 242/1000
# 3/3 [==============================] - 2s 557ms/step - loss: 0.3221 - val_loss: 0.0458
# Epoch 243/1000
# 3/3 [==============================] - 1s 548ms/step - loss: 0.3197 - val_loss: 0.0535
# Epoch 244/1000
# 3/3 [==============================] - 2s 555ms/step - loss: 0.3214 - val_loss: 0.0273
# Epoch 245/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.3297 - val_loss: 0.0452
# Epoch 246/1000
# 3/3 [==============================] - 1s 537ms/step - loss: 0.3306 - val_loss: 0.0476
# Epoch 247/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 0.3185 - val_loss: 0.0529
# Epoch 248/1000
# 3/3 [==============================] - 2s 550ms/step - loss: 0.3140 - val_loss: 0.0804
# Epoch 249/1000
# 3/3 [==============================] - 1s 549ms/step - loss: 0.3169 - val_loss: 0.0467
# Epoch 250/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.3126 - val_loss: 0.0759
# Epoch 251/1000
# 3/3 [==============================] - 1s 515ms/step - loss: 0.3137 - val_loss: 0.0909
# Epoch 252/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 0.3248 - val_loss: 0.0823
# Epoch 253/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 0.3110 - val_loss: 0.0617
# Epoch 254/1000
# 3/3 [==============================] - 1s 551ms/step - loss: 0.3271 - val_loss: 0.0860
# Epoch 255/1000
# 3/3 [==============================] - 1s 500ms/step - loss: 0.3088 - val_loss: 0.0761
# Epoch 256/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.3180 - val_loss: 0.0133
# Epoch 257/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 0.3115 - val_loss: 0.0092
# Epoch 258/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.3081 - val_loss: 0.0061
# Epoch 259/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.3181 - val_loss: 0.0103
# Epoch 260/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 0.3071 - val_loss: 0.0185
# Epoch 261/1000
# 3/3 [==============================] - 2s 558ms/step - loss: 0.3159 - val_loss: 0.0229
# Epoch 262/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3103 - val_loss: 0.0063
# Epoch 263/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 0.3179 - val_loss: 0.0051
# Epoch 264/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.3164 - val_loss: 0.0234
# Epoch 265/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.3077 - val_loss: 0.0341
# Epoch 266/1000
# 3/3 [==============================] - 1s 536ms/step - loss: 0.3089 - val_loss: 0.0168
# Epoch 267/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.3098 - val_loss: 0.0133
# Epoch 268/1000
# 3/3 [==============================] - 1s 542ms/step - loss: 0.3106 - val_loss: 0.0283
# Epoch 269/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3167 - val_loss: 0.0223
# Epoch 270/1000
# 3/3 [==============================] - 1s 517ms/step - loss: 0.3140 - val_loss: 0.0270
# Epoch 271/1000
# 3/3 [==============================] - 1s 525ms/step - loss: 0.3040 - val_loss: 0.0634
# Epoch 272/1000
# 3/3 [==============================] - 2s 552ms/step - loss: 0.3059 - val_loss: 0.0393
# Epoch 273/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 0.3215 - val_loss: 0.0352
# Epoch 274/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.3051 - val_loss: 0.0579
# Epoch 275/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.3131 - val_loss: 0.0499
# Epoch 276/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 0.3099 - val_loss: 0.0535
# Epoch 277/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 0.3032 - val_loss: 0.0611
# Epoch 278/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 0.3106 - val_loss: 0.0788
# Epoch 279/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.3018 - val_loss: 0.0564
# Epoch 280/1000
# 3/3 [==============================] - 1s 530ms/step - loss: 0.3017 - val_loss: 0.0390
# Epoch 281/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.3056 - val_loss: 0.0273
# Epoch 282/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 0.2966 - val_loss: 0.0076
# Epoch 283/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 0.3041 - val_loss: 0.0282
# Epoch 284/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 0.3055 - val_loss: 0.0769
# Epoch 285/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 0.3069 - val_loss: 0.1245
# Epoch 286/1000
# 3/3 [==============================] - 1s 540ms/step - loss: 0.3125 - val_loss: 0.0878
# Epoch 287/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 0.3135 - val_loss: 0.0772
# Epoch 288/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.3129 - val_loss: 0.0699
# Epoch 289/1000
# 3/3 [==============================] - 1s 532ms/step - loss: 0.3047 - val_loss: 0.0630
# Epoch 290/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 0.3154 - val_loss: 0.0945
# Epoch 291/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 0.3073 - val_loss: 0.1022
# Epoch 292/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 0.3121 - val_loss: 0.1302
# Epoch 293/1000
# 3/3 [==============================] - 1s 495ms/step - loss: 0.3045 - val_loss: 0.1525
# Epoch 294/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 0.3018 - val_loss: 0.0796
# Epoch 295/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 0.3085 - val_loss: 0.0370
# Epoch 296/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3126 - val_loss: 0.0755
# Epoch 297/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.2979 - val_loss: 0.1250
# Epoch 298/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 0.3001 - val_loss: 0.0782
# Epoch 299/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 0.2990 - val_loss: 0.0321
# Epoch 300/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 0.3138 - val_loss: 0.0869
# Epoch 301/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 0.3036 - val_loss: 0.1099
# Epoch 302/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3070 - val_loss: 0.1107
# Epoch 303/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 0.3091 - val_loss: 0.1594
# Epoch 304/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.2979 - val_loss: 0.1554
# Epoch 305/1000
# 3/3 [==============================] - 1s 496ms/step - loss: 0.3057 - val_loss: 0.0906
# Epoch 306/1000
# 3/3 [==============================] - 1s 512ms/step - loss: 0.3093 - val_loss: 0.0421
# Epoch 307/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 0.3071 - val_loss: 0.0468
# Epoch 308/1000
# 3/3 [==============================] - 1s 545ms/step - loss: 0.3038 - val_loss: 0.0504
# Epoch 309/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 0.3027 - val_loss: 0.0434
# Epoch 310/1000
# 3/3 [==============================] - 1s 505ms/step - loss: 0.3092 - val_loss: 0.0478
# Epoch 311/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 0.3063 - val_loss: 0.1549
# Epoch 312/1000
# 3/3 [==============================] - 1s 539ms/step - loss: 0.2993 - val_loss: 0.2184
# Epoch 313/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 0.3128 - val_loss: 0.1744
# Epoch 314/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.2989 - val_loss: 0.1738
# Epoch 315/1000
# 3/3 [==============================] - 1s 543ms/step - loss: 0.2997 - val_loss: 0.1862
# Epoch 316/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.2932 - val_loss: 0.3057
# Epoch 317/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.2953 - val_loss: 0.2403
# Epoch 318/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.2981 - val_loss: 0.1361
# Epoch 319/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.2960 - val_loss: 0.0932
# Epoch 320/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.2955 - val_loss: 0.1392
# Epoch 321/1000
# 3/3 [==============================] - 1s 543ms/step - loss: 0.2956 - val_loss: 0.0778
# Epoch 322/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3156 - val_loss: 0.0828
# Epoch 323/1000
# 3/3 [==============================] - 1s 533ms/step - loss: 0.3146 - val_loss: 0.1371
# Epoch 324/1000
# 3/3 [==============================] - 1s 516ms/step - loss: 0.2988 - val_loss: 0.1488
# Epoch 325/1000
# 3/3 [==============================] - 1s 501ms/step - loss: 0.3064 - val_loss: 0.1247
# Epoch 326/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.3031 - val_loss: 0.0943
# Epoch 327/1000
# 3/3 [==============================] - 1s 548ms/step - loss: 0.3086 - val_loss: 0.0780
# Epoch 328/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 0.2969 - val_loss: 0.0758
# Epoch 329/1000
# 3/3 [==============================] - 1s 508ms/step - loss: 0.3047 - val_loss: 0.1105
# Epoch 330/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.2909 - val_loss: 0.1599
# Epoch 331/1000
# 3/3 [==============================] - 1s 526ms/step - loss: 0.2910 - val_loss: 0.1134
# Epoch 332/1000
# 3/3 [==============================] - 1s 514ms/step - loss: 0.2992 - val_loss: 0.0774
# Epoch 333/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.2931 - val_loss: 0.0983
# Epoch 334/1000
# 3/3 [==============================] - 1s 496ms/step - loss: 0.2970 - val_loss: 0.0876
# Epoch 335/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 0.2924 - val_loss: 0.0662
# Epoch 336/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.2940 - val_loss: 0.0638
# Epoch 337/1000
# 3/3 [==============================] - 1s 498ms/step - loss: 0.2899 - val_loss: 0.0505
# Epoch 338/1000
# 3/3 [==============================] - 2s 559ms/step - loss: 0.2998 - val_loss: 0.0205
# Epoch 339/1000
# 3/3 [==============================] - 1s 506ms/step - loss: 0.3110 - val_loss: 0.0853
# Epoch 340/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.2940 - val_loss: 0.1383
# Epoch 341/1000
# 3/3 [==============================] - 1s 510ms/step - loss: 0.2956 - val_loss: 0.1226
# Epoch 342/1000
# 3/3 [==============================] - 1s 496ms/step - loss: 0.2954 - val_loss: 0.1156
# Epoch 343/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.2991 - val_loss: 0.1599
# Epoch 344/1000
# 3/3 [==============================] - 1s 553ms/step - loss: 0.2890 - val_loss: 0.1226
# Epoch 345/1000
# 3/3 [==============================] - 1s 528ms/step - loss: 0.2874 - val_loss: 0.0591
# Epoch 346/1000
# 3/3 [==============================] - 1s 520ms/step - loss: 0.3003 - val_loss: 0.0646
# Epoch 347/1000
# 3/3 [==============================] - 1s 546ms/step - loss: 0.2949 - val_loss: 0.1581
# Epoch 348/1000
# 3/3 [==============================] - 1s 522ms/step - loss: 0.3084 - val_loss: 0.0928
# Epoch 349/1000
# 3/3 [==============================] - 1s 525ms/step - loss: 0.2956 - val_loss: 0.0326
# Epoch 350/1000
# 3/3 [==============================] - 2s 555ms/step - loss: 0.3176 - val_loss: 0.0403
# Epoch 351/1000
# 3/3 [==============================] - 1s 541ms/step - loss: 0.2987 - val_loss: 0.0619
# Epoch 352/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 0.3100 - val_loss: 0.0871
# Epoch 353/1000
# 3/3 [==============================] - 2s 574ms/step - loss: 0.3162 - val_loss: 0.0566
# Epoch 354/1000
# 3/3 [==============================] - 1s 509ms/step - loss: 0.3056 - val_loss: 0.0395
# Epoch 355/1000
# 3/3 [==============================] - 2s 857ms/step - loss: 0.2885 - val_loss: 0.0487
# Epoch 356/1000
# 3/3 [==============================] - 1s 543ms/step - loss: 0.2909 - val_loss: 0.0958
# Epoch 357/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.2998 - val_loss: 0.0998
# Epoch 358/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 0.2952 - val_loss: 0.1105
# Epoch 359/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.2894 - val_loss: 0.1254
# Epoch 360/1000
# 3/3 [==============================] - 1s 507ms/step - loss: 0.2880 - val_loss: 0.0864
# Epoch 361/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.2911 - val_loss: 0.1174
# Epoch 362/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 0.2895 - val_loss: 0.1435
# Epoch 363/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 0.2864 - val_loss: 0.1367
# Epoch 364/1000
# 3/3 [==============================] - 1s 529ms/step - loss: 0.2930 - val_loss: 0.1233
# Epoch 365/1000
# 3/3 [==============================] - 1s 531ms/step - loss: 0.2920 - val_loss: 0.0705
# Epoch 366/1000
# 3/3 [==============================] - 1s 549ms/step - loss: 0.2915 - val_loss: 0.1026
# Epoch 367/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.2973 - val_loss: 0.1083
# Epoch 368/1000
# 3/3 [==============================] - 2s 553ms/step - loss: 0.2943 - val_loss: 0.0675
# Epoch 369/1000
# 3/3 [==============================] - 1s 521ms/step - loss: 0.2893 - val_loss: 0.0933
# Epoch 370/1000
# 3/3 [==============================] - 1s 524ms/step - loss: 0.2844 - val_loss: 0.1095
# Epoch 371/1000
# 3/3 [==============================] - 1s 499ms/step - loss: 0.2898 - val_loss: 0.0925
# Epoch 372/1000
# 3/3 [==============================] - 2s 563ms/step - loss: 0.2768 - val_loss: 0.1017
# Epoch 373/1000
# 3/3 [==============================] - 1s 523ms/step - loss: 0.2720 - val_loss: 0.0940
# Epoch 374/1000
# 3/3 [==============================] - 1s 511ms/step - loss: 0.2816 - val_loss: 0.0881
# Epoch 375/1000
# 3/3 [==============================] - 1s 534ms/step - loss: 0.2840 - val_loss: 0.0961
# Epoch 376/1000
# 3/3 [==============================] - 1s 513ms/step - loss: 0.2804 - val_loss: 0.1040
# Epoch 377/1000
# 3/3 [==============================] - 1s 519ms/step - loss: 0.2712 - val_loss: 0.0641
# Epoch 378/1000
# 3/3 [==============================] - 2s 555ms/step - loss: 0.2803 - val_loss: 0.0842
# Epoch 379/1000
# 3/3 [==============================] - 1s 500ms/step - loss: 0.2799 - val_loss: 0.1093
# Epoch 380/1000
# 3/3 [==============================] - 1s 518ms/step - loss: 0.2981 - val_loss: 0.0701
# Epoch 381/1000
# 3/3 [==============================] - 3s 1s/step - loss: 0.2911 - val_loss: 0.0964
# INFO:tensorflow:Assets written to: /home/user/workdir/CMAQ_Emulator/main/src/model/o3_prediction/final_model_origin/assets
# INFO:tensorflow:Assets written to: /home/user/workdir/CMAQ_Emulator/main/src/model/o3_prediction/final_model_origin/assets

# %%
def plot_loss(history):
    epochs = range(1, len(history.history['loss']) + 1)
    
    plt.figure(figsize=(15, 10))
    
    # 1. 전체 에포크에 대한 학습 및 검증 손실
    plt.subplot(2, 2, 1)
    plt.plot(epochs, history.history['loss'], label='Training Loss', color='blue')
    plt.plot(epochs, history.history['val_loss'], label='Validation Loss', color='orange')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss over Epochs')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 2. 마지막 10 에포크의 손실 (세부 분석)
    plt.subplot(2, 2, 2)
    if len(epochs) >= 10:
        last_epochs = epochs[-10:]
        plt.plot(last_epochs, history.history['loss'][-10:], label='Training Loss', color='blue')
        plt.plot(last_epochs, history.history['val_loss'][-10:], label='Validation Loss', color='orange')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title('Loss (Last 10 Epochs)')
        plt.legend()
        plt.grid(alpha=0.3)
    else:
        plt.text(0.5, 0.5, "Not enough epochs for zoomed plot", ha='center')
    
    # 3. 학습 손실과 검증 손실의 차이
    plt.subplot(2, 2, 3)
    loss_diff = np.array(history.history['val_loss']) - np.array(history.history['loss'])
    plt.plot(epochs, loss_diff, label='Val Loss - Train Loss', color='green')
    plt.xlabel('Epochs')
    plt.ylabel('Loss Difference')
    plt.title('Difference between Validation and Training Loss')
    plt.legend()
    plt.grid(alpha=0.3)
    
    # 4. 이동 평균 (window=10)을 통한 평활화된 손실 추세
    plt.subplot(2, 2, 4)
    window = 10
    if len(epochs) >= window:
        train_ma = [np.mean(history.history['loss'][max(0, i-window):i]) for i in range(1, len(history.history['loss'])+1)]
        val_ma = [np.mean(history.history['val_loss'][max(0, i-window):i]) for i in range(1, len(history.history['val_loss'])+1)]
        plt.plot(epochs, train_ma, label='Training Loss MA', color='blue', linestyle='--')
        plt.plot(epochs, val_ma, label='Validation Loss MA', color='orange', linestyle='--')
        plt.xlabel('Epochs')
        plt.ylabel('Loss (Moving Average)')
        plt.title('Moving Average of Loss (window = 10)')
        plt.legend()
        plt.grid(alpha=0.3)
    else:
        plt.text(0.5, 0.5, "Not enough epochs for moving average plot", ha='center')
    
    plt.tight_layout()
    plt.show()

# Loss 결과물 출력
plot_loss(history)

# %% [markdown]
# # Prediction

# %%
test_split = 0.4  # 테스트 데이터 비율 (20%)
random_seed = 42  # 랜덤 시드
model = tf.keras.models.load_model('/home/user/workdir/CMAQ_Emulator/main/src/model/o3_prediction/final_model_origin')

# 입력 데이터셋 로드
pred_emis_data = []
dataset_2013 = pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/ctrl/dataset_for_o3_interaction_v3.csv')
ctrl_data = pd.concat([dataset_2013], axis=0)
ctrl_data = ctrl_data.reset_index(drop=True).values
pred_emis_data = ctrl_data[:, :17*4]

# 레이블 데이터 로드
base_path_2013 = "/home/user/workdir/CMAQ_Emulator/main/datasets/concentration/2013"
conc_path = []
for i in range(1, 120): 
    conc_path.append(os.path.join(base_path_2013, '1.00', f'ACONC.{i}'))
conc_data = []
for path in conc_path:
    with nc.Dataset(path) as f:
        conc_data.append(f.variables['O3'][:].data.squeeze()) 
conc_data = np.array(conc_data).reshape(len(conc_path), 82, 67, 1)

# 여기서, X_emis_train과 y_train은 dummy로 사용
X_emis_train, X_emis_test, y_train, y_test = train_test_split(pred_emis_data, conc_data, test_size=test_split, random_state=random_seed)

y_preds_scaled = model.predict([X_emis_test])

# 스케일러 파라미터 객체 로드
scaler = joblib.load('/home/user/workdir/CMAQ_Emulator/main/o3_training/o3_prediction_origin.pkl')
n_samples = y_preds_scaled.shape[0]  # 테스트 샘플 수
y_preds = scaler.inverse_transform(y_preds_scaled.reshape(n_samples, -1))
y_preds = y_preds.reshape(y_preds_scaled.shape)

y_pred = y_preds.squeeze()
y_true = y_test.squeeze()
# Out:
# 2/2 [==============================] - 14s 4s/step

# %%
print("Mean values:", scaler.mean_)
print("Scale values:", scaler.scale_)
print("Variance values:", scaler.var_)
# Out:
# Mean values: [0.04656921 0.04654878 0.04606796 ... 0.04533913 0.0452985  0.04531852]
# Scale values: [1.80774828e-05 1.83846467e-05 1.91075883e-05 ... 5.22114166e-05
#  4.83884023e-05 4.59747103e-05]
# Variance values: [3.26795383e-10 3.37995235e-10 3.65099932e-10 ... 2.72603202e-09
#  2.34143748e-09 2.11367399e-09]

# %%
mask_expanded = np.repeat(mask[np.newaxis, :, :], repeats=y_true.shape[0], axis=0)
pred_conc_map_w_lines = np.where(mask_expanded == 1, y_pred, 0) # 마스킹 적용
true_conc_map_w_lines = np.where(mask_expanded == 1, y_true, 0) # 마스킹 적용

# %%
def plot_scatter(ax, y_true, y_pred):
    r_x, r_y = np.polyfit(y_true, y_pred, 1)
    ax.hist2d(
        y_true, y_pred,
        bins=150, cmap='jet', cmin=1,
        norm=mpl.colors.LogNorm(vmin=1, vmax=1000),
    )
    ax.plot(
        y_true, r_x*y_true + r_y,
        color='red', label=f"y={r_x:.4f}x+{r_y:.4f}")
    r2 = r2_score(y_true, y_pred)
    ax.text(
        0.05, 0.95, f"$R^2={r2:.4f}$ \nSlope={r_x:.4f}\nIntercept={r_y:.4f}",
        verticalalignment='top', horizontalalignment='left',
        transform=ax.transAxes, fontsize=11
    )
    ax.grid(alpha=0.25)
    return ax

def get_score(y_true, y_pred):
    batch_size = y_true.shape[0]
    y_true = y_true.reshape(batch_size, -1)
    y_pred = y_pred.reshape(batch_size, -1)
    y_norm_err = np.abs(y_true - y_pred) / np.mean(y_true, axis=1, keepdims=True)
    y_err_mean = np.mean(y_norm_err, axis=1)
    y_err_std = np.percentile(y_norm_err, q=5, axis=1)
    return y_err_mean, y_err_std

# %%
y_true_modi = true_conc_map_w_lines.reshape(-1)
y_pred_modi = pred_conc_map_w_lines.reshape(-1)

fig, axes = plt.subplots(1, 1, figsize=(5, 5), dpi=300)
axes = plot_scatter(axes, y_true_modi, y_pred_modi)
axes.grid(alpha=0.25)
axes.set_title("True vs. Pred scatter plot")
axes.set_xlabel('True O3 [$\mu \mathrm{g}/\mathrm{m}^3$]')
axes.set_ylabel('Pred O3 [$\mu \mathrm{g}/\mathrm{m}^3$]')
cbaxes = axes.inset_axes([0.5, 0.2, 0.35, 0.03])
cb = plt.colorbar(
    mpl.cm.ScalarMappable(norm=mpl.colors.LogNorm(vmin=1, vmax=1000), cmap='jet'),
    cax=cbaxes, label='Number of samples', orientation='horizontal')
cb.set_label(label='Number of samples', fontsize=10)

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 6), dpi=300)
score, score_std = get_score(true_conc_map_w_lines, pred_conc_map_w_lines)
label_text = f'NMAE: {np.mean(score):.3f}±{np.std(score):.3f}'

axes.bar(np.arange(y_test.shape[0]), score, yerr=score_std, label=label_text, capsize=2)
axes.set_xticks(np.arange(y_test.shape[0]), range(y_test.shape[0]))
axes.grid(alpha=0.25)
axes.legend()
axes.set_title("NMAE of Cond. U-Net Nitrate")
axes.set_xlabel('Scenario')
axes.set_ylabel('NMAE [%]')
plt.show()

# %%
cmap_with_white = plt.get_cmap('jet').copy()   # jet 컬러맵 복사
cmap_with_white.set_bad('white')               # 마스킹된 부분을 흰색으로

def plot_prediction_loss(y_true, y_pred, num_samples=1, indices=-1):
    if indices == -1 or indices < 0:
        indices = np.random.choice(len(y_true), num_samples, replace=False)
    else:
        index = indices
        indices = [index]
    
    local_min = min(y_true[indices].min(), y_pred[indices].min())
    local_max = max(y_true[indices].max(), y_pred[indices].max())
    local_diff = np.abs(y_true[indices] - y_pred[indices])
    local_max = max(local_max, local_diff.max())

    fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))
    if num_samples == 1:
        axes = axes[np.newaxis, :]  # (1, 3) 형태로 맞춤

    # 지도 투영 좌표 범위
    x_min = -180000 + offset_x
    x_max =  414000 + offset_x
    y_min = -585000 + offset_y
    y_max =  144000 + offset_y

    x_ticks = np.linspace(x_min, x_max, 8)
    x_labels = [str(i) for i in range(124, 132)]
    y_ticks = np.linspace(y_min, y_max, 8)
    y_labels = [str(i) for i in range(32, 40)]

    # threshold 이하이면 흰색으로 표시
    threshold = 0.0005

    for i, idx in enumerate(indices):
        
        # (A) True
        data_true = y_true[idx][::-1]
        masked_true = np.ma.masked_where(data_true <= threshold, data_true)
        im_true = axes[i, 0].imshow(
            masked_true,
            cmap=cmap_with_white,
            extent=(x_min, x_max, y_min, y_max),
            vmin=threshold,
            vmax=local_max 
        )
        ctprvn_proj.boundary.plot(
            ax=axes[i, 0], edgecolor='black', facecolor='none', linewidth=1, alpha=0.25
        )
        axes[i, 0].set_title(f"True (#{idx})")
        axes[i, 0].set_xlabel('Longitude [°]')
        axes[i, 0].set_ylabel('Latitude [°]')
        axes[i, 0].set_xlim(x_min, x_max)
        axes[i, 0].set_ylim(y_min, y_max)
        axes[i, 0].set_xticks(x_ticks)
        axes[i, 0].set_yticks(y_ticks)
        axes[i, 0].set_xticklabels(x_labels)
        axes[i, 0].set_yticklabels(y_labels)
        axes[i, 0].grid(alpha=0.25, color='silver')

        # (B) Predicted
        data_pred = y_pred[idx][::-1]
        masked_pred = np.ma.masked_where(data_pred <= threshold, data_pred)

        im_pred = axes[i, 1].imshow(
            masked_pred,
            cmap=cmap_with_white,
            extent=(x_min, x_max, y_min, y_max),
            vmin=threshold,
            vmax=local_max
        )
        ctprvn_proj.boundary.plot(
            ax=axes[i, 1], edgecolor='black', facecolor='none', linewidth=1, alpha=0.25
        )
        axes[i, 1].set_title(f"Predicted (#{idx})")
        axes[i, 1].set_xlabel('Longitude [°]')
        axes[i, 1].set_ylabel('Latitude [°]')
        axes[i, 1].set_xlim(x_min, x_max)
        axes[i, 1].set_ylim(y_min, y_max)
        axes[i, 1].set_xticks(x_ticks)
        axes[i, 1].set_yticks(y_ticks)
        axes[i, 1].set_xticklabels(x_labels)
        axes[i, 1].set_yticklabels(y_labels)
        axes[i, 1].grid(alpha=0.25, color='silver')

        # (C) Difference
        data_diff = np.abs(y_true[idx] - y_pred[idx])[::-1]
        masked_diff = np.ma.masked_where(data_diff <= threshold, data_diff)

        im_diff = axes[i, 2].imshow(
            masked_diff,
            cmap=cmap_with_white,
            extent=(x_min, x_max, y_min, y_max),
            vmin=threshold,
            vmax=local_max
        )
        ctprvn_proj.boundary.plot(
            ax=axes[i, 2], edgecolor='black', facecolor='none', linewidth=1, alpha=0.25
        )
        axes[i, 2].set_title(f"Difference (#{idx})")
        axes[i, 2].set_xlabel('Longitude [°]')
        axes[i, 2].set_ylabel('Latitude [°]')
        axes[i, 2].set_xlim(x_min, x_max)
        axes[i, 2].set_ylim(y_min, y_max)
        axes[i, 2].set_xticks(x_ticks)
        axes[i, 2].set_yticks(y_ticks)
        axes[i, 2].set_xticklabels(x_labels)
        axes[i, 2].set_yticklabels(y_labels)
        axes[i, 2].grid(alpha=0.25, color='silver')

    # 서브플롯 간격/레이아웃 조정
    plt.subplots_adjust(wspace=-0.4, hspace=0.2)
    plt.tight_layout(rect=[0, 0, 0.88, 0.96])

    cbar = fig.colorbar(
        im_true,
        ax=axes.ravel().tolist(),
        orientation='vertical',
        fraction=0.03,
        pad=0.02,
        shrink=0.8
    )
    cbar.set_label('conc. [$\\mu \\mathrm{g}/\\mathrm{m}^3$]')

    plt.show()

# ==============================
print(np.argmax(score))
plot_prediction_loss(true_conc_map_w_lines, pred_conc_map_w_lines, indices=np.argmax(score))
# Out:
# 4

# %% [markdown]
# # 기타 분석 내용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import statsmodels.api as sm

# ----------------------------------------
# 1. 기본 지표 계산 함수 (예: NSE, d, Spearman, MBE, FB 등)
# ----------------------------------------
def nash_sutcliffe_efficiency(y_true, y_pred):
    """
    Nash–Sutcliffe Efficiency (NSE)
    hydrological model 평가에 자주 사용되는 지표
    """
    numerator = np.sum((y_true - y_pred)**2)
    denominator = np.sum((y_true - np.mean(y_true))**2)
    return 1 - numerator / denominator

def willmott_d(y_true, y_pred):
    """
    Willmott's d
    관측값과 예측값의 편차를 표준화하는 방식
    """
    obs_mean = np.mean(y_true)
    numerator = np.sum((y_pred - y_true)**2)
    denominator = np.sum((np.abs(y_pred - obs_mean) + np.abs(y_true - obs_mean))**2)
    return 1 - (numerator / denominator)

def spearman_corr(y_true, y_pred):
    """
    스피어만 상관계수
    비선형 관계에서도 순위 정보를 반영하여 상관성 측정
    """
    rho, pval = st.spearmanr(y_true, y_pred)
    return rho, pval

def mean_bias_error(y_true, y_pred):
    """ MBE (Mean Bias Error) """
    return np.mean(y_pred - y_true)

def fractional_bias(y_true, y_pred):
    """
    Fractional Bias (화학농도 예측에서 자주 쓰이는 지표 중 하나)
    """
    return 2.0 * np.mean(y_pred - y_true) / np.mean(y_pred + y_true)


# ----------------------------------------
# 2. 잔차 분석 및 시각화
# ----------------------------------------
def plot_residuals(y_true, y_pred):
    """
    Residual vs. True, Residual vs. Pred, 그리고 Q-Q plot을 그려서
    잔차의 분포/정규성/극단값 구간 등을 시각적으로 확인
    """
    residuals = y_true - y_pred

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
    # (1) Residual vs. True
    axes[0].scatter(y_true, residuals, color='blue', alpha=0.7, edgecolors='none')
    axes[0].axhline(0, color='red', linestyle='--')
    axes[0].set_xlabel('True O3 [µg/m³]')
    axes[0].set_ylabel('Residual (Pred - True)')
    axes[0].set_title('Residual vs. True O3')

    # (2) Residual vs. Pred
    axes[1].scatter(y_pred, residuals, color='orange', alpha=0.7, edgecolors='none')
    axes[1].axhline(0, color='red', linestyle='--')
    axes[1].set_xlabel('Pred O3 [µg/m³]')
    axes[1].set_ylabel('Residual (Pred - True)')
    axes[1].set_title('Residual vs. Pred O3')

    # (3) Q-Q plot
    sm.qqplot(residuals, line='45', ax=axes[2], markersize=3, color='blue')
    axes[2].set_title('Q-Q Plot of Residuals')

    plt.tight_layout()
    plt.show()


# ----------------------------------------
# 3. 고농도 구간(예: 0.03 µg/m³ 초과)만 별도 분석
# ----------------------------------------
def analyze_high_concentration(y_true, y_pred, threshold=0.03):
    """
    예: y_true가 0.03 µg/m³ 이상인 부분만 추려서
        NSE, d, Spearman, etc. 재계산
    """
    mask = (y_true > threshold)
    if np.sum(mask) < 2:
        print(f"[High O3 > {threshold:.3f}] 샘플이 충분치 않습니다.")
        return

    y_true_high = y_true[mask]
    y_pred_high = y_pred[mask]

    nse_val = nash_sutcliffe_efficiency(y_true_high, y_pred_high)
    d_val   = willmott_d(y_true_high, y_pred_high)
    rho, pval = spearman_corr(y_true_high, y_pred_high)

    print(f"[High O3 > {threshold:.3f}]")
    print(f"  NSE = {nse_val:.4f}")
    print(f"  d   = {d_val:.4f}")
    print(f"  Spearman = {rho:.4f}, p-value = {pval:.1e}")


# ----------------------------------------
# 4. 로그 변환 후의 지표 분석
# ----------------------------------------
def analyze_log_transform(y_true, y_pred, offset=1e-5):
    """
    농도 값이 0에 가까울 수 있으므로 offset을 더해 로그 변환
    """
    # 0 또는 음수값이 있을 수 있으므로 작은 offset 추가
    y_true_log = np.log(y_true + offset)
    y_pred_log = np.log(y_pred + offset)

    nse_val = nash_sutcliffe_efficiency(y_true_log, y_pred_log)
    d_val   = willmott_d(y_true_log, y_pred_log)
    rho, pval = spearman_corr(y_true_log, y_pred_log)

    print("[Log-Transformed Analysis]")
    print(f"  NSE(log)      = {nse_val:.4f}")
    print(f"  d(log)        = {d_val:.4f}")
    print(f"  Spearman(log) = {rho:.4f}, p-value = {pval:.1e}")


# ----------------------------------------
# 5. 전체 파이프라인 예시
# ----------------------------------------
def main_evaluation_pipeline(y_true, y_pred, threshold=0.03):
    """
    전체 파이프라인 예시
    1) 잔차 시각화
    2) 전체 지표 계산
    3) 고농도 구간 지표 계산
    4) 로그 변환 지표 계산
    """

    # 1) 잔차 시각화
    plot_residuals(y_true, y_pred)

    # 2) 전체 지표
    nse_val  = nash_sutcliffe_efficiency(y_true, y_pred)
    d_val    = willmott_d(y_true, y_pred)
    rho, pval = spearman_corr(y_true, y_pred)
    mbe_val  = mean_bias_error(y_true, y_pred)
    fb_val   = fractional_bias(y_true, y_pred)

    print(f"Overall Metrics:")
    print(f"  NSE         = {nse_val:.4f}")
    print(f"  d           = {d_val:.4f}")
    print(f"  Spearman    = {rho:.4f}, p-value = {pval:.1e}")
    print(f"  MBE         = {mbe_val:.4f}")
    print(f"  Fractional Bias = {fb_val:.4f}\n")

    # 3) 고농도 구간 지표
    analyze_high_concentration(y_true, y_pred, threshold=threshold)

    # 4) 로그 변환 지표
    analyze_log_transform(y_true, y_pred, offset=1e-5)

main_evaluation_pipeline(y_true_modi, y_pred_modi, threshold=0.03)
# Out:
# /home/user/.local/lib/python3.10/site-packages/statsmodels/graphics/gofplots.py:1041: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)
# Overall Metrics:
#   NSE         = 0.9991
#   d           = 0.9998
#   Spearman    = 0.9997, p-value = 0.0e+00
#   MBE         = 0.0000
#   Fractional Bias = 0.0007
#
# [High O3 > 0.030]
#   NSE = 0.9687
#   d   = 0.9922
#   Spearman = 0.9873, p-value = 0.0e+00
# [Log-Transformed Analysis]
#   NSE(log)      = 1.0000
#   d(log)        = 1.0000
#   Spearman(log) = 0.9997, p-value = 0.0e+00
