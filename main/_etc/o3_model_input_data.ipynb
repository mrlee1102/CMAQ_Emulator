# %% [markdown]
# REFERENCE:
#
#     input_data_setup.ipynb
#
# SETUP:
#
#     focus on prediction "O3"
#
#     Using training data for "O3" Prediction

# %%
import os
import numpy as np
import pandas as pd
import netCDF4 as nc
from netCDF4 import Dataset

# %%
emis_ctrl_mat = pd.read_csv('/home/user/workdir/CMAQ_Emulator/main/resources/ctrl/precursor_control_2013.csv', index_col=0)
filtering_column = emis_ctrl_mat.columns[emis_ctrl_mat.columns.str.contains('NOX|VOC|NH3')]
data_set = emis_ctrl_mat[filtering_column]
data_set
# Out:
#      A_NOX_ALL  A_VOC_ALL  A_NH3_ALL  B_NOX_ALL  B_VOC_ALL  B_NH3_ALL  \
# 1     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 2     0.871163   1.241296   1.241296   0.869528   1.008703   1.008703
# 3     0.734821   0.647231   0.647231   1.188854   1.000202   1.000202
# 4     1.234901   1.263537   1.263537   0.955756   0.971038   0.971038
# 5     0.806340   0.734720   0.734720   1.090280   1.147626   1.147626
# ..         ...        ...        ...        ...        ...        ...
# 115   0.649676   1.279131   1.279131   1.334521   0.679807   0.679807
# 116   0.974798   0.671351   0.671351   0.850271   0.916459   0.916459
# 117   0.886244   1.100741   1.100741   0.619206   0.974206   0.974206
# 118   0.892489   0.816186   0.816186   0.916137   0.945854   0.945854
# 119   0.919966   0.747131   0.747131   1.209267   1.010035   1.010035
#
#      C_NOX_ALL  C_VOC_ALL  C_NH3_ALL  D_NOX_ALL  ...  N_NH3_ALL  O_NOX_ALL  \
# ...

# %%
# 필터링된 데이터프레임 저장
output_file_path = '/home/user/workdir/CMAQ_Emulator/main/resources/ctrl/precursor_control_matrix_2013_for_o3.csv'
data_set.to_csv(output_file_path)
print(f"Filtered data saved to {output_file_path}")
# Out:
# Filtered data saved to /home/user/workdir/CMAQ_Emulator/main/resources/ctrl/precursor_control_matrix_2013_for_o3.csv
