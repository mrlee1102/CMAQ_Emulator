# %%
import os

import numpy as np
import pandas as pd
import netCDF4 as nc
from netCDF4 import Dataset

# %%
origin_data = pd.read_csv('/home/user/workdir/main/resources/ctrl/precursor_control_2019_4input_origin_o3.csv')
origin_data.describe()
# Out:
#         A_NOX_ALL   A_VOC_ALL   A_NH3_ALL  A_PM25_ALL    A_O3_ALL   B_NOX_ALL  \
# count  119.000000  119.000000  119.000000  119.000000  119.000000  119.000000
# mean     1.005910    0.998434    1.000558    1.002395    0.022114    1.003876
# std      0.206400    0.239082    0.183563    0.183808    0.090417    0.189965
# min      0.588029    0.531930    0.599285    0.550902    0.010711    0.582765
# 25%      0.842938    0.783113    0.883708    0.877794    0.012596    0.860374
# 50%      0.991268    1.001864    0.994100    0.999322    0.013554    1.004567
# 75%      1.178626    1.226506    1.153573    1.142681    0.015086    1.152588
# max      1.447161    1.385267    1.372199    1.368511    1.000000    1.400156
#
#         B_VOC_ALL   B_NH3_ALL  B_PM25_ALL    B_O3_ALL  ...   P_NOX_ALL  \
# count  119.000000  119.000000  119.000000  119.000000  ...  119.000000
# mean     0.997677    1.001811    1.004072    0.044706  ...    1.011087
# ...

# %%
normalized_data = pd.read_csv('/home/user/workdir/main/resources/ctrl/precursor_control_2019_4input_o3.csv')
normalized_data.describe()
# Out:
#         A_NOX_ALL   A_VOC_ALL   A_NH3_ALL  A_PM25_ALL    A_O3_ALL   B_NOX_ALL  \
# count  119.000000  119.000000  119.000000  119.000000  119.000000  119.000000
# mean     1.005910    0.998434    1.000558    1.002395    0.617506    1.003876
# std      0.206400    0.239082    0.183563    0.183808    0.053812    0.189965
# min      0.588029    0.531930    0.599285    0.550902    0.511117    0.582765
# 25%      0.842938    0.783113    0.883708    0.877794    0.586106    0.860374
# 50%      0.991268    1.001864    0.994100    0.999322    0.621268    1.004567
# 75%      1.178626    1.226506    1.153573    1.142681    0.649144    1.152588
# max      1.447161    1.385267    1.372199    1.368511    1.000000    1.400156
#
#         B_VOC_ALL   B_NH3_ALL  B_PM25_ALL    B_O3_ALL  ...   P_NOX_ALL  \
# count  119.000000  119.000000  119.000000  119.000000  ...  119.000000
# mean     0.997677    1.001811    1.004072    1.150554  ...    1.011087
# ...

# %%
scaled_data = pd.read_csv('/home/user/workdir/main/resources/ctrl/precursor_control_2019_4input_scaled_o3.csv')
scaled_data.describe()
# Out:
#         A_NOX_ALL   A_VOC_ALL   A_NH3_ALL  A_PM25_ALL    A_O3_ALL   B_NOX_ALL  \
# count  119.000000  119.000000  119.000000  119.000000  119.000000  119.000000
# mean     1.005910    0.998434    1.000558    1.002395    0.599099    1.003876
# std      0.206400    0.239082    0.183563    0.183808    0.062036    0.189965
# min      0.588029    0.531930    0.599285    0.550902    0.500000    0.582765
# 25%      0.842938    0.783113    0.883708    0.877794    0.557903    0.860374
# 50%      0.991268    1.001864    0.994100    0.999322    0.587315    1.004567
# 75%      1.178626    1.226506    1.153573    1.142681    0.634384    1.152588
# max      1.447161    1.385267    1.372199    1.368511    1.000000    1.400156
#
#         B_VOC_ALL   B_NH3_ALL  B_PM25_ALL    B_O3_ALL  ...   P_NOX_ALL  \
# count  119.000000  119.000000  119.000000  119.000000  ...  119.000000
# mean     0.997677    1.001811    1.004072    1.293151  ...    1.011087
# ...

# %%
import numpy as np

# %%
data = np.load('/mnt/dsk1/yhlee/workdir/cmaqnet/datasets/conc_o3_total.npy')

# %%
data.shape
# Out:
# (119, 3912, 82, 67, 1)
